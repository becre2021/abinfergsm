# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(precision = 4)
import os
import pickle 
import pandas as pd
from datetime import date
from datetime import datetime

import sys
sys.path.append('./../')

# %%
import seaborn as sns
sns.set()
sns.set_style('white')
#sns.set_style('whitegrid')
import matplotlib
plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
#plt.rc('font', weight='bold')

current_palette = sns.color_palette(sns.hls_palette(10+1, l=.4, s=1.0))
sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %%
saved_pickle_path = './result_pickle/'
format_name = '.pickle'

# %%
def get_resultpickle(saved_filename):
    with open(saved_pickle_path + saved_filename + format_name, 'rb') as f:
        result_pickle = pickle.load(f) # 단 한줄씩 읽어옴    
    return result_pickle

def read_resultpikcle(result_pickle):
    print('#'*100)
    print('Exp_setting')
    print(result_pickle['Exp_setting'])
    if 'model_name' in result_pickle['Exp_setting'].keys():
        print('model_name : ' + result_pickle['Exp_setting']['model_name'])
    if 'kernel_type' in result_pickle['Exp_setting'].keys():
        print('kernel_type : ' + result_pickle['Exp_setting']['kernel_type'])    
    if 'semi_option' in result_pickle['Exp_setting'].keys():
        print('semisupervised_option : %s'%(result_pickle['Exp_setting']['semi_option']))   
    if 'lambda'in result_pickle['Exp_setting'].keys():
        print('alpha : %s' %(result_pickle['Exp_setting']['lambda']))   

    print('test rmse')
    print(np.asarray(result_pickle['test_rmse'][result_pickle['Exp_setting']['model_name']]))
    print('')
    return

# %%
##################################################################################################################################################3

#saved_filename = 'data_CO2_taskweightsampling_Q7_totalsamplept70_numbatch1_optiter10000_kloptionFalse_repetitiveexp2'
#saved_filename = 'data_airline_taskweightsampling_Q10_totalsamplept100_numbatch1_optiter15000_kloptionFalse_repetitiveexp2'


##################################################################################################################################################3
#saved_filename = 'data_airline_taskweightsampling_Q4_totalsamplept80_numbatch1_optiter10000_kloptionFalse_repetitiveexp3'
#saved_filename = 'data_airline_taskweightsampling_Q4_totalsamplept40_numbatch1_optiter20000_kloptionFalse_repetitiveexp3'


#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter5000_kloptionFalse_repetitiveexp3_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter5000_kloptionFalse_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter5000_kloptionFalse_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter5000_kloptionFalse_repetitiveexp1_randomseedstart1000'


#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter4000_kloptionFalse_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter4000_kloptionTrue_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept20_numbatch1_optimizerAdam_optiter3000_kloptionTrue_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter3000_kloptionTrue_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp1_randomseedstart1000'
#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp1_randomseedstart1000'
saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp1_randomseedstart1000'

#saved_filename = 'data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp5_randomseedstart1000'

# %%
import os.path
from os import path
save_figure_path  = './result_figure/exp1/'
os.makedirs(save_figure_path) if path.isdir(save_figure_path) is False else 1
# Out:
# 1

# %%
save_figname = 'data_SM_Q2' + '_Recovery'

# %%
result_pickle = get_resultpickle(saved_filename)
result_pickle.keys()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-7d4ada0168a7> in <module>()
# ----> 1 result_pickle = get_resultpickle(saved_filename)
#       2 result_pickle.keys()
#
# <ipython-input-4-bde10862e280> in get_resultpickle(saved_filename)
#       1 def get_resultpickle(saved_filename):
# ----> 2     with open(saved_pickle_path + saved_filename + format_name, 'rb') as f:
#       3         result_pickle = pickle.load(f) # 단 한줄씩 읽어옴
#       4     return result_pickle
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './result_pickle/data_SM_Q2_exp1_Q2_lrhyp0.001_totalsamplept10_numbatch1_optimizerAdam_optiter5000_kloptionTrue_repetitiveexp1_randomseedstart1000.pickle'

# %%
result_pickle['Exp_setting']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1bb1bb583843> in <module>()
# ----> 1 result_pickle['Exp_setting']
#
# NameError: name 'result_pickle' is not defined

# %%
x_train = result_pickle['Data_setting']['x_train']
y_train = result_pickle['Data_setting']['y_train']
x_train_s = result_pickle['Data_setting']['x_train_s']
y_train_s = result_pickle['Data_setting']['y_train_s']
x_test = result_pickle['Data_setting']['x_test']
y_test = result_pickle['Data_setting']['y_test']
x_full = result_pickle['Data_setting']['x_full']
y_full = result_pickle['Data_setting']['y_full']

# %%
x_train.shape,x_test.shape
# Out:
# ((1600, 1), (401, 1))

# %%
result_pickle['Exp_setting']
# Out:
# {'random_seed': 1000,
#  'input_dim': 1,
#  'init_sample_num': 50,
#  'Num_Q': 2,
#  'lr_hyp': 0.001,
#  'noise_err': 0.08829743668243585,
#  'kl_option': True,
#  'num_sample_pt': 5,
#  'num_batch': 1,
#  'tau0': 1000,
#  'iter': 5000,
#  'num_rep': 1,
#  'weight_rate': 0.01,
#  'optimizer': 'Adam',
#  'hypparam': {'weight': array([[1.],
#          [1.]]), 'mean': array([[0.1562],
#          [0.9271]]), 'mean_prior': array([[0.],
#          [0.]]), 'std': array([[0.0313],
#          [0.2285]]), 'std_prior': array([[1.],
#          [1.]]), 'noise_variance': 1.0, 'length_scale': 0.5}}

# %%
from collections import OrderedDict

def get_static(result_pickle,metric = 'loss'):    #metic = 
    loss_mean = OrderedDict()
    loss_std = OrderedDict()
    for ith_model in result_pickle[metric]:
        loss_mean[ith_model] = np.asarray(result_pickle[metric][ith_model]).mean(axis = 0)
        loss_std[ith_model] = np.asarray(result_pickle[metric][ith_model]).std(axis = 0)
    return loss_mean,loss_std

# %%
loss_mean,loss_std = get_static(result_pickle,metric = 'loss')
rmse_mean,rmse_std = get_static(result_pickle,metric = 'rmse')
mnll_mean,mnll_std = get_static(result_pickle,metric = 'mnll')
#get_static(result_pickle,metric = 'pred_mu')

# %%
from matplotlib.ticker import StrMethodFormatter
import matplotlib.ticker as ticker

#figsiz = (6,4) 
figsiz = (7,5) 
#figsiz = (10,6) 
labelsiz = 18
fontsiz = 20
interval = 0.2

# %%
#target_model_list = ['weight_reg','weight_reg_nat']
#target_model_list = ['gpsm','equal_reg','equal_reg_nat','weight_reg','weight_reg_nat']
target_model_list = ['equal_reg','weight_reg']

#target_model_list = ['equal_reg','equal_reg_nat']

#color_dict = {'gpsm': 0 ,'equal_reg' : 2,'equal_reg_nat' : 10,'weight_reg' : 4,'weight_reg_nat' : 7 }
color_dict = {'gpsm': 0 ,'equal_reg' : 7, 'gprbf' :4,'weight_reg' : 5}
num_tick = 100
#target_model_list = ['gpsm']

# %%
plt.figure(figsize = (15,4))
plt.subplot(1,3,1)
#for ith_model,ith_color in zip(loss_mean,color_list):
for ith_model in loss_mean:
    iteration = np.arange(len(rmse_mean[ith_model]))        
    if ith_model in target_model_list :    
        plt.plot(iteration[::num_tick], loss_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          loss_mean[ith_model][::num_tick] - loss_std[ith_model][::num_tick],
                          loss_mean[ith_model][::num_tick] + loss_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])

    
plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('nlml',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
#plt.xlim([0,1000])
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
#plt.show()


plt.subplot(1,3,2)
for ith_model in rmse_mean:    
    if ith_model in target_model_list :        
        plt.plot(iteration[::num_tick], rmse_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          rmse_mean[ith_model][::num_tick] - rmse_std[ith_model][::num_tick],
                          rmse_mean[ith_model][::num_tick] + rmse_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])

    
plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('rmse',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
#plt.show()


plt.subplot(1,3,3)
for ith_model in  mnll_mean:
    if ith_model in target_model_list :    
        plt.plot(iteration[::num_tick], mnll_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          mnll_mean[ith_model][::num_tick] - mnll_std[ith_model][::num_tick],
                          mnll_mean[ith_model][::num_tick] + mnll_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])
    

plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('mnll',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = figsiz)
#for ith_model,ith_color in zip(loss_mean,color_list):
for ith_model in loss_mean:
    iteration = np.arange(len(rmse_mean[ith_model]))        
    if ith_model in target_model_list :    
        plt.plot(iteration[::num_tick], loss_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          loss_mean[ith_model][::num_tick] - loss_std[ith_model][::num_tick],
                          loss_mean[ith_model][::num_tick] + loss_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])

    
plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('nlml',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
#plt.xlim([0,1000])
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = figsiz)
#for ith_model,ith_color in zip(rmse_mean,color_list):
for ith_model in rmse_mean:    
    if ith_model in target_model_list :        
        plt.plot(iteration[::num_tick], rmse_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          rmse_mean[ith_model][::num_tick] - rmse_std[ith_model][::num_tick],
                          rmse_mean[ith_model][::num_tick] + rmse_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])

    
plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('rmse',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = figsiz)
#for ith_model,ith_color in zip(mnll_mean,color_list):
for ith_model in  mnll_mean:
    if ith_model in target_model_list :    
        plt.plot(iteration[::num_tick], mnll_mean[ith_model][::num_tick] , label = ith_model, color = current_palette[color_dict[ith_model]] , linewidth = 2)
        plt.fill_between( iteration[::num_tick],
                          mnll_mean[ith_model][::num_tick] - mnll_std[ith_model][::num_tick],
                          mnll_mean[ith_model][::num_tick] + mnll_std[ith_model][::num_tick],
                          alpha = 0.5, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])
    

plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('mnll',fontsize = fontsiz)
plt.xlabel('iteration',fontsize = fontsiz)
plt.tick_params(axis='both', which='major', labelsize= fontsiz)
plt.legend(fontsize = fontsiz)
plt.tight_layout()
plt.show()

# %%
from scipy import signal
from scipy import  stats

#def get_symmetric_gaussain_density(weight_param,mu_param,std_param,x):
def get_symmetric_gaussain_density(result_pickle = None,weight_param = None,mu_param = None,std_param = None,ith_model = None,x = None):
    if result_pickle is not None:
        weight_param = np.asarray(result_pickle['param_history'][ith_model]['weight']).squeeze()[-1]
        mu_param = np.asarray(result_pickle['param_history'][ith_model]['mu']).squeeze()[-1]
        std_param = np.asarray(result_pickle['param_history'][ith_model]['std']).squeeze()[-1]    
    print(ith_model)
    print(weight_param)
    print(mu_param)
    print(std_param)

    #print( 'weight param : {0:.4f}'.format(weight_param))
    
    a = []
    for ith_weight,ith_mu,ith_std in zip(weight_param,mu_param,std_param):
        print(ith_weight,ith_mu,ith_std)
        a.append(.5*ith_weight* ( stats.norm.pdf(x, ith_mu,ith_std**2) + stats.norm.pdf(x, -ith_mu ,ith_std**2) ) )
        #print('')
    a =  np.asarray(a).sum(axis = 0)
    #return a
    #return np.asarray(a)
    #print(a)
    print('')
    #return a/a.sum()
    return a

# %%
result_pickle['Exp_setting']['hypparam']
# Out:
# {'weight': array([[1.],
#         [1.]]), 'mean': array([[0.1562],
#         [0.9271]]), 'mean_prior': array([[0.],
#         [0.]]), 'std': array([[0.0313],
#         [0.2285]]), 'std_prior': array([[1.],
#         [1.]]), 'noise_variance': 1.0, 'length_scale': 0.5}

# %%
#mixture kernel with weights 1 and 0.5, spectral means of 0.2 and 0.9 and standard deviations of 0.05.

# %%
w = np.arange(0,1.5,0.00001)
#s_w = get_symmetric_gaussain_density(weight_param[-1],mu_param[-1],std_param[-1] ,w)

s_w_equal = get_symmetric_gaussain_density(result_pickle = result_pickle,ith_model = 'equal_reg' ,x = w)
s_w_weight = get_symmetric_gaussain_density(result_pickle = result_pickle,ith_model = 'weight_reg' ,x = w)
s_w_sm = get_symmetric_gaussain_density(result_pickle = result_pickle,ith_model = 'gpsm' ,x = w)
s_w_true = get_symmetric_gaussain_density(weight_param = [1,0.5],mu_param = [0.2,0.9],std_param = [.05,.05],x = w)
# Out:
# equal_reg
# [2.9278 8.3035]
# [0.1996 0.8983]
# [0.0068 0.0295]
# 2.9278412053942007 0.19961793052642793 0.006843820895207596
# 8.303470218984986 0.8983108701247734 0.029500166834458386
#
# weight_reg
# [3.9949 5.4912]
# [0.1998 0.8969]
# [0.007  0.0253]
# 3.9949079060455355 0.19975470478672464 0.006994552256875366
# 5.491211781177901 0.8969495162381219 0.025309374029644355
#
# gpsm
# [0.3044 0.3184]
# [0.1994 0.8991]
# [0.0038 0.0021]
# 0.3043542141100246 0.19940843224710544 0.0038125567010448506
# 0.3183733926204732 0.899061421227355 0.0020696177108941254
#
# None
# [1, 0.5]
# [0.2, 0.9]
# [0.05, 0.05]
# 1 0.2 0.05
# 0.5 0.9 0.05

# %%
for ith_model in result_pickle['best_loss']:
    ith_mean = np.asarray(result_pickle['best_loss'][ith_model]).mean()
    ith_std =  np.asarray(result_pickle['best_loss'][ith_model]).std()
    print('loss %s           \t mean :%4f \t std :%4f'%(ith_model,ith_mean,ith_std))
# Out:
# loss gpsm           	 mean :-18.278305 	 std :0.000000
# loss equal_reg           	 mean :161.662773 	 std :0.000000
# loss weight_reg           	 mean :163.797113 	 std :0.000000
# loss gprbf           	 mean :60.366366 	 std :0.000000

# %%
for ith_model in result_pickle['best_rmse']:
    ith_mean = np.asarray(result_pickle['best_rmse'][ith_model]).mean()
    ith_std =  np.asarray(result_pickle['best_rmse'][ith_model]).std()
    print('rmse %s           \t mean :%4f \t std :%4f'%(ith_model,ith_mean,ith_std))
# Out:
# rmse gpsm           	 mean :0.104451 	 std :0.000000
# rmse equal_reg           	 mean :0.103604 	 std :0.000000
# rmse weight_reg           	 mean :0.102665 	 std :0.000000
# rmse gprbf           	 mean :3.743840 	 std :0.000000

# %%
for ith_model in result_pickle['best_mnll']:
    ith_mean = np.asarray(result_pickle['best_mnll'][ith_model]).mean()
    ith_std =  np.asarray(result_pickle['best_mnll'][ith_model]).std()
    print('mnll %s           \t mean :%4f \t std :%4f'%(ith_model,ith_mean,ith_std))
# Out:
# mnll gpsm           	 mean :-0.232803 	 std :0.000000
# mnll equal_reg           	 mean :-0.199427 	 std :0.000000
# mnll weight_reg           	 mean :-0.200194 	 std :0.000000
# mnll gprbf           	 mean :26.938424 	 std :0.000000

# %%
figsiz = (8,5) 
labelsiz = 15
fontsiz = 20
interval = 0.2

# %%
truecolor = current_palette[1]

# %%
ith_exp_index = 0

# %%
plt.figure(figsize = (10,5))

#plt.scatter(x_train_s,y_train_s , s = 50 , color = truecolor ,label = 'true')        
plt.plot(x_full, y_full ,label = 'true' , linewidth = 2.0)

# %%
result_pickle['pred_test_mu']['gprbf']
# Out:
# [array([[-0.8817],
#         [-0.7919],
#         [-0.7062],
#         ...,
#         [-2.1416],
#         [-2.3448],
#         [-2.5802]])]

# %%
result_pickle['pred_test_mu'][ith_model]
# Out:
# [array([[-0.8817],
#         [-0.7919],
#         [-0.7062],
#         ...,
#         [-2.1416],
#         [-2.3448],
#         [-2.5802]])]

# %%
color_dict
# Out:
# {'gpsm': 0, 'equal_reg': 7, 'gprbf': 4, 'weight_reg': 5}

# %%
### for iith,(ith_model,ith_color) in enumerate(zip(result_pickle['pred_mu'],color_list)):

#plt.figure(figsize = figsiz)
plt.figure(figsize = (8,5))


plt.plot(x_full, y_full,color = truecolor ,label = 'true' , linewidth = 1.3)

ith_model = 'gprbf'
plt.plot(x_full,result_pickle['pred_test_mu'][ith_model][ith_exp_index] , label = 'RBF' , color = current_palette[color_dict[ith_model]] , linewidth = 1.5)
plt.fill_between( x_full.squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] - 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] + 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  alpha = 0.4, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]]  )


ith_model = 'gpsm'
plt.plot(x_full,result_pickle['pred_test_mu'][ith_model][ith_exp_index] , label = 'SM' , color = current_palette[color_dict[ith_model]] , linewidth = 1.5)
plt.fill_between( x_full.squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] - 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] + 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  alpha = 0.4, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]]  )

ith_model = 'equal_reg'
plt.plot(x_full,result_pickle['pred_test_mu'][ith_model][ith_exp_index] , label = 'SVSS' , color = current_palette[color_dict[ith_model]] , linewidth = 1.5)
plt.fill_between( x_full.squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] - 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  (result_pickle['pred_test_mu'][ith_model][ith_exp_index] + 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
                  alpha = 0.4, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]] )



plt.scatter(x_train_s,y_train_s , s = 55 , color = truecolor ,label = 'training')        

# ith_model = 'weight_reg'
# plt.plot(x_full,result_pickle['pred_test_mu'][ith_model][ith_exp_index] , label = 'SSVS Ws' , color = current_palette[color_dict[ith_model]] , linewidth = 1.5)
# plt.fill_between( x_full.squeeze(),
#                   (result_pickle['pred_test_mu'][ith_model][ith_exp_index] - 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
#                   (result_pickle['pred_test_mu'][ith_model][ith_exp_index] + 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
#                   alpha = 0.4, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]] )


# for iith,ith_model in enumerate(result_pickle['pred_test_mu']):
#     plt.plot(x_full,result_pickle['pred_test_mu'][ith_model][ith_exp_index] , label = ith_model , color = current_palette[color_dict[ith_model]] , linewidth = 1.0)
#     plt.fill_between( x_full.squeeze(),
#                       (result_pickle['pred_test_mu'][ith_model][ith_exp_index] - 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
#                       (result_pickle['pred_test_mu'][ith_model][ith_exp_index] + 2*np.sqrt(result_pickle['pred_test_var'][ith_model][ith_exp_index])).squeeze(),
#                       alpha = 0.2, edgecolor = current_palette[color_dict[ith_model]], facecolor = current_palette[color_dict[ith_model]])




plt.tick_params(labelsize=labelsiz) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.ylabel('y',fontsize = 20)
plt.xlabel('x',fontsize = 20)
plt.xlim([-7.5,7.5])
plt.ylim([-2.5,2.5])

plt.tick_params(axis='both', which='major', labelsize= fontsiz)

#plt.legend(fontsize = fontsiz,loc = 'best')
#plt.legend(loc='center', bbox_to_anchor=(1, 0.5, 0, 0),fontsize = 15)
#plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", mode="expand", borderaxespad=0, ncol=6,fontsize = 15)
leg = plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", mode="expand", borderaxespad=0, ncol=3,fontsize = 18)
for i in leg.legendHandles:
    i.set_linewidth(3)        

plt.tight_layout()

plt.savefig(save_figure_path + save_figname   + '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
plt.show()


save_figure_path + save_figname
# Out:
# './result_figure/exp1/data_SM_Q2_Recovery'

# %%
len(w)
# Out:
# 150000

# %%
from scipy import signal
import matplotlib.pyplot as plt
fs = int(1/(x_full[1]-x_full[0]))
f, Pxx_den = signal.periodogram(y_full.squeeze(), fs)

init0 = 1e-8

plt.figure(figsize = (8,5))
#plt.plot(w,s_w_sm,'b')
#plt.plot(w,s_w_equal,'r')

plt.plot(f,np.log(Pxx_den + init0), label = 'Empirical', color = 'g' , linewidth = 2)
#plt.plot(f, np.log(np.sqrt(Pxx_den)),'g')

ith_model = 'true'
plt.plot(w,np.log(s_w_true + init0), label = 'true', color = 'k' , linewidth = 2 )


# ith_model = 'weight_reg'
# plt.plot(w,np.log(s_w_weight +1e-16), label = 'SSVS Ws', color = current_palette[color_dict[ith_model]] , linewidth = 1.5)


ith_model = 'equal_reg'
plt.plot(w,np.log(s_w_equal + init0), label = 'SVSS', color = current_palette[color_dict[ith_model]] , linewidth = 2.5,alpha = 0.8)


ith_model = 'gpsm'
plt.plot(w,np.log(s_w_sm + init0), label = 'SM', color = current_palette[color_dict[ith_model]] , linewidth = 2.5 ,alpha = 0.8)





plt.tick_params(labelsize=20) 
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
# plt.ylabel('log power density',fontsize = 20)
# plt.xlabel('spectral domain',fontsize = 20)

plt.ylabel('log psd',fontsize = 20)
plt.xlabel('spectral domain',fontsize = 20)


# plt.xlim([-7.1,7.1])
# plt.ylim([-2.5,2.5])

plt.xlim([0,1.05])


leg = plt.legend(bbox_to_anchor=(0,1.06,1,0.2), loc="lower left", mode="expand", borderaxespad=0, ncol=4,fontsize = 18)
for i in leg.legendHandles:
    i.set_linewidth(3)        

plt.tight_layout()

plt.savefig(save_figure_path + save_figname + '2'   + '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
plt.show()


save_figure_path + save_figname + '2'
# Out:
# './result_figure/exp1/data_SM_Q2_Recovery2'

# %%
result_pickle['pred_test_mu'].keys()

# %%
xlim_range = [0-1,80]

from scipy import signal
from scipy import  stats


figsiz = (8,5) 
#figsiz = (6,3)
labelsiz = 15
fontsiz = 15
interval = 0.2

Fs = len(x_train[0])
fig,axs =  plt.subplots( 2, sharex=True , gridspec_kw={'hspace': 0.1})
ax1,ax2 = axs[0],axs[1]


for ith_z in range(10):
    #print(np.where(z_train==ith_z)[0][:3])
    for j,jth in enumerate(np.where(z_train==ith_z)[0][:5]):
        freqs, psd = signal.welch(y_train[jth], fs= Fs ,nperseg= len(y_train[jth]) )        
        if j == 0:
            ax1.plot(freqs, psd , color = current_palette[ith_z] , linewidth = 1 ,alpha = 1.0 ,label = 'class ' + str(ith_z + 1) )
        else:
            ax1.plot(freqs, psd , color = current_palette[ith_z] , linewidth = 1 , alpha = 1.0  )
    
#ax1.legend(loc='upper out',ncol = 3 ,fontsize = 10)
ax1.legend(bbox_to_anchor=(-0.05,1.02,1,0.1), loc="lower left", borderaxespad = 0.2 ,ncol = 5 ,fontsize = 9)
#ax1.legend(bbox_to_anchor=(1.04,0.5), loc="lower left", borderaxespad=0 ,ncol = 1 ,fontsize = 10)
fig.tight_layout()    
ax1.set_ylabel('psd',fontsize = 18)



current_iter = result_pickle['HMMGP_setting']['Iter_train']-1
x = np.arange(512)
for ith_emission in range(result_pickle['Exp_setting']['Num_HiddenState']):
    a = 0
    for ith_weight,ith_mu,ith_std in zip(result_pickle['paramhistory_dict'][chosen_idx]['weight'][current_iter][ith_emission],
                                         result_pickle['paramhistory_dict'][chosen_idx]['mu'][current_iter][ith_emission],
                                         result_pickle['paramhistory_dict'][chosen_idx]['std'][current_iter][ith_emission]) :
        a += .5*ith_weight* (stats.norm.pdf(x, ith_mu,ith_std**2) + stats.norm.pdf(x, -ith_mu ,ith_std**2))
    try : 
        #ax2.plot(x, a , color = current_palette[revised_order_dict[ith_emission]] , linewidth = 3.0 ,alpha = .9  ,label = 'state ' + str(ith_emission+1))
        ax2.plot(x, a , color = current_palette[revised_order_dict[ith_emission]] , linewidth = 2.0 ,alpha = 1.0  ,label = 'state ' + str(revised_order_dict[ith_emission]+1))        
    except:
        #ax2.plot(x, a , color = current_palette[ith_emission] , linewidth = 3.0 ,alpha = .9  ,label = 'state ' + str(ith_emission+1))
        ax2.plot(x, a , color = current_palette[ith_emission] , linewidth = 2.0 ,alpha = 1.0  ,label = 'state ' + str(ith_emission+1))  
#        ax2.plot(x, a , color = current_palette[2*revised_order_dict[ith_emission]] , linewidth = 3.0 ,alpha = .9  ,label = 'state ' + str(ith_emission+1))        
        
#ax2.set_ylim([0,0.6])
ax2.set_xlabel('Hz ',fontsize = 18)
ax2.set_ylabel('S(s)',fontsize = 18)
plt.xticks(fontsize = 15)
plt.xlim(xlim_range)


fig.tight_layout()    
plt.savefig(save_figure_path + model_name + '_psd_toegether'   + '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
model_name = 'equal_reg_nat'

# %%
predImg

# %%
imSize = 130
trainIdx = np.round((x_train + 1) * (imSize - 1) / 2.0).astype(int)
testIdx = np.round((x_test + 1) * (imSize - 1) / 2.0).astype(int)
fullImg = np.zeros((imSize, imSize))

for idx, y in zip(trainIdx, y_train):
    fullImg[idx[0], idx[1]] = y
    
for idx, y in zip(testIdx, y_test):
    fullImg[idx[0], idx[1]] = y
    
    
    
predImg = np.zeros((imSize, imSize))
for idx, y in zip(trainIdx, result_pickle['pred_train_mu'][model_name][ith_exp_index]):
    predImg[idx[0], idx[1]] = y

    
for idx, y in zip(testIdx, result_pickle['pred_test_mu'][model_name][ith_exp_index]):
    predImg[idx[0], idx[1]] = y
predImgPrcs = np.clip(predImg, -1, 1)


plt.figure()
plt.imshow(fullImg)
plt.show()


plt.figure()
plt.imshow(predImgPrcs)
plt.show()

# %% [markdown]
# ### true estimation

# %%
# _, revised_z_test_pred, _ = _measure_metric(z_test, z_test_pred)

# plt.figure(figsize = figsiz2 )
# for ith_x,ith_y,ith_z in zip(x_test,y_test,z_test):
#     plt.plot(ith_x,ith_y , color = current_palette[ith_z])
# #plt.title('true')
# plt.tick_params(labelsize=labelsiz) 
# plt.xlim([x_test.min() - interval , x_test.max() + interval])
# plt.ylabel('obs',fontsize = fontsiz)
# plt.xlabel('time',fontsize = fontsiz)
# plt.savefig(save_figure_path + save_figname_dataset + '_true'  + '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
# save_figure_path + save_figname_dataset + '_true'

# %% [markdown]
# ### prediction estimation

# %%
# plt.figure(figsize = figsiz2 )
# for ith_x,ith_y,ith_z in zip(x_test,y_test,revised_z_test_pred):
# #for ith_x,ith_y,ith_z in zip(x_test,y_test,z_test_pred):
#     plt.plot(ith_x,ith_y , color = current_palette[ith_z])     
# plt.tick_params(labelsize=labelsiz) 
# #plt.title('pred')
# plt.xlim([x_test.min() - interval , x_test.max() + interval])
# plt.ylabel('obs',fontsize = fontsiz)
# plt.xlabel('time',fontsize = fontsiz)
# plt.savefig(save_figure_path + save_figname_dataset + '_pred' + '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
# save_figure_path + save_figname_dataset + '_pred'
