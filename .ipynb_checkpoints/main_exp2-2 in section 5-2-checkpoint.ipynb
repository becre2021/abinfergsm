# %%
import argparse
import copy
import torch
import time
import numpy as np
np.set_printoptions(precision = 4)
import pickle

from datasets.dataset import _load_collection_real,_load_collection_syn
from models_utility.construct_models import _initialize_SMkernelhyp,_make_gpmodel
from utility.eval_metric import _evaluate_metric
import matplotlib.pyplot as plt

import random
from matplotlib import rc
rc('font', size=20)
rc('legend', fontsize=20)

# %%
import seaborn as sns
sns.set()
sns.set_style('white')
import matplotlib
plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')

current_palette = sns.color_palette(sns.hls_palette(8+1, l=.5, s=1.0))

sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %% [markdown]
# # dataset

# %%
device = True
datafilename_list = ['CO2','airline']

#filename = 'CO2'
filename = 'airline'

# %%
x_train, x_test, y_train, y_test = _load_collection_real(filename,cuda_option=device)
x_full = torch.cat([x_train,x_test],dim = 0)
y_full = torch.cat([y_train,y_test],dim = 0)

y_mean = y_full.mean()
y_train -= y_mean
y_test -= y_mean
y_full -= y_full.mean()
y_full = torch.cat([y_train,y_test],dim = 0)



random_seed = 1000
setting_dict = {}
setting_dict['random_seed'] = random_seed
setting_dict['input_dim'] = x_train.shape[1]




if filename in [ 'CO2']:
    print('C02 setting') 
    setting_dict['init_sample_num'] = 500    
    setting_dict['lr_hyp'] = 0.005 
    setting_dict['noise_err'] = .05*y_train.cpu().data.numpy().std()    
    setting_dict['Num_Q'] = 8
    setting_dict['num_sample_pt'] = 3
    setting_dict['iter'] = 4000
    setting_dict['weight_rate'] = .20  #allocation rate
    
    
elif filename in ['airline']:
    print('airline setting') 
    setting_dict['init_sample_num'] = 500    
    setting_dict['lr_hyp'] = 0.005
    setting_dict['noise_err'] = .05*y_train.cpu().data.numpy().std()
    setting_dict['Num_Q'] = 6
    setting_dict['num_sample_pt'] = 3
    setting_dict['iter'] = 4000
    setting_dict['weight_rate'] = .20 #allocation rate


else:
    pass


setting_dict['kl_option'] = True    #['True','False']
setting_dict['num_batch'] = 1
setting_dict['num_rep'] = 1
setting_dict['optimizer'] = 'Adam'
# Out:
# #loaded collection#
# airline setting

# %%
result_dict = {}
result_dict['Exp_setting'] = setting_dict
result_dict['Data_setting'] = {'x_train' : x_train.cpu().data.numpy(),
                               'y_train' : y_train.cpu().data.numpy(),
                               'x_test' : x_test.cpu().data.numpy(),
                               'y_test' : y_test.cpu().data.numpy()}

result_dict['loss'] = {}
result_dict['rmse'] = {}
result_dict['mnll'] = {}
result_dict['best_loss'] = {}
result_dict['best_rmse'] = {}
result_dict['best_mnll'] = {}

result_dict['pred_train_mu'] = {}
result_dict['pred_train_var'] = {}
result_dict['pred_test_mu'] = {}
result_dict['pred_test_var'] = {}
result_dict['param_history'] = {}
result_dict['error_history'] = {}

# %% [markdown]
# ### modelsetup

# %%
def save_model_param(temp_model):
    param_dict = {}
    for ith_name,ith_param in temp_model.named_parameters():
        param_dict[ith_name] = ith_param.data.clone()    
    if hasattr(temp_model,'likelihood'):
        param_dict['var_noise'] = temp_model.likelihood.variance.data.clone()     
    return param_dict


def load_model_param(temp_model,saved_param):
    for ith_name,ith_param in temp_model.named_parameters():
        ith_param.data = saved_param[ith_name]        
    if hasattr(temp_model,'likelihood'):
        temp_model.likelihood.variance.data = saved_param['var_noise']
    return temp_model

# %% [markdown]
# ### proposed

# %%
observed_period = 100

# %%
import torch.nn.utils as torch_utils
from scipy.linalg import norm as fnorm
from models_utility.personalized_adam import Adam_variation


def _train_model(ith_model_name,ith,setting_dict,num_spt1 ):
    setting_dict['num_sample_pt'] = num_spt1     
    if num_spt1 >= 2:
        # intializatoin part
        best_loss = np.inf
        for ith in range(10):    
            setting_dict = _initialize_SMkernelhyp(x_train, y_train, setting_dict, random_seed + ith ,yesSM= True, filename = filename)        

            temp_model = _make_gpmodel(model_name=ith_model_name, setting_dict=setting_dict, device=device)
            if ith_model_name in ['gpvfe', 'gpvferbf']:
                temp_model._set_data(batch_x=x_train, batch_y=y_train)        
                temp_model._set_inducing_pt(2 * setting_dict['Num_Q'] * setting_dict['num_sample_pt'])
                optimizable_param =  [*temp_model.parameters(),temp_model.likelihood.variance]
            elif ith_model_name in ['vssgp']:
                temp_model._set_data(batch_x=x_train, batch_y=y_train)                
                temp_model._set_inducing_pt( setting_dict['Num_Q'] * setting_dict['num_sample_pt'])
                optimizable_param =  [*temp_model.parameters()]
            else:
                temp_model._set_data(x_train, y_train)                            
                optimizable_param =  [*temp_model.parameters(),temp_model.likelihood.variance]

                
            temp_optimizer = torch.optim.Adam(optimizable_param ,
                                              lr=setting_dict['lr_hyp'],
                                              betas=(0.9, 0.99),
                                              eps=1e-08,
                                              weight_decay=0.0)    
            
                        

            for i in range(30 + 1):    
                temp_optimizer.zero_grad()    
                losstotal = temp_model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])
                losstotal.backward()
                temp_optimizer.step()

            # best model chosen
            if best_loss >= losstotal.cpu().data.numpy():
                best_loss = losstotal.cpu().data.numpy()        
                saved_param = save_model_param(temp_model)
                ith_model = load_model_param(temp_model,saved_param)
                optimizer = temp_optimizer
                
                print('%d init loss: %.4f '%(ith,losstotal.cpu().data.numpy()))
                print('%d model chosen '%(ith))
            else:
                pass



        param_history_list = []
        error_history_list1,error_history_list2 = [],[]
        loss_history_list,loss_history_list1,loss_history_list2 = [],[],[]
        rmse_history_list,rmse_history_list1,rmse_history_list2 = [],[],[]

        print('#'*100)
        print(ith_model_name)
        ith_model.train()
        for i in range(setting_dict['iter'] + 1):
            optimizer.zero_grad()

            ith_tic = time.time()
            losstotal = ith_model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])
            losstotal.backward()
            optimizer.step()
            ith_toc = time.time()

            with torch.no_grad():
                pred_train_mu, pred_train_var = ith_model._predict(inputs_new=x_train)
                pred_test_mu, pred_test_var = ith_model._predict(inputs_new=x_test)        
                ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)

            #print('\n')

            if i % observed_period == 0 :
                print('%d th loss0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,losstotal.cpu().data.numpy(),ith_rmse,ith_mnll))        
                #print('%d th loss0 : %.4f, reg0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,ith_loss.cpu().data.numpy(),ith_reg.cpu().data.numpy(),ith_rmse,ith_mnll))
                try:
                    print('self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance')            
                    print(ith_model.weight.exp().squeeze(),ith_model.mu.exp().squeeze(),ith_model.std.exp().squeeze(),ith_model.likelihood.variance.transform()**2)
                    print('self.num_samplept_list_at')
                    print(ith_model.num_samplept_list_at)
                    print('\n')
                except:
                    pass

                loss_history_list.append( losstotal.cpu().data.numpy().squeeze())
                rmse_history_list.append(ith_rmse.squeeze())



        return ith_model,loss_history_list,rmse_history_list
    else:
        return ith_model,loss_history_list,rmse_history_list

# %%
def _compare_reg_model(num_spt1,num_rep):
    rep_loss_history_list_e,rep_loss_history_list_w = [],[]
    rep_rmse_history_list_e,rep_rmse_history_list_w = [],[]
    rep_model_history_list_e,rep_model_history_list_w = [],[]

    for i in range(num_rep):
        model_w,loss_history_list_w,rmse_history_list_w =  _train_model('weight_reg',i,setting_dict,num_spt1=num_spt1)    
        model_e,loss_history_list_e,rmse_history_list_e =  _train_model('equal_reg',i,setting_dict,num_spt1=num_spt1)

        rep_loss_history_list_e.append(loss_history_list_e)
        rep_loss_history_list_w.append(loss_history_list_w)
        rep_rmse_history_list_e.append(rmse_history_list_e)
        rep_rmse_history_list_w.append(rmse_history_list_w)

        rep_model_history_list_e.append(model_e)
        rep_model_history_list_w.append(model_w)
        
    return rep_loss_history_list_e,rep_loss_history_list_w,\
           rep_rmse_history_list_e,rep_rmse_history_list_w,\
           rep_model_history_list_e,rep_model_history_list_w

# %%
num_rep,num_spt1 = 3,4

# %%
rep_loss_history_list_e,rep_loss_history_list_w,rep_rmse_history_list_e,rep_rmse_history_list_w,rep_model_history_list_e,rep_model_history_list_w =  _compare_reg_model(num_spt1,num_rep )
# Out:
# 0 init loss: 17866.7359
# 0 model chosen
# 1 init loss: 12949.4467
# 1 model chosen
# 4 init loss: 10943.7364
# 4 model chosen
# 8 init loss: 9371.1486
# 8 model chosen
# ####################################################################################################
# weight_reg
# 0 th loss0 : 16474.7993, test rmse : 172.2750, test mnll: : 704.8621
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1626, 1.1408, 1.1608, 1.1608, 1.1298, 1.1605], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2482, 0.0240, 0.0845, 0.0090, 0.4040, 0.1647], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0126, 0.0178, 0.0063, 0.0011, 0.0521, 0.0086], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([16.9564], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 5, 3, 2, 6, 4]
#
#
# 100 th loss0 : 6133.4582, test rmse : 110.2834, test mnll: : 168.5838
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6654, 1.5230, 1.7369, 1.8635, 1.4508, 1.7321], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2489, 0.0217, 0.0843, 0.0065, 0.3858, 0.1671], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0110, 0.0187, 0.0051, 0.0013, 0.0542, 0.0072], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([29.9558], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 5, 3, 2, 6, 4]
#
#
# 200 th loss0 : 3871.8548, test rmse : 101.2803, test mnll: : 100.0667
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2159, 1.8038, 2.4761, 2.8499, 1.7599, 2.4474], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2519, 0.0210, 0.0835, 0.0054, 0.3856, 0.1671], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0096, 0.0186, 0.0042, 0.0012, 0.0515, 0.0060], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([43.6325], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 4, 4, 3, 4, 4]
#
#
# 300 th loss0 : 2293.2372, test rmse : 105.0132, test mnll: : 79.6439
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.8698, 2.0758, 3.4718, 4.1867, 2.0004, 3.4160], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2473, 0.0205, 0.0833, 0.0047, 0.3768, 0.1672], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0083, 0.0184, 0.0035, 0.0011, 0.0495, 0.0051], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([60.9311], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 5, 3, 2, 6, 4]
#
#
# 400 th loss0 : 1762.7113, test rmse : 79.5253, test mnll: : 36.0526
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.7376, 2.3567, 4.7635, 6.0157, 2.2851, 4.7020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2491, 0.0200, 0.0830, 0.0044, 0.3571, 0.1677], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0073, 0.0182, 0.0031, 0.0010, 0.0478, 0.0043], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([83.5103], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 5, 3, 2, 6, 4]
#
#
# 500 th loss0 : 1480.8690, test rmse : 77.4630, test mnll: : 25.6485
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.7472, 2.6840, 6.5431, 8.4852, 2.5711, 6.4148], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2541, 0.0195, 0.0837, 0.0042, 0.3390, 0.1663], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0063, 0.0181, 0.0027, 0.0009, 0.0449, 0.0037], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([116.1253], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 5, 3, 2, 5, 4]
#
#
# 600 th loss0 : 1116.6864, test rmse : 80.5599, test mnll: : 20.6159
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 5.9301,  3.0246,  8.8315, 11.8872,  2.7349,  8.6707], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2494, 0.0192, 0.0837, 0.0041, 0.3385, 0.1676], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0059, 0.0180, 0.0024, 0.0008, 0.0413, 0.0033], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([163.8751], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 5, 3, 2, 5, 4]
#
#
# 700 th loss0 : 921.4004, test rmse : 81.5105, test mnll: : 16.1809
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.0904,  3.4444, 11.9199, 16.4252,  2.5384, 11.5947], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2502, 0.0189, 0.0832, 0.0041, 0.3325, 0.1672], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0055, 0.0179, 0.0022, 0.0007, 0.0368, 0.0030], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([234.4366], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 3, 5, 4, 3, 5]
#
#
# 800 th loss0 : 776.9745, test rmse : 79.7382, test mnll: : 12.3567
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.1386,  3.8530, 15.9737, 22.6007,  2.2316, 15.2451], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2509, 0.0185, 0.0839, 0.0041, 0.3423, 0.1667], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0058, 0.0180, 0.0020, 0.0006, 0.0323, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([339.2263], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 5, 4, 2, 4, 4]
#
#
# 900 th loss0 : 693.7101, test rmse : 82.9466, test mnll: : 10.4611
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.9173,  4.2746, 21.2371, 30.9579,  1.8988, 19.8595], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2550, 0.0181, 0.0840, 0.0040, 0.3386, 0.1675], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0072, 0.0181, 0.0019, 0.0006, 0.0286, 0.0028], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([486.0887], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 5, 4, 2, 3, 5]
#
#
# 1000 th loss0 : 635.5605, test rmse : 93.3066, test mnll: : 10.1499
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 6.0549,  4.7204, 28.1711, 42.3336,  1.5905, 25.5732], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2817, 0.0179, 0.0843, 0.0041, 0.3389, 0.1688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0111, 0.0180, 0.0018, 0.0005, 0.0258, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([670.8174], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [5, 5, 4, 2, 3, 5]
#
#
# 1100 th loss0 : 596.6449, test rmse : 81.0133, test mnll: : 7.8858
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 4.3844,  5.2636, 37.6746, 58.1267,  1.3253, 32.8456], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3251, 0.0177, 0.0844, 0.0041, 0.3393, 0.1674], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0173, 0.0181, 0.0018, 0.0005, 0.0237, 0.0030], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([846.1955], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 5, 2, 3, 6]
#
#
# 1200 th loss0 : 570.4822, test rmse : 75.5882, test mnll: : 7.3646
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 3.4026,  5.8577, 51.8238, 81.4650,  1.0685, 43.1085], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3302, 0.0174, 0.0842, 0.0040, 0.3398, 0.1666], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0252, 0.0184, 0.0018, 0.0005, 0.0226, 0.0032], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([868.5249], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 3, 6, 4, 2, 6]
#
#
# 1300 th loss0 : 538.5478, test rmse : 71.1467, test mnll: : 7.6316
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  2.4461,   6.7263,  75.8262, 118.0151,   0.8152,  60.8725],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3312, 0.0174, 0.0838, 0.0039, 0.3390, 0.1669], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0330, 0.0184, 0.0021, 0.0005, 0.0222, 0.0030], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([617.4410], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 4, 6, 3, 2, 6]
# 1400 th loss0 : 504.2257, test rmse : 54.0197, test mnll: : 7.4565
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.6687,   8.2710, 121.3881, 175.3270,   0.6161,  92.3468],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3316, 0.0174, 0.0826, 0.0036, 0.3412, 0.1670], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0355, 0.0183, 0.0028, 0.0004, 0.0217, 0.0028], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([317.2531], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 4, 7, 2, 2, 6]
#
#
# 1500 th loss0 : 471.3371, test rmse : 47.4518, test mnll: : 7.6509
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.1905,  12.3468, 191.6541, 258.4476,   0.5254, 135.8874],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3344, 0.0157, 0.0829, 0.0034, 0.3396, 0.1669], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0336, 0.0191, 0.0030, 0.0004, 0.0213, 0.0024], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([173.9613], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 4, 8, 2, 2, 6]
#
#
# 1600 th loss0 : 463.6285, test rmse : 46.9246, test mnll: : 7.9211
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.1872,  19.3884, 282.2230, 372.3028,   0.6115, 181.3166],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3402, 0.0168, 0.0829, 0.0033, 0.3491, 0.1673], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0292, 0.0175, 0.0029, 0.0003, 0.0193, 0.0022], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([138.4931], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 4, 8, 2, 2, 5]
#
#
# 1700 th loss0 : 446.0997, test rmse : 42.1779, test mnll: : 7.3210
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.1714,  28.5086, 385.6774, 525.5196,   0.7778, 213.5294],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3146, 0.0159, 0.0832, 0.0032, 0.3445, 0.1680], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0299, 0.0174, 0.0028, 0.0003, 0.0183, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([126.7940], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 4, 9, 2, 2, 5]
#
#
# 1800 th loss0 : 439.9027, test rmse : 43.0293, test mnll: : 7.4395
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.2127,  41.1719, 505.6354, 730.1935,   1.0581, 249.0412],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3164, 0.0152, 0.0832, 0.0032, 0.3359, 0.1688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0305, 0.0172, 0.0029, 0.0003, 0.0176, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([115.3005], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 4, 9, 2, 2, 4]
#
#
# 1900 th loss0 : 437.7265, test rmse : 43.1672, test mnll: : 7.2516
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([   1.2968,   55.8635,  626.8621, 1006.2593,    1.4077,  275.3357],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3309, 0.0146, 0.0834, 0.0031, 0.3516, 0.1702], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0325, 0.0164, 0.0028, 0.0003, 0.0150, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([113.9005], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 5, 9, 2, 2, 4]
#
#
# 2000 th loss0 : 433.9299, test rmse : 50.7028, test mnll: : 7.3488
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2897e+00, 6.9739e+01, 7.2967e+02, 1.3817e+03, 1.9020e+00, 2.6151e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3338, 0.0159, 0.0829, 0.0032, 0.3430, 0.1687], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0318, 0.0158, 0.0027, 0.0003, 0.0147, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([111.3579], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 4, 9, 3, 2, 4]
#
#
# 2100 th loss0 : 429.6681, test rmse : 53.0997, test mnll: : 7.6651
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3115e+00, 8.0152e+01, 8.2427e+02, 1.8970e+03, 2.4951e+00, 2.8397e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3296, 0.0161, 0.0835, 0.0031, 0.3397, 0.1668], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0312, 0.0149, 0.0025, 0.0004, 0.0135, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([110.6335], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 6, 2, 4]
#
#
# 2200 th loss0 : 428.4518, test rmse : 43.6501, test mnll: : 6.4759
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2886e+00, 9.1471e+01, 8.9830e+02, 2.5652e+03, 3.5711e+00, 2.9432e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3276, 0.0165, 0.0838, 0.0031, 0.3378, 0.1672], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0325, 0.0143, 0.0025, 0.0005, 0.0122, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([104.4688], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 5, 8, 3, 2, 4]
#
#
# 2300 th loss0 : 424.5686, test rmse : 43.3368, test mnll: : 5.8605
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2064e+00, 9.4557e+01, 9.1020e+02, 3.4310e+03, 4.8832e+00, 3.0484e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3331, 0.0160, 0.0837, 0.0029, 0.3301, 0.1697], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0298, 0.0134, 0.0026, 0.0005, 0.0103, 0.0022], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([95.5297], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 5, 8, 3, 2, 4]
#
#
# 2400 th loss0 : 425.1602, test rmse : 45.5079, test mnll: : 7.4107
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2624e+00, 9.4436e+01, 9.3111e+02, 4.6267e+03, 6.0132e+00, 3.4350e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3392, 0.0157, 0.0836, 0.0028, 0.3273, 0.1672], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0298, 0.0114, 0.0024, 0.0006, 0.0089, 0.0023], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([104.7500], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 4, 7, 4, 2, 4]
#
#
# 2500 th loss0 : 438.1797, test rmse : 48.9121, test mnll: : 6.4773
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2647e+00, 9.5370e+01, 1.0437e+03, 6.0196e+03, 7.8959e+00, 3.2083e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3317, 0.0171, 0.0834, 0.0029, 0.3313, 0.1679], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0301, 0.0102, 0.0024, 0.0007, 0.0077, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([97.7891], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 4, 8, 5, 2, 3]
#
#
# 2600 th loss0 : 422.7132, test rmse : 36.6866, test mnll: : 5.6521
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1365e+00, 8.8232e+01, 1.0690e+03, 7.7130e+03, 1.0826e+01, 3.5324e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3285, 0.0175, 0.0829, 0.0027, 0.3348, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0311, 0.0091, 0.0025, 0.0007, 0.0064, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([98.7092], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 2, 4, 11, 2, 3]
#
#
# 2700 th loss0 : 421.7998, test rmse : 49.7382, test mnll: : 6.0646
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.6792e-01, 8.6784e+01, 1.0893e+03, 9.3957e+03, 1.4481e+01, 3.7075e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3260, 0.0172, 0.0824, 0.0027, 0.3337, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0324, 0.0078, 0.0023, 0.0008, 0.0052, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([94.3028], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 3, 7, 6, 2, 3]
# 2800 th loss0 : 427.0217, test rmse : 40.1127, test mnll: : 5.4094
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.0156e-01, 8.2773e+01, 1.0608e+03, 1.0889e+04, 1.8318e+01, 3.8485e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3278, 0.0179, 0.0830, 0.0026, 0.3318, 0.1679], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0347, 0.0066, 0.0022, 0.0008, 0.0042, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([91.7231], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 2900 th loss0 : 425.0969, test rmse : 42.4408, test mnll: : 5.4814
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.6302e-01, 7.5928e+01, 1.1416e+03, 1.1434e+04, 2.1280e+01, 3.9975e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3416, 0.0186, 0.0834, 0.0025, 0.3313, 0.1684], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0354, 0.0060, 0.0022, 0.0008, 0.0034, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([91.9182], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 3000 th loss0 : 422.3837, test rmse : 49.7527, test mnll: : 5.6655
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.3614e-01, 7.1110e+01, 1.1903e+03, 1.1775e+04, 2.3609e+01, 4.1589e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3336, 0.0191, 0.0830, 0.0024, 0.3314, 0.1691], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0358, 0.0057, 0.0022, 0.0008, 0.0031, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([89.1803], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 6, 2, 4]
#
#
# 3100 th loss0 : 423.7979, test rmse : 34.9015, test mnll: : 5.4061
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.4143e-01, 7.1392e+01, 1.2023e+03, 1.2487e+04, 2.3697e+01, 4.0424e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3488, 0.0195, 0.0834, 0.0025, 0.3335, 0.1662], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0361, 0.0051, 0.0021, 0.0008, 0.0028, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([86.2723], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 2, 3, 12, 2, 3]
#
#
# 3200 th loss0 : 425.8034, test rmse : 33.4295, test mnll: : 5.1876
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.3808e-01, 6.5222e+01, 1.2175e+03, 1.2700e+04, 2.4254e+01, 3.9935e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3325, 0.0192, 0.0825, 0.0025, 0.3350, 0.1675], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0357, 0.0047, 0.0020, 0.0008, 0.0026, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([90.0514], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 2, 7, 7, 2, 4]
#
#
# 3300 th loss0 : 427.9950, test rmse : 39.1272, test mnll: : 6.0925
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.8820e-01, 6.2824e+01, 1.2186e+03, 1.2105e+04, 2.3536e+01, 3.9834e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3337, 0.0191, 0.0830, 0.0024, 0.3343, 0.1665], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0361, 0.0048, 0.0021, 0.0008, 0.0024, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([89.1235], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 3400 th loss0 : 421.6189, test rmse : 43.0982, test mnll: : 6.6628
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.6974e-01, 6.2354e+01, 1.2535e+03, 1.1889e+04, 2.3486e+01, 4.1566e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3244, 0.0199, 0.0821, 0.0025, 0.3309, 0.1672], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0391, 0.0046, 0.0021, 0.0007, 0.0023, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([90.6217], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 6, 2, 4]
#
#
# 3500 th loss0 : 422.0160, test rmse : 42.6338, test mnll: : 6.2111
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2822e-01, 6.3505e+01, 1.2550e+03, 1.2403e+04, 2.3951e+01, 3.8333e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3329, 0.0190, 0.0815, 0.0024, 0.3320, 0.1677], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0375, 0.0044, 0.0021, 0.0007, 0.0022, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([87.8584], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 3600 th loss0 : 421.2575, test rmse : 40.5074, test mnll: : 5.5767
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8683e-01, 6.4976e+01, 1.2793e+03, 1.2078e+04, 2.4944e+01, 3.8096e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3283, 0.0193, 0.0835, 0.0025, 0.3344, 0.1684], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0367, 0.0045, 0.0021, 0.0007, 0.0023, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([87.9107], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 2, 4, 11, 2, 3]
#
#
# 3700 th loss0 : 425.3141, test rmse : 47.0391, test mnll: : 5.6334
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5880e-01, 6.3132e+01, 1.1949e+03, 1.2407e+04, 2.4284e+01, 3.9950e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3303, 0.0185, 0.0836, 0.0025, 0.3323, 0.1686], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0362, 0.0043, 0.0021, 0.0007, 0.0023, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([87.0601], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 2, 7, 7, 2, 4]
#
#
# 3800 th loss0 : 420.8307, test rmse : 47.3502, test mnll: : 6.2754
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3070e-01, 6.6120e+01, 1.2477e+03, 1.2547e+04, 2.3489e+01, 4.0315e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3304, 0.0191, 0.0828, 0.0025, 0.3323, 0.1689], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0366, 0.0040, 0.0022, 0.0008, 0.0023, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([86.3118], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 3900 th loss0 : 426.1706, test rmse : 33.8183, test mnll: : 5.3731
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1094e-01, 6.4765e+01, 1.2224e+03, 1.1814e+04, 2.3278e+01, 3.7835e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3312, 0.0203, 0.0833, 0.0025, 0.3314, 0.1667], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0360, 0.0040, 0.0021, 0.0008, 0.0023, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([88.3598], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [2, 3, 7, 7, 2, 3]
#
#
# 4000 th loss0 : 421.7583, test rmse : 38.4283, test mnll: : 5.5231
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.4612e-02, 6.6067e+01, 1.2648e+03, 1.2000e+04, 2.3720e+01, 3.8594e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3316, 0.0200, 0.0828, 0.0024, 0.3318, 0.1684], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0351, 0.0047, 0.0021, 0.0007, 0.0023, 0.0018], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([88.5536], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [3, 3, 7, 6, 2, 3]
#
#
# 0 init loss: 16410.9009
# 0 model chosen
# 1 init loss: 14028.0974
# 1 model chosen
# 6 init loss: 12232.0949
# 6 model chosen
# 8 init loss: 8493.9828
# 8 model chosen
# ####################################################################################################
# equal_reg
# 0 th loss0 : 17863.6381, test rmse : 171.7691, test mnll: : 728.7063
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1411, 1.1480, 1.1622, 1.1642, 1.1160, 1.1706], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2417, 0.0248, 0.0832, 0.0090, 0.3681, 0.1688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0124, 0.0176, 0.0064, 0.0011, 0.0548, 0.0080], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([16.7403], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 100 th loss0 : 5040.7559, test rmse : 135.8475, test mnll: : 263.6404
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6513, 1.5489, 1.7432, 1.8477, 1.4602, 1.7835], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2500, 0.0227, 0.0839, 0.0065, 0.3495, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0118, 0.0182, 0.0049, 0.0014, 0.0592, 0.0066], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([29.1085], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 200 th loss0 : 3028.4841, test rmse : 91.8219, test mnll: : 86.4599
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2422, 1.8739, 2.4837, 2.8020, 1.7252, 2.5485], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2512, 0.0213, 0.0831, 0.0054, 0.3374, 0.1676], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0105, 0.0185, 0.0040, 0.0014, 0.0606, 0.0053], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([42.0601], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 300 th loss0 : 2665.7323, test rmse : 105.0678, test mnll: : 81.9145
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.9241, 2.1644, 3.4900, 4.1244, 1.9803, 3.5751], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2530, 0.0207, 0.0836, 0.0048, 0.3374, 0.1674], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0091, 0.0185, 0.0034, 0.0013, 0.0588, 0.0044], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([57.8468], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 400 th loss0 : 1903.4135, test rmse : 92.4464, test mnll: : 48.3763
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.8168, 2.4590, 4.8112, 5.9319, 2.2726, 4.9148], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2486, 0.0203, 0.0839, 0.0044, 0.3262, 0.1676], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0082, 0.0185, 0.0029, 0.0011, 0.0554, 0.0037], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([80.2193], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 500 th loss0 : 1397.3146, test rmse : 78.5439, test mnll: : 27.5872
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.8744, 2.7796, 6.5423, 8.3638, 2.4300, 6.6735], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2473, 0.0198, 0.0839, 0.0043, 0.3335, 0.1679], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0073, 0.0184, 0.0026, 0.0010, 0.0513, 0.0033], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([112.4198], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 600 th loss0 : 1093.0686, test rmse : 94.2339, test mnll: : 27.0902
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 5.9706,  3.1161,  8.8366, 11.6896,  2.4139,  8.9945], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2513, 0.0195, 0.0834, 0.0042, 0.3377, 0.1674], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0065, 0.0183, 0.0023, 0.0009, 0.0470, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([161.5571], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 700 th loss0 : 912.1654, test rmse : 90.3905, test mnll: : 19.1761
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.1275,  3.4811, 11.8026, 16.1471,  2.2679, 11.8782], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2535, 0.0190, 0.0835, 0.0041, 0.3349, 0.1666], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0061, 0.0183, 0.0021, 0.0008, 0.0418, 0.0027], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([234.8973], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 800 th loss0 : 772.1771, test rmse : 83.7558, test mnll: : 13.1541
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.0098,  3.9033, 15.6509, 22.0966,  1.9833, 15.5388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2538, 0.0186, 0.0832, 0.0041, 0.3384, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0065, 0.0182, 0.0019, 0.0007, 0.0366, 0.0026], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([344.9068], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 900 th loss0 : 698.8132, test rmse : 85.4043, test mnll: : 10.6233
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.5500,  4.3173, 20.6167, 30.1158,  1.7052, 20.0836], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2590, 0.0184, 0.0841, 0.0041, 0.3410, 0.1670], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0082, 0.0182, 0.0018, 0.0007, 0.0319, 0.0026], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([505.4529], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1000 th loss0 : 636.8393, test rmse : 85.2280, test mnll: : 8.9516
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 5.5956,  4.7785, 27.1074, 40.8826,  1.4465, 25.5944], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2901, 0.0182, 0.0839, 0.0041, 0.3387, 0.1674], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0123, 0.0181, 0.0017, 0.0006, 0.0280, 0.0027], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([714.4199], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1100 th loss0 : 602.0583, test rmse : 80.6060, test mnll: : 7.6298
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 4.1910,  5.2504, 35.7890, 55.8227,  1.2113, 32.3023], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3250, 0.0181, 0.0831, 0.0041, 0.3393, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0182, 0.0180, 0.0017, 0.0006, 0.0251, 0.0030], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([925.1898], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1200 th loss0 : 573.8907, test rmse : 76.1724, test mnll: : 7.1301
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 3.2868,  5.7775, 48.6201, 77.7872,  0.9942, 41.4563], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3281, 0.0182, 0.0835, 0.0040, 0.3401, 0.1664], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0261, 0.0182, 0.0017, 0.0005, 0.0233, 0.0034], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([979.6277], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1300 th loss0 : 547.7289, test rmse : 70.2175, test mnll: : 7.2372
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  2.4179,   6.5232,  70.2718, 112.4980,   0.7667,  57.3544],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3338, 0.0181, 0.0840, 0.0039, 0.3389, 0.1692], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0334, 0.0184, 0.0018, 0.0005, 0.0224, 0.0035], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([719.1689], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1400 th loss0 : 510.8544, test rmse : 58.2639, test mnll: : 7.7090
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.6458,   7.9015, 111.7438, 167.8934,   0.5624,  88.4172],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3303, 0.0177, 0.0837, 0.0037, 0.3387, 0.1696], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0351, 0.0188, 0.0022, 0.0004, 0.0220, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([367.0353], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1500 th loss0 : 477.4127, test rmse : 56.7010, test mnll: : 9.2914
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.2710,  11.4237, 184.0149, 248.9584,   0.4382, 135.6607],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3331, 0.0179, 0.0822, 0.0033, 0.3455, 0.1663], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0345, 0.0173, 0.0027, 0.0004, 0.0215, 0.0026], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([197.8931], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1600 th loss0 : 466.6721, test rmse : 49.5593, test mnll: : 8.7832
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.0898,  18.0047, 283.0893, 360.4174,   0.5782, 181.9650],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3224, 0.0179, 0.0829, 0.0032, 0.3348, 0.1693], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0339, 0.0156, 0.0028, 0.0004, 0.0203, 0.0025], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([153.3676], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1700 th loss0 : 463.5745, test rmse : 57.4509, test mnll: : 11.1825
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.1791,  27.9859, 401.6169, 509.9771,   0.8617, 213.8298],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3280, 0.0164, 0.0826, 0.0031, 0.3290, 0.1673], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0329, 0.0130, 0.0027, 0.0004, 0.0192, 0.0022], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([135.1773], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1800 th loss0 : 447.1991, test rmse : 49.4193, test mnll: : 9.5904
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.2945,  41.4914, 547.6422, 710.6301,   1.3274, 254.7673],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3355, 0.0168, 0.0830, 0.0032, 0.3365, 0.1687], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0369, 0.0105, 0.0026, 0.0004, 0.0160, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([118.8235], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1900 th loss0 : 433.0100, test rmse : 46.2210, test mnll: : 6.9989
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  1.3747,  55.9801, 706.5144, 981.9918,   2.0552, 255.8387],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3251, 0.0167, 0.0832, 0.0031, 0.3331, 0.1684], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0341, 0.0085, 0.0025, 0.0004, 0.0136, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([113.2700], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2000 th loss0 : 431.1940, test rmse : 50.5414, test mnll: : 7.3986
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([   1.3847,   67.8709,  888.1377, 1339.2499,    3.4932,  295.5765],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3328, 0.0178, 0.0824, 0.0031, 0.3306, 0.1678], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0333, 0.0075, 0.0024, 0.0005, 0.0106, 0.0021], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([103.0137], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2100 th loss0 : 429.7559, test rmse : 46.2698, test mnll: : 7.9609
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2754e+00, 7.5153e+01, 1.0254e+03, 1.8311e+03, 5.4269e+00, 3.0346e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3423, 0.0183, 0.0824, 0.0031, 0.3310, 0.1681], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0346, 0.0066, 0.0024, 0.0005, 0.0090, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([99.9018], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2200 th loss0 : 424.7997, test rmse : 39.9759, test mnll: : 5.7761
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0596e+00, 7.4948e+01, 1.2178e+03, 2.4684e+03, 8.9596e+00, 3.1499e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3399, 0.0191, 0.0827, 0.0029, 0.3337, 0.1671], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0335, 0.0068, 0.0022, 0.0006, 0.0063, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([93.0852], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2300 th loss0 : 420.5638, test rmse : 51.6200, test mnll: : 7.4279
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.2946e-01, 6.9546e+01, 1.3484e+03, 3.3350e+03, 1.3275e+01, 3.5176e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3327, 0.0206, 0.0831, 0.0030, 0.3324, 0.1684], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0361, 0.0066, 0.0022, 0.0006, 0.0047, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([91.3753], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2400 th loss0 : 431.1365, test rmse : 45.0931, test mnll: : 7.0988
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.3725e-01, 7.1589e+01, 1.5080e+03, 4.4214e+03, 1.7352e+01, 3.6755e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3345, 0.0201, 0.0826, 0.0028, 0.3328, 0.1688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0349, 0.0063, 0.0022, 0.0006, 0.0041, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([86.7639], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2500 th loss0 : 423.1902, test rmse : 48.5730, test mnll: : 6.3382
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.7404e-01, 6.9161e+01, 1.5597e+03, 5.7718e+03, 2.0551e+01, 3.5594e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3284, 0.0197, 0.0827, 0.0028, 0.3314, 0.1658], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0365, 0.0060, 0.0021, 0.0006, 0.0035, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([86.2008], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2600 th loss0 : 424.7418, test rmse : 40.9176, test mnll: : 5.9428
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.7092e-01, 6.3578e+01, 1.4749e+03, 7.2144e+03, 2.1830e+01, 3.5013e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3322, 0.0205, 0.0834, 0.0027, 0.3355, 0.1675], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0370, 0.0060, 0.0020, 0.0007, 0.0032, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([83.6480], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2700 th loss0 : 421.2426, test rmse : 44.7110, test mnll: : 5.6655
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.9091e-01, 6.8161e+01, 1.6022e+03, 8.8878e+03, 2.1790e+01, 3.2596e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3248, 0.0205, 0.0829, 0.0026, 0.3342, 0.1676], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0375, 0.0059, 0.0021, 0.0006, 0.0028, 0.0018], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([84.1867], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2800 th loss0 : 419.6068, test rmse : 42.6464, test mnll: : 5.1742
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.4220e-01, 6.4007e+01, 1.6523e+03, 1.0348e+04, 2.2938e+01, 3.4677e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3297, 0.0202, 0.0822, 0.0026, 0.3343, 0.1681], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0376, 0.0056, 0.0023, 0.0007, 0.0027, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([83.0858], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2900 th loss0 : 420.4982, test rmse : 44.3637, test mnll: : 5.6031
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8935e-01, 6.3100e+01, 1.6929e+03, 1.1508e+04, 2.2803e+01, 3.4404e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3336, 0.0202, 0.0825, 0.0026, 0.3292, 0.1689], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0374, 0.0053, 0.0022, 0.0007, 0.0028, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([84.9433], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3000 th loss0 : 425.3022, test rmse : 48.9030, test mnll: : 6.6226
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5043e-01, 6.0974e+01, 1.5956e+03, 1.2050e+04, 2.4037e+01, 3.5834e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3328, 0.0200, 0.0834, 0.0026, 0.3300, 0.1677], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0364, 0.0054, 0.0021, 0.0007, 0.0030, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([85.5859], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3100 th loss0 : 422.6137, test rmse : 34.4931, test mnll: : 5.6018
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1451e-01, 6.1742e+01, 1.5514e+03, 1.2201e+04, 2.2648e+01, 3.5481e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3307, 0.0194, 0.0822, 0.0025, 0.3329, 0.1683], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0369, 0.0056, 0.0020, 0.0006, 0.0030, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([85.6713], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3200 th loss0 : 419.4646, test rmse : 40.1735, test mnll: : 6.1898
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.4252e-02, 6.1587e+01, 1.6412e+03, 1.2517e+04, 2.2015e+01, 3.3175e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3299, 0.0202, 0.0828, 0.0026, 0.3319, 0.1677], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0372, 0.0058, 0.0021, 0.0007, 0.0027, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([85.3728], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3300 th loss0 : 425.6712, test rmse : 31.6769, test mnll: : 5.5425
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.6416e-02, 6.4349e+01, 1.6219e+03, 1.2160e+04, 2.5351e+01, 3.4007e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3298, 0.0194, 0.0822, 0.0025, 0.3336, 0.1688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0362, 0.0059, 0.0022, 0.0006, 0.0031, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([85.9400], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3400 th loss0 : 420.7168, test rmse : 36.3634, test mnll: : 4.9406
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.0102e-02, 6.2912e+01, 1.7228e+03, 1.2757e+04, 2.2624e+01, 3.1466e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3313, 0.0205, 0.0818, 0.0026, 0.3318, 0.1676], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0366, 0.0057, 0.0021, 0.0007, 0.0028, 0.0018], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([86.6616], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3500 th loss0 : 422.7772, test rmse : 39.0556, test mnll: : 6.9716
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.9613e-02, 6.1861e+01, 1.6974e+03, 1.1713e+04, 2.2772e+01, 3.1824e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3294, 0.0214, 0.0824, 0.0025, 0.3326, 0.1668], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0362, 0.0055, 0.0019, 0.0006, 0.0027, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([83.6733], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3600 th loss0 : 421.2715, test rmse : 38.7738, test mnll: : 7.5923
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.1104e-02, 6.1180e+01, 1.7081e+03, 1.1991e+04, 2.2737e+01, 3.2656e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3306, 0.0208, 0.0828, 0.0025, 0.3305, 0.1683], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0358, 0.0054, 0.0019, 0.0006, 0.0027, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([85.4949], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3700 th loss0 : 419.9592, test rmse : 38.1495, test mnll: : 5.1299
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.1280e-02, 6.3252e+01, 1.7217e+03, 1.1951e+04, 2.1754e+01, 3.4186e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3309, 0.0208, 0.0826, 0.0025, 0.3337, 0.1695], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0366, 0.0053, 0.0019, 0.0006, 0.0026, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([84.8711], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3800 th loss0 : 427.2854, test rmse : 58.0137, test mnll: : 6.0992
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.5342e-02, 6.0518e+01, 1.7320e+03, 1.1818e+04, 2.3991e+01, 3.3711e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3296, 0.0201, 0.0841, 0.0025, 0.3319, 0.1675], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0356, 0.0053, 0.0020, 0.0006, 0.0028, 0.0020], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([83.7091], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3900 th loss0 : 420.4077, test rmse : 52.1411, test mnll: : 6.1938
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.0586e-02, 6.0603e+01, 1.6836e+03, 1.1474e+04, 2.2551e+01, 3.3539e+02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3296, 0.0208, 0.0838, 0.0025, 0.3338, 0.1682], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0364, 0.0055, 0.0019, 0.0006, 0.0026, 0.0019], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([84.1158], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 4000 th loss0 : 424.5424, test rmse : 41.5191, test mnll: : 6.7944
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6816e-02, 6.2485e+01, 1.7801e+03, 1.2180e+04, 2.4548e+01, 3.1592e+02],
# ...
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1400 th loss0 : 614.4197, test rmse : 148.0377, test mnll: : 6.7619
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([15.5870,  2.7535,  4.4527,  0.5063,  5.3945,  2.4304], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0042, 0.1379, 0.2173, 0.3690, 0.3042, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0032, 0.0890, 0.0044, 0.0834, 0.0366, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([8162.5050], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1500 th loss0 : 613.2467, test rmse : 150.4105, test mnll: : 6.7964
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([18.7185,  3.0111,  4.3301,  0.4177,  4.8381,  1.9825], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0042, 0.1236, 0.2173, 0.3689, 0.3041, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0033, 0.0925, 0.0044, 0.0834, 0.0479, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([8242.3029], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1600 th loss0 : 612.3159, test rmse : 146.0140, test mnll: : 6.7636
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([25.9378,  3.2688,  4.1382,  0.3288,  4.1456,  1.5472], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0041, 0.1190, 0.2173, 0.3689, 0.3042, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0033, 0.0878, 0.0044, 0.0834, 0.0517, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7789.5985], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1700 th loss0 : 606.5799, test rmse : 150.1221, test mnll: : 7.0337
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([45.1141,  3.7170,  3.8298,  0.2455,  3.3268,  1.1470], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.1239, 0.2173, 0.3689, 0.3041, 0.3188], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.0813, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([6489.3400], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1800 th loss0 : 590.8671, test rmse : 126.2669, test mnll: : 7.1873
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([93.6027,  4.1348,  3.2728,  0.1676,  2.3866,  0.7793], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0040, 0.1158, 0.2173, 0.3689, 0.3044, 0.3190], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0847, 0.0044, 0.0834, 0.0515, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([3613.8596], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 1900 th loss0 : 555.5690, test rmse : 86.6188, test mnll: : 7.1677
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.9131e+02, 4.5549e+00, 2.2536e+00, 9.7404e-02, 1.4378e+00, 4.5479e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0040, 0.1112, 0.2173, 0.3687, 0.3042, 0.3194], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0014, 0.0863, 0.0044, 0.0836, 0.0515, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1362.6276], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2000 th loss0 : 539.4956, test rmse : 103.5013, test mnll: : 8.9246
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.2127e+02, 7.0724e+00, 1.3874e+00, 5.8362e-02, 8.5593e-01, 2.7156e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0038, 0.1148, 0.2172, 0.3688, 0.3055, 0.3184], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0011, 0.0898, 0.0044, 0.0830, 0.0525, 0.0301], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1029.4325], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2100 th loss0 : 531.0307, test rmse : 77.2725, test mnll: : 7.3241
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.8335e+02, 9.0921e+00, 9.2548e-01, 3.8791e-02, 5.7506e-01, 1.8282e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0036, 0.1083, 0.2173, 0.3692, 0.3057, 0.3186], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0009, 0.0988, 0.0044, 0.0838, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([956.7886], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2200 th loss0 : 524.0698, test rmse : 85.5681, test mnll: : 7.7066
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.9621e+02, 1.0759e+01, 6.4299e-01, 2.7176e-02, 4.0211e-01, 1.2801e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0035, 0.1187, 0.2172, 0.3687, 0.3050, 0.3192], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0008, 0.0973, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([926.0900], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2300 th loss0 : 520.8094, test rmse : 72.8835, test mnll: : 7.0872
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.8056e+02, 1.2523e+01, 4.5623e-01, 1.9429e-02, 2.8566e-01, 9.0962e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0034, 0.1132, 0.2173, 0.3694, 0.3044, 0.3190], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0932, 0.0044, 0.0836, 0.0515, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([926.3916], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2400 th loss0 : 514.4806, test rmse : 86.2435, test mnll: : 7.6375
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3641e+03, 1.5326e+01, 3.2696e-01, 1.4041e-02, 2.0576e-01, 6.5579e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0032, 0.1241, 0.2173, 0.3688, 0.3030, 0.3186], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0813, 0.0044, 0.0835, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([889.9999], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2500 th loss0 : 511.6891, test rmse : 79.2581, test mnll: : 7.2078
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8774e+03, 1.9247e+01, 2.3511e-01, 1.0021e-02, 1.5089e-01, 4.7593e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0031, 0.1236, 0.2173, 0.3688, 0.3037, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0788, 0.0044, 0.0834, 0.0517, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([871.7614], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2600 th loss0 : 514.8473, test rmse : 74.9771, test mnll: : 7.0282
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.5707e+03, 2.2377e+01, 1.7060e-01, 7.2913e-03, 1.1007e-01, 3.4632e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.1133, 0.2173, 0.3688, 0.3046, 0.3188], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0779, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([879.4479], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2700 th loss0 : 514.9463, test rmse : 73.9179, test mnll: : 6.9686
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.4714e+03, 2.8191e+01, 1.2347e-01, 5.3022e-03, 8.0904e-02, 2.5269e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.1016, 0.2172, 0.3690, 0.3043, 0.3191], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0812, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([840.0054], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2800 th loss0 : 506.0541, test rmse : 73.7367, test mnll: : 6.8960
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.6228e+03, 3.5670e+01, 8.9503e-02, 3.8232e-03, 5.9763e-02, 1.8326e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0029, 0.1090, 0.2173, 0.3690, 0.3035, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0824, 0.0044, 0.0835, 0.0521, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([879.3941], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 2900 th loss0 : 504.2726, test rmse : 75.1248, test mnll: : 6.7812
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9828e+03, 4.3176e+01, 6.4997e-02, 2.8150e-03, 4.4191e-02, 1.3386e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.1040, 0.2173, 0.3690, 0.3037, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0756, 0.0044, 0.0834, 0.0522, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([831.9554], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3000 th loss0 : 506.5609, test rmse : 73.8655, test mnll: : 7.0508
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.6569e+03, 5.1412e+01, 4.7353e-02, 2.0849e-03, 3.2549e-02, 9.7341e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.1069, 0.2173, 0.3690, 0.3043, 0.3188], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0704, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([815.3706], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3100 th loss0 : 513.5409, test rmse : 70.0551, test mnll: : 6.5126
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.1700e+03, 5.8960e+01, 3.4521e-02, 1.5175e-03, 2.3831e-02, 7.1903e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.1040, 0.2172, 0.3690, 0.3041, 0.3188], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0727, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([804.9186], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3200 th loss0 : 511.7896, test rmse : 71.7805, test mnll: : 6.7249
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0596e+04, 6.8610e+01, 2.5105e-02, 1.1269e-03, 1.7556e-02, 5.1857e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.1062, 0.2172, 0.3688, 0.3045, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0698, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([762.2923], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3300 th loss0 : 506.7350, test rmse : 75.8165, test mnll: : 6.6232
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1409e+04, 7.6491e+01, 1.8261e-02, 8.2489e-04, 1.2762e-02, 3.8105e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.0995, 0.2172, 0.3690, 0.3040, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0646, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([806.7989], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3400 th loss0 : 507.3707, test rmse : 66.4216, test mnll: : 6.6019
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1759e+04, 8.9866e+01, 1.3217e-02, 6.0073e-04, 9.4582e-03, 2.7657e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0971, 0.2173, 0.3690, 0.3042, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0622, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([748.7424], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3500 th loss0 : 516.1975, test rmse : 72.5691, test mnll: : 6.7710
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1482e+04, 9.6962e+01, 9.6079e-03, 4.3670e-04, 6.9275e-03, 2.0220e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0913, 0.2173, 0.3690, 0.3041, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0597, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([796.7302], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3600 th loss0 : 515.7045, test rmse : 76.0047, test mnll: : 6.7378
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2196e+04, 1.0762e+02, 6.9734e-03, 3.2218e-04, 5.0426e-03, 1.4810e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.0807, 0.2172, 0.3690, 0.3040, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0538, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([808.0476], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3700 th loss0 : 493.2072, test rmse : 72.6114, test mnll: : 6.3621
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1469e+04, 1.1994e+02, 5.0675e-03, 2.3827e-04, 3.7183e-03, 1.0852e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0796, 0.2173, 0.3689, 0.3042, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0499, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([756.7793], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3800 th loss0 : 514.2995, test rmse : 77.1000, test mnll: : 6.5793
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1534e+04, 1.2697e+02, 3.6774e-03, 1.7313e-04, 2.7340e-03, 7.9608e-04],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0864, 0.2172, 0.3689, 0.3043, 0.3188], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0476, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([811.2556], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 3900 th loss0 : 518.9920, test rmse : 70.8561, test mnll: : 6.6522
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1579e+04, 1.3056e+02, 2.6930e-03, 1.2857e-04, 2.0208e-03, 5.8691e-04],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0888, 0.2173, 0.3689, 0.3040, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0478, 0.0044, 0.0834, 0.0519, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([784.3627], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
#
#
# 4000 th loss0 : 516.3934, test rmse : 75.0825, test mnll: : 6.7617
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1771e+04, 1.4644e+02, 1.9495e-03, 9.3556e-05, 1.4749e-03, 4.2905e-04],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0827, 0.2173, 0.3690, 0.3041, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0460, 0.0044, 0.0834, 0.0518, 0.0300], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([756.1991], device='cuda:0', grad_fn=<PowBackward0>)
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]

# %% [markdown]
# ### summary

# %%
wl_mean1,wl_std1 = np.asarray(rep_loss_history_list_w).mean(axis = 0).round(3), np.asarray(rep_loss_history_list_w).std(axis = 0).round(3)
el_mean1,el_std1 = np.asarray(rep_loss_history_list_e).mean(axis = 0).round(3), np.asarray(rep_loss_history_list_e).std(axis = 0).round(3)


wr_mean1,wr_std1 = np.asarray(rep_rmse_history_list_w).mean(axis = 0).round(3), np.asarray(rep_rmse_history_list_w).std(axis = 0).round(3)
er_mean1,er_std1 = np.asarray(rep_rmse_history_list_e).mean(axis = 0).round(3), np.asarray(rep_rmse_history_list_e).std(axis = 0).round(3)

# %%
import seaborn as sns
sns.set()
sns.set_style('white')
#sns.set_style('whitegrid')
import matplotlib
plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.cal'] = 'stix:italic'

# %%
figsiz = (7,5)

# %%
current_palette = sns.color_palette(sns.hls_palette(15+1, l=.5, s=1.0))
sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %%
figsiz = (7,5)
markersiz = 8
#figsiz = (5,3.5)

# %% [markdown]
# ### loss

# %%
save_figname = filename + '_loss'+ '_Q'+str(setting_dict['Num_Q']) + '_spt' + str(num_spt1) + '_esti'
save_figname
# Out:
# 'airline_loss_Q6_spt4_esti'

# %%
idx = observed_period*np.arange(len(wl_mean1))

plt.figure(figsize = figsiz)

idxh = 0
plt.plot(idx, wl_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'SVSS Ws M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  wl_mean1 - wl_std1,
                  wl_mean1 + wl_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])



idxh = 9
plt.plot(idx,el_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'SVSS' '       M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  el_mean1 - el_std1,
                  el_mean1 + el_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])



plt.xlabel('iteration',fontsize = 20)
plt.ylabel('loss',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)
plt.ticklabel_format(axis='x',style='sci',scilimits=(0,0))
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))



#plt.ylim([.40*1e3,0.99*1e3]) #airline #M=6x4
plt.ylim([.32*1e3,3.55*1e3]) #airline  #M=8x3





leg = plt.legend(loc='best', fontsize = 17.5)

for line in leg.get_lines():
    line.set_linewidth(3) 
plt.gca().yaxis.get_offset_text().set_size(17)
plt.gca().xaxis.get_offset_text().set_size(15)

plt.show()

# %% [markdown]
# ### rmse

# %%
idx = observed_period*np.arange(len(wl_mean1))
plt.figure(figsize = figsiz)

idxh = 0
plt.plot(idx,wr_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'weight M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  wr_mean1 - wr_std1,
                  wr_mean1 + wr_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])




idxh = 9
plt.plot(idx,er_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'equal M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  er_mean1 - er_std1,
                  er_mean1 + er_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])





plt.xlabel('iteration',fontsize = 20)
plt.ylabel('rmse',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=10)
plt.locator_params(axis='x', nbins=6)
plt.ticklabel_format(axis='x',style='sci',scilimits=(0,0))
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.gca().yaxis.get_offset_text().set_size(17)
plt.gca().xaxis.get_offset_text().set_size(17)

#plt.ylim([30,100]) #M=6x4
#plt.ylim([30,160]) #M=8x3

plt.show()

# %% [markdown]
# # set model number

# %%
idx = 0

# %% [markdown]
# # weight sampling

# %%
ith_model = rep_model_history_list_w[idx]
with torch.no_grad():
#     pred_train_mu, pred_train_var = ith_model._predict(inputs_new=x_train)
#     pred_test_mu, pred_test_var = ith_model._predict(inputs_new=x_test)
    
    pred_train_mu, pred_train_var = ith_model._predict_exact(inputs_new=x_train)
    pred_test_mu, pred_test_var = ith_model._predict_exact(inputs_new=x_test)

# %%
figsiz = (7,5)

ith = 7
plt.figure(figsize = figsiz)


plt.plot(x_train.cpu().data.numpy().squeeze(),y_train.cpu().data.numpy().squeeze(),'r.',markersize = 8, label='train')
plt.plot(x_test.cpu().data.numpy().squeeze(),y_test.cpu().data.numpy().squeeze(),'b.',markersize = 8, label='test')

plt.plot(x_train.cpu().data.numpy().squeeze(),pred_train_mu.cpu().data.numpy().squeeze(),'k',linewidth = 2, label='pred mu')

plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() + 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() - 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith], label='pred std')

plt.plot(x_test.cpu().data.numpy().squeeze(),pred_test_mu.cpu().data.numpy().squeeze() ,'k',linewidth = 2)
plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() + 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() - 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith])



plt.xlabel('x',fontsize = 20)
plt.ylabel('y',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=8)
plt.locator_params(axis='x', nbins=6)



leg = plt.legend(loc='best', fontsize = 15)
for line in leg.get_lines():
    line.set_linewidth(4) 
    line.set_markersize(4) 

plt.show()

# %% [markdown]
# # equal sampling

# %%
ith_model = rep_model_history_list_e[idx]
with torch.no_grad():
#     pred_train_mu, pred_train_var = ith_model._predict(inputs_new=x_train)
#     pred_test_mu, pred_test_var = ith_model._predict(inputs_new=x_test)
    
    pred_train_mu, pred_train_var = ith_model._predict_exact(inputs_new=x_train)
    pred_test_mu, pred_test_var = ith_model._predict_exact(inputs_new=x_test)

# %%
figsiz = (7,5)

ith = 7
plt.figure(figsize = figsiz)


plt.plot(x_train.cpu().data.numpy().squeeze(),y_train.cpu().data.numpy().squeeze(),'r.',markersize = 8, label='train')
plt.plot(x_test.cpu().data.numpy().squeeze(),y_test.cpu().data.numpy().squeeze(),'b.',markersize = 8, label='test')

plt.plot(x_train.cpu().data.numpy().squeeze(),pred_train_mu.cpu().data.numpy().squeeze(),'k',linewidth = 2, label='pred mu')

plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() + 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() - 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith], label='pred std')

plt.plot(x_test.cpu().data.numpy().squeeze(),pred_test_mu.cpu().data.numpy().squeeze() ,'k',linewidth = 2)
plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() + 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() - 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith])



plt.xlabel('x',fontsize = 20)
plt.ylabel('y',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)



leg = plt.legend(loc='best', fontsize = 15)
for line in leg.get_lines():
    line.set_linewidth(4) 
    line.set_markersize(4) 

plt.show()

# %%
metric_list = []

for idx in range(num_rep):
    ith_model_w = rep_model_history_list_w[idx]
    ith_model_e = rep_model_history_list_e[idx]
    with torch.no_grad():
        pred_test_mu_w, pred_test_var_w = ith_model_w._predict_exact(inputs_new=x_test)
        pred_test_mu_e, pred_test_var_e = ith_model_e._predict_exact(inputs_new=x_test)
        
        ith_rmse_w,ith_mnll_w = _evaluate_metric(pred_test_mu_w, pred_test_var_w, y_test)
        ith_rmse_e,ith_mnll_e = _evaluate_metric(pred_test_mu_e, pred_test_var_e, y_test)
        
        metric_list.append( (ith_rmse_w,ith_mnll_w , ith_rmse_e,ith_mnll_e)  )
        
metric_list
# Out:
# [(array(41.7537), array(5.2859), array(40.0816), array(5.177)),
#  (array(42.1678), array(5.4056), array(176.9689), array(6.4537)),
#  (array(44.0951), array(5.4371), array(72.769), array(6.387))]

# %% [markdown]
# # SVSS Ws exact prediction (weight sampling )

# %%
print('mean rmse: {0:.4f}, mean mnll: {1:.4f}'.format(*np.asarray(metric_list).mean(axis=0)[:2]))
print('std rmse: {0:.4f},  std mnll: {1:.4f}'.format(*np.asarray(metric_list).std(axis=0)[:2]))
# Out:
# mean rmse: 42.6722, mean mnll: 5.3762
# std rmse: 1.0203,  std mnll: 0.0652

# %% [markdown]
# # SVSS exact prediction (exact sampling )

# %%
print('mean rmse: {0:.4f}, mean mnll: {1:.4f}'.format(*np.asarray(metric_list).mean(axis=0)[2:]))
print('std rmse: {0:.4f},  std mnll: {1:.4f}'.format(*np.asarray(metric_list).std(axis=0)[2:]))
# Out:
# mean rmse: 96.6065, mean mnll: 6.0059
# std rmse: 58.3707,  std mnll: 0.5867
