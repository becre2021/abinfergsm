# %%
import argparse
import copy
import torch
import time
import numpy as np
np.set_printoptions(precision = 4)
import pickle

from datasets.dataset import _load_collection_real,_load_collection_syn,_load_collection_bbq_data
from models_utility.construct_models import _initialize_SMkernelhyp,_make_gpmodel
from utility.eval_metric import _evaluate_metric
import matplotlib.pyplot as plt

import random


#import matplotlib.pylab as pl
from matplotlib import rc
#rc('text', usetex=True)
rc('font', size=20)
rc('legend', fontsize=20)
#rc('text.latex', preamble=r'\usepackage{cmbright}')

# %%
import seaborn as sns
sns.set()
sns.set_style('white')
#sns.set_style('whitegrid')
import matplotlib
plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
#plt.rc('font', weight='bold')

current_palette = sns.color_palette(sns.hls_palette(8+1, l=.5, s=1.0))

sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %% [markdown]
# # dataset

# %%
device = True

datafilename_list = ['CO2','airline','audio']


#filename = 'CO2'
filename = 'airline'
#filename = 'audio'

# %%
x_train, x_test, y_train, y_test = _load_collection_real(filename,cuda_option=device)


x_full = torch.cat([x_train,x_test],dim = 0)
y_full = torch.cat([y_train,y_test],dim = 0)
y_mean = y_full.mean()
y_train -= y_mean
y_test -= y_mean
y_full -= y_full.mean()
y_full = torch.cat([y_train,y_test],dim = 0)


#random_seed = 1000
random_seed = 1000
setting_dict = {}
setting_dict['random_seed'] = random_seed
setting_dict['input_dim'] = x_train.shape[1]




if filename in [ 'CO2']:
    print('C02 setting') 
    setting_dict['init_sample_num'] = 500    
    #setting_dict['lr_hyp'] = 0.01
    setting_dict['lr_hyp'] = 0.005 
    #setting_dict['noise_err'] = .05*y_train.cpu().data.numpy().std()
    setting_dict['noise_err'] = .1*y_train.cpu().data.numpy().std()
    
    setting_dict['Num_Q'] = 10
    setting_dict['num_sample_pt'] = 5
    setting_dict['iter'] = 4000
    setting_dict['weight_rate'] = 1.0  #allocation rate
    
    
elif filename in ['airline']:
    print('airline setting') 
    setting_dict['init_sample_num'] = 500    
    setting_dict['lr_hyp'] = 0.005 # 0.005 default
    setting_dict['noise_err'] = .05*y_train.cpu().data.numpy().std()
    setting_dict['Num_Q'] = 6
    setting_dict['num_sample_pt'] = 4
    setting_dict['iter'] = 4000
    setting_dict['weight_rate'] = 0.1 #allocation rate


elif filename in ['audio']:
    print('audio setting') 
    setting_dict['init_sample_num'] = 500    
    setting_dict['lr_hyp'] = 0.005
    setting_dict['noise_err'] = 1.0
    setting_dict['Num_Q'] = 8
    setting_dict['num_sample_pt'] = 5
    setting_dict['iter'] = 4000
    setting_dict['weight_rate'] = 1.0
else:
    pass


setting_dict['kl_option'] = True    #['True','False']
setting_dict['num_batch'] = 1
#setting_dict['tau0'] = 100
setting_dict['num_rep'] = 1
setting_dict['optimizer'] = 'Adam'
# Out:
# #loaded collection#
# airline setting

# %%
result_dict = {}
result_dict['Exp_setting'] = setting_dict
result_dict['Data_setting'] = {'x_train' : x_train.cpu().data.numpy(),
                               'y_train' : y_train.cpu().data.numpy(),
                               'x_test' : x_test.cpu().data.numpy(),
                               'y_test' : y_test.cpu().data.numpy()}

result_dict['loss'] = {}
result_dict['rmse'] = {}
result_dict['mnll'] = {}
result_dict['best_loss'] = {}
result_dict['best_rmse'] = {}
result_dict['best_mnll'] = {}

result_dict['pred_train_mu'] = {}
result_dict['pred_train_var'] = {}
result_dict['pred_test_mu'] = {}
result_dict['pred_test_var'] = {}
result_dict['param_history'] = {}
result_dict['error_history'] = {}

# %% [markdown]
# ### modelsetup

# %%
def _clone_parms(ith_model):
    if hasattr(ith_model,'kernel'):
        weight_ = ith_model.kernel.weight.data.clone()
        mu_ = ith_model.kernel.mu.data.clone()
        std_ = ith_model.kernel.std.data.clone()
        var_ = ith_model.likelihood.variance.data.clone()
    return weight_,mu_,std_,var_

def _transfer_params(model_reg,weight_,mu_,std_,var_):
    model_reg.weight.data = weight_
    model_reg.mu.data = mu_
    model_reg.std.data = std_
    model_reg.likelihood.variance.data = var_
    return model_reg

# %% [markdown]
# ### proposed

# %%
#setting_dict['iter']= 2000
#observed_period = 100
observed_period = 200

# %%
num_spt1 = 4

# %%
import torch.nn.utils as torch_utils
from scipy.linalg import norm as fnorm
from models_utility.personalized_adam import Adam_variation


def _train_model(ith_model_name,ith,setting_dict,num_spt1 ):
    setting_dict['num_sample_pt'] = num_spt1     
    if num_spt1 >= 2:
        # intializatoin part
        best_loss = np.inf
        for ith in range(5):    
            setting_dict = _initialize_SMkernelhyp(x_train, y_train, setting_dict, random_seed + ith ,yesSM= True, filename = filename)        

            temp_model = _make_gpmodel(model_name=ith_model_name, setting_dict=setting_dict, device=device)
            if ith_model_name in ['gpvfe', 'gpvferbf']:
                temp_model._set_data(batch_x=x_train, batch_y=y_train)        
                temp_model._set_inducing_pt(2 * setting_dict['Num_Q'] * setting_dict['num_sample_pt'])
                optimizable_param =  [*temp_model.parameters(),temp_model.likelihood.variance]
            elif ith_model_name in ['vssgp']:
                temp_model._set_data(batch_x=x_train, batch_y=y_train)                
                temp_model._set_inducing_pt( setting_dict['Num_Q'] * setting_dict['num_sample_pt'])
                optimizable_param =  [*temp_model.parameters()]
            else:
                temp_model._set_data(x_train, y_train)                            
                optimizable_param =  [*temp_model.parameters(),temp_model.likelihood.variance]

                
            temp_optimizer = torch.optim.Adam(optimizable_param ,
                                              lr=setting_dict['lr_hyp'],
                                              betas=(0.9, 0.99),
                                              eps=1e-08,
                                              weight_decay=0.0)    

            for i in range(1 + 1):    
                temp_optimizer.zero_grad()    
                #losstotal = temp_model.compute_loss(batch_x=x_train[::2], batch_y=y_train[::2], kl_option=setting_dict['kl_option'])
                losstotal = temp_model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])
                losstotal.backward()
                temp_optimizer.step()

            # best model chosen
            if best_loss >= losstotal.cpu().data.numpy():
                best_loss = losstotal.cpu().data.numpy()        
                ith_model = temp_model
                optimizer = temp_optimizer
                print('%d init loss: %.4f '%(ith,losstotal.cpu().data.numpy()))
                print('%d model chosen '%(ith))
            else:
                pass



        param_history_list = []
        error_history_list1,error_history_list2 = [],[]
        loss_history_list,loss_history_list1,loss_history_list2 = [],[],[]
        rmse_history_list,rmse_history_list1,rmse_history_list2 = [],[],[]

        print('#'*100)
        print(ith_model_name)
        ith_model.train()
        for i in range(setting_dict['iter'] + 1):
            optimizer.zero_grad()

            ith_tic = time.time()
            losstotal = ith_model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])
            losstotal.backward()
            optimizer.step()
            ith_toc = time.time()

            with torch.no_grad():
                pred_train_mu, pred_train_var = ith_model._predict(inputs_new=x_train)
                pred_test_mu, pred_test_var = ith_model._predict(inputs_new=x_test)        
                ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)

            #print('\n')

            if i % observed_period == 0 :
                print('%d th loss0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,losstotal.cpu().data.numpy(),ith_rmse,ith_mnll))        
                #print('%d th loss0 : %.4f, reg0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,ith_loss.cpu().data.numpy(),ith_reg.cpu().data.numpy(),ith_rmse,ith_mnll))
                try:
                    print('self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance')            
                    print(ith_model.weight.exp().squeeze(),ith_model.mu.exp().squeeze(),ith_model.std.exp().squeeze(),ith_model.likelihood.variance.transform()**2)
                    print('\n')
                    print('self.num_samplept_list_at')
                    print(ith_model.num_samplept_list_at)

                except:
                    print('self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance')            
                    print(ith_model.kernel.weight.exp().squeeze(),ith_model.kernel.mu.exp().squeeze(),ith_model.kernel.std.exp().squeeze(),ith_model.likelihood.variance.transform()**2)
                    print('\n')
                    pass


                loss_history_list.append( losstotal.cpu().data.numpy().squeeze())
                rmse_history_list.append(ith_rmse.squeeze())



        return ith_model,loss_history_list,rmse_history_list
    else:
        return ith_model,loss_history_list,rmse_history_list

# %%
def _compare_reg_model(num_spt1):
    rep_loss_history_list_e,rep_loss_history_list_w = [],[]
    rep_rmse_history_list_e,rep_rmse_history_list_w = [],[]
    rep_model_history_list_e,rep_model_history_list_w = [],[]

    for i in range(3):
        model_w,loss_history_list_w,rmse_history_list_w =  _train_model('weight_reg',i,setting_dict,num_spt1=num_spt1)    
        model_e,loss_history_list_e,rmse_history_list_e =  _train_model('equal_reg',i,setting_dict,num_spt1=num_spt1)

        rep_loss_history_list_e.append(loss_history_list_e)
        rep_loss_history_list_w.append(loss_history_list_w)
        rep_rmse_history_list_e.append(rmse_history_list_e)
        rep_rmse_history_list_w.append(rmse_history_list_w)

        rep_model_history_list_e.append(model_e)
        rep_model_history_list_w.append(model_w)
        
    return rep_loss_history_list_e,rep_loss_history_list_w,\
           rep_rmse_history_list_e,rep_rmse_history_list_w,\
           rep_model_history_list_e,rep_model_history_list_w

# %%
rep_loss_history_list_e,rep_loss_history_list_w,rep_rmse_history_list_e,rep_rmse_history_list_w,rep_model_history_list_e,rep_model_history_list_w =  _compare_reg_model(num_spt1 )
# Out:
# 0 init loss: 24081.5332
# 0 model chosen
# 1 init loss: 17479.2125
# 1 model chosen
# ####################################################################################################
# weight_reg
# 0 th loss0 : 17108.5378, test rmse : 149.5085, test mnll: : 649.8917
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0150, 1.0151, 1.0151, 1.0150, 1.0139, 1.0143], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1662, 0.0116, 0.0829, 0.3329, 0.2495, 0.4219], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0070, 0.0059, 0.0070, 0.0096, 0.0082, 0.0078], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([13.1683], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 5, 4, 4]
# 200 th loss0 : 4671.0249, test rmse : 134.4350, test mnll: : 167.7341
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2023, 2.2776, 2.2237, 2.1500, 2.0817, 2.0328], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1681, 0.0074, 0.0829, 0.3300, 0.2504, 0.4130], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0044, 0.0065, 0.0045, 0.0063, 0.0056, 0.0064], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([45.4774], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 5, 4, 4]
# 400 th loss0 : 2554.3192, test rmse : 145.4251, test mnll: : 79.3885
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.8385, 4.0626, 3.9515, 3.5490, 3.4549, 2.9457], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1680, 0.0060, 0.0826, 0.3308, 0.2491, 0.4129], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0036, 0.0054, 0.0035, 0.0049, 0.0042, 0.0064], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([120.8856], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 3, 4, 5, 4, 5]
# 600 th loss0 : 1257.3390, test rmse : 157.6738, test mnll: : 40.7999
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9684, 6.6767, 6.2924, 4.9633, 5.0203, 2.9886], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1682, 0.0051, 0.0833, 0.3344, 0.2504, 0.4106], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0033, 0.0044, 0.0028, 0.0046, 0.0038, 0.0099], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([308.9850], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 4, 4, 5]
# 800 th loss0 : 807.0207, test rmse : 144.8436, test mnll: : 16.9732
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.3452, 10.2110,  9.3386,  5.4177,  5.9417,  2.0049], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1686, 0.0046, 0.0838, 0.3294, 0.2501, 0.3637], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0035, 0.0036, 0.0024, 0.0073, 0.0053, 0.0253], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([791.0379], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 3, 5, 4, 5]
# 1000 th loss0 : 644.3489, test rmse : 136.2829, test mnll: : 9.2770
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.9754, 14.4131, 12.6139,  4.3620,  5.2488,  1.4712], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1693, 0.0043, 0.0845, 0.3122, 0.2534, 0.2957], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0051, 0.0032, 0.0024, 0.0192, 0.0134, 0.0626], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1998.5181], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 2, 3, 5, 5, 4]
# 1200 th loss0 : 590.6467, test rmse : 140.0050, test mnll: : 7.3372
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.9005, 19.0768, 15.5171,  3.2767,  3.9962,  1.1400], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1833, 0.0040, 0.0847, 0.2755, 0.2779, 0.2496], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0119, 0.0030, 0.0029, 0.0500, 0.0358, 0.0989], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([4359.8884], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [6, 2, 3, 5, 5, 3]
# 1400 th loss0 : 577.0218, test rmse : 148.7750, test mnll: : 6.9366
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.3259, 25.6181, 17.8195,  2.5092,  2.9586,  0.9037], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2534, 0.0038, 0.0842, 0.2463, 0.3039, 0.2345], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0314, 0.0029, 0.0054, 0.0954, 0.0814, 0.0999], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([6880.0572], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [7, 2, 4, 4, 4, 3]
# 1600 th loss0 : 569.7125, test rmse : 151.4604, test mnll: : 7.0543
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 6.0882, 46.7520, 19.9109,  1.8383,  2.0101,  0.7118], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3320, 0.0034, 0.0840, 0.2365, 0.3073, 0.2290], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0741, 0.0028, 0.0134, 0.1018, 0.1004, 0.1032], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([6524.7930], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [6, 3, 7, 3, 3, 2]
# 1800 th loss0 : 526.7493, test rmse : 109.8381, test mnll: : 7.7163
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  3.1878, 169.4828,  25.8763,   1.1483,   0.9760,   0.4579],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3343, 0.0039, 0.0846, 0.2463, 0.3101, 0.2356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1016, 0.0018, 0.0326, 0.0955, 0.1025, 0.0992], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1916.6878], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 10, 3, 2, 2]
# 2000 th loss0 : 483.2709, test rmse : 99.4587, test mnll: : 9.5409
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3731e+00, 4.6572e+02, 1.0304e+02, 8.1951e-01, 4.7396e-01, 2.9695e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3146, 0.0034, 0.0851, 0.2433, 0.2912, 0.2353], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1051, 0.0010, 0.0312, 0.0948, 0.1022, 0.0937], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([700.2657], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 13, 2, 2, 2]
# 2200 th loss0 : 464.0711, test rmse : 68.8389, test mnll: : 7.6770
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.7352e-01, 9.7714e+02, 2.8461e+02, 6.5742e-01, 3.0189e-01, 3.0332e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3196, 0.0031, 0.0836, 0.2351, 0.3108, 0.2236], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1055, 0.0007, 0.0196, 0.0971, 0.0991, 0.1041], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([427.7455], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 14, 2, 2, 2]
# 2400 th loss0 : 450.1091, test rmse : 69.6936, test mnll: : 7.6383
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9720e-01, 1.9052e+03, 4.5830e+02, 7.3159e-01, 1.9780e-01, 3.1572e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3358, 0.0029, 0.0830, 0.2574, 0.3074, 0.2349], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1005, 0.0006, 0.0102, 0.0921, 0.0974, 0.1008], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([374.9079], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 13, 2, 2, 2]
# 2600 th loss0 : 442.6408, test rmse : 60.9916, test mnll: : 6.8118
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.8165e-01, 3.5257e+03, 5.1593e+02, 7.8236e-01, 1.5272e-01, 3.3048e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3220, 0.0028, 0.0836, 0.2275, 0.2951, 0.2453], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1004, 0.0005, 0.0058, 0.1030, 0.1024, 0.0928], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([339.8725], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 3, 13, 2, 2, 2]
# 2800 th loss0 : 440.1896, test rmse : 49.8607, test mnll: : 6.0233
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.7472e-01, 6.1391e+03, 5.7788e+02, 9.7527e-01, 1.5138e-01, 3.4758e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3383, 0.0026, 0.0830, 0.2482, 0.2913, 0.2383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0990, 0.0004, 0.0035, 0.0904, 0.1093, 0.0974], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([335.1862], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 4, 12, 2, 2, 2]
# 3000 th loss0 : 438.8805, test rmse : 45.8974, test mnll: : 5.7723
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.9727e-01, 9.7165e+03, 7.3335e+02, 1.1074e+00, 1.3271e-01, 4.0615e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3296, 0.0025, 0.0821, 0.2411, 0.3055, 0.2373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1023, 0.0005, 0.0025, 0.0957, 0.1035, 0.0945], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([337.9675], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 5, 11, 2, 2, 2]
# 3200 th loss0 : 437.7058, test rmse : 43.5096, test mnll: : 5.6656
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6646e-01, 1.3288e+04, 8.3509e+02, 1.2042e+00, 1.2466e-01, 4.0064e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3437, 0.0023, 0.0830, 0.2465, 0.2992, 0.2454], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0978, 0.0006, 0.0023, 0.0978, 0.1031, 0.0897], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([329.8148], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 6, 10, 2, 2, 2]
# 3400 th loss0 : 443.1550, test rmse : 44.0017, test mnll: : 5.8927
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3439e-01, 1.4880e+04, 8.7281e+02, 1.2545e+00, 1.1254e-01, 4.4278e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3416, 0.0022, 0.0827, 0.2763, 0.3101, 0.2246], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0952, 0.0006, 0.0023, 0.0873, 0.0955, 0.0987], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([333.7120], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 6, 10, 2, 2, 2]
# 3600 th loss0 : 439.0068, test rmse : 43.0022, test mnll: : 5.4911
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0403e-01, 1.6357e+04, 8.5218e+02, 1.2413e+00, 9.5503e-02, 4.5803e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3432, 0.0022, 0.0829, 0.2757, 0.2985, 0.2218], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0946, 0.0006, 0.0023, 0.0851, 0.1024, 0.1046], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([329.1731], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 3800 th loss0 : 439.7636, test rmse : 42.8195, test mnll: : 5.4834
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.3103e-02, 1.6427e+04, 8.7929e+02, 9.7218e-01, 8.4003e-02, 4.8307e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3294, 0.0022, 0.0827, 0.2557, 0.3157, 0.2122], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1012, 0.0006, 0.0022, 0.0891, 0.0982, 0.1081], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([331.7825], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 6, 9, 2, 2, 2]
# 4000 th loss0 : 439.0247, test rmse : 43.3725, test mnll: : 5.6061
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.2930e-02, 1.6482e+04, 8.5635e+02, 9.6272e-01, 8.0727e-02, 5.1862e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3307, 0.0021, 0.0832, 0.2574, 0.3108, 0.2355], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1003, 0.0006, 0.0022, 0.0928, 0.0977, 0.0998], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([327.2402], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 0 init loss: 28694.2890
# 0 model chosen
# 2 init loss: 24073.9024
# 2 model chosen
# 3 init loss: 23426.6150
# 3 model chosen
# ####################################################################################################
# equal_reg
# 0 th loss0 : 25602.1356, test rmse : 178.1191, test mnll: : 920.6471
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0146, 1.0151, 1.0144, 1.0151, 1.0146, 1.0148], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0778, 0.0103, 0.3277, 0.1675, 0.4113, 0.2402], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0172, 0.0010, 0.0125, 0.0049, 0.0061, 0.0127], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([13.1840], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 200 th loss0 : 3818.9277, test rmse : 118.5666, test mnll: : 144.0634
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.0278, 2.5447, 2.0232, 2.2774, 2.0017, 2.0010], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0817, 0.0055, 0.3307, 0.1672, 0.4138, 0.2494], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0136, 0.0014, 0.0101, 0.0035, 0.0048, 0.0101], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([41.5115], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 400 th loss0 : 2212.3346, test rmse : 90.8381, test mnll: : 48.9337
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.0052, 5.4099, 3.5435, 4.4226, 3.0943, 3.3535], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0846, 0.0045, 0.3297, 0.1670, 0.4167, 0.2500], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0088, 0.0011, 0.0076, 0.0028, 0.0044, 0.0081], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([75.9031], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 600 th loss0 : 1240.9149, test rmse : 77.1278, test mnll: : 22.0224
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.9142, 10.6992,  6.0203,  8.2827,  4.0020,  5.4785], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0843, 0.0042, 0.3300, 0.1673, 0.4128, 0.2495], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0059, 0.0009, 0.0058, 0.0025, 0.0053, 0.0061], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([137.9762], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 800 th loss0 : 846.2660, test rmse : 73.5964, test mnll: : 12.8957
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([15.2152, 20.4911,  9.2279, 15.1603,  3.1289,  8.3340], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0830, 0.0040, 0.3363, 0.1669, 0.4132, 0.2482], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0040, 0.0007, 0.0050, 0.0024, 0.0112, 0.0055], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([259.3385], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1000 th loss0 : 656.2648, test rmse : 81.1662, test mnll: : 10.2125
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([27.9765, 38.7231, 10.0142, 26.7238,  1.5572,  9.2040], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0836, 0.0040, 0.3291, 0.1674, 0.4153, 0.2503], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0031, 0.0006, 0.0070, 0.0026, 0.0329, 0.0067], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([476.6130], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1200 th loss0 : 570.1159, test rmse : 73.8886, test mnll: : 7.8263
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([52.1091, 74.2177,  5.5304, 46.8573,  0.8817,  5.6113], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0835, 0.0040, 0.3201, 0.1683, 0.4136, 0.2516], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0005, 0.0174, 0.0029, 0.0779, 0.0163], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([677.4934], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1400 th loss0 : 507.6808, test rmse : 57.3118, test mnll: : 7.2273
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([109.9786, 152.1448,   2.4862,  90.1277,   0.4763,   2.4917],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0838, 0.0037, 0.2944, 0.1690, 0.4173, 0.2633], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0004, 0.0460, 0.0027, 0.0985, 0.0447], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([403.3300], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1600 th loss0 : 463.1948, test rmse : 50.0225, test mnll: : 8.0874
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.6142e+02, 3.2011e+02, 1.2262e+00, 1.7328e+02, 2.2509e-01, 1.4552e+00],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0823, 0.0032, 0.2627, 0.1683, 0.4215, 0.2687], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0029, 0.0004, 0.0801, 0.0024, 0.0969, 0.0754], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([195.1283], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1800 th loss0 : 443.7122, test rmse : 43.6218, test mnll: : 6.6554
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.9811e+02, 6.3864e+02, 9.4604e-01, 2.1167e+02, 1.3159e-01, 1.0105e+00],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0820, 0.0030, 0.2498, 0.1678, 0.4105, 0.2915], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.0003, 0.0995, 0.0021, 0.0980, 0.0776], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([179.1879], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2000 th loss0 : 435.5644, test rmse : 44.1115, test mnll: : 6.6589
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.0007e+02, 1.2311e+03, 7.7902e-01, 2.2387e+02, 7.5703e-02, 7.2024e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0836, 0.0028, 0.2537, 0.1673, 0.4128, 0.2925], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0024, 0.0003, 0.1052, 0.0020, 0.1002, 0.0910], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([175.9129], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2200 th loss0 : 433.8440, test rmse : 42.6937, test mnll: : 6.3788
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0167e+03, 2.3171e+03, 6.0527e-01, 2.2317e+02, 4.7295e-02, 6.1706e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0822, 0.0027, 0.2597, 0.1674, 0.4127, 0.2867], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0023, 0.0003, 0.0988, 0.0020, 0.1005, 0.0922], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([170.3870], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2400 th loss0 : 427.2030, test rmse : 41.2511, test mnll: : 5.9797
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1834e+03, 4.2462e+03, 5.0477e-01, 2.2952e+02, 2.8376e-02, 5.8224e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0819, 0.0026, 0.2830, 0.1682, 0.4181, 0.2958], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0021, 0.0003, 0.0986, 0.0020, 0.0998, 0.0925], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([163.1858], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2600 th loss0 : 426.3699, test rmse : 40.3269, test mnll: : 6.9073
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3062e+03, 7.5123e+03, 3.9120e-01, 2.3476e+02, 1.8338e-02, 4.2756e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0821, 0.0024, 0.2540, 0.1670, 0.4132, 0.2990], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0021, 0.0004, 0.1024, 0.0021, 0.0999, 0.0951], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([161.9293], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2800 th loss0 : 430.2630, test rmse : 31.8678, test mnll: : 5.2440
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3925e+03, 1.3117e+04, 3.3776e-01, 2.2773e+02, 1.2545e-02, 3.3322e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0822, 0.0023, 0.2602, 0.1677, 0.4179, 0.3033], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0005, 0.1064, 0.0021, 0.0994, 0.0988], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([160.6550], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3000 th loss0 : 428.1964, test rmse : 39.7105, test mnll: : 5.7862
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3952e+03, 2.2602e+04, 2.9258e-01, 2.3952e+02, 8.3124e-03, 2.6309e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0819, 0.0022, 0.2694, 0.1680, 0.4129, 0.3047], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0007, 0.1038, 0.0020, 0.1000, 0.1000], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([164.5335], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3200 th loss0 : 426.5216, test rmse : 32.9379, test mnll: : 5.4228
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.4726e+03, 3.4455e+04, 2.4155e-01, 2.2523e+02, 5.5145e-03, 2.2161e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0819, 0.0020, 0.2589, 0.1675, 0.4161, 0.3069], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0007, 0.0954, 0.0020, 0.1004, 0.0973], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([157.2382], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3400 th loss0 : 425.5232, test rmse : 28.4035, test mnll: : 4.8608
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5943e+03, 4.7429e+04, 2.2357e-01, 2.2721e+02, 3.4911e-03, 1.7440e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0832, 0.0020, 0.2634, 0.1671, 0.4141, 0.2956], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0021, 0.0009, 0.0995, 0.0021, 0.0999, 0.0963], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([155.6693], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3600 th loss0 : 425.2272, test rmse : 41.7131, test mnll: : 5.6035
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5009e+03, 5.4611e+04, 1.8534e-01, 2.1756e+02, 2.3503e-03, 1.4292e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0838, 0.0019, 0.2526, 0.1686, 0.4148, 0.3149], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0019, 0.0009, 0.1001, 0.0019, 0.1003, 0.1025], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([158.4223], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3800 th loss0 : 424.7087, test rmse : 32.7109, test mnll: : 5.1085
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5782e+03, 6.2343e+04, 1.7117e-01, 2.6512e+02, 1.4697e-03, 1.2617e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0833, 0.0020, 0.2748, 0.1674, 0.4145, 0.3003], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0011, 0.1017, 0.0022, 0.1003, 0.1024], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([152.4935], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 4000 th loss0 : 427.1851, test rmse : 29.0455, test mnll: : 4.9718
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5511e+03, 7.5245e+04, 1.5606e-01, 2.7686e+02, 1.0141e-03, 1.2126e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0834, 0.0025, 0.2627, 0.1669, 0.4152, 0.3077], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0014, 0.0971, 0.0021, 0.1004, 0.0999], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([145.7136], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 0 init loss: 26967.6277
# 0 model chosen
# 1 init loss: 11554.1562
# 1 model chosen
# ####################################################################################################
# weight_reg
# 0 th loss0 : 20712.6948, test rmse : 179.0157, test mnll: : 946.5059
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0147, 1.0151, 1.0148, 1.0151, 1.0149, 1.0146], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1696, 0.0117, 0.0821, 0.3326, 0.2559, 0.4136], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0071, 0.0059, 0.0071, 0.0096, 0.0081, 0.0078], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([13.1626], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 5, 4, 4]
# 200 th loss0 : 6263.0204, test rmse : 139.1145, test mnll: : 169.1336
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.1559, 2.1872, 2.1842, 2.0906, 2.1215, 2.0201], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1679, 0.0076, 0.0827, 0.3322, 0.2482, 0.4148], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0049, 0.0062, 0.0043, 0.0061, 0.0057, 0.0063], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([49.4807], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 5, 4, 4]
# 400 th loss0 : 2205.5475, test rmse : 120.2845, test mnll: : 49.9920
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.6496, 3.7701, 3.7192, 3.3040, 3.4137, 2.8565], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1678, 0.0062, 0.0838, 0.3305, 0.2480, 0.4120], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0038, 0.0054, 0.0030, 0.0047, 0.0041, 0.0065], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([139.3547], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 4, 4, 5]
# 600 th loss0 : 1211.9592, test rmse : 179.7373, test mnll: : 46.0999
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.4700, 5.9710, 5.7309, 4.4186, 4.7769, 2.7394], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1679, 0.0054, 0.0841, 0.3300, 0.2490, 0.4074], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0035, 0.0047, 0.0024, 0.0047, 0.0039, 0.0108], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([358.7761], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 3, 3, 4, 4, 5]
# 800 th loss0 : 796.5022, test rmse : 147.3497, test mnll: : 15.7624
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.2965, 8.8303, 8.1736, 4.6110, 5.5226, 1.8979], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1693, 0.0048, 0.0842, 0.3298, 0.2494, 0.3554], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0038, 0.0041, 0.0022, 0.0080, 0.0058, 0.0281], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([917.5380], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 3, 5, 4, 5]
# 1000 th loss0 : 637.2442, test rmse : 147.4671, test mnll: : 9.4400
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.3105, 11.8501, 10.5545,  3.7399,  4.7846,  1.4298], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1706, 0.0045, 0.0842, 0.3065, 0.2575, 0.2903], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0059, 0.0037, 0.0022, 0.0205, 0.0144, 0.0677], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([2304.2764], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 3, 5, 5, 4]
# 1200 th loss0 : 590.3417, test rmse : 150.9322, test mnll: : 7.4842
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.9498, 14.9401, 12.4729,  2.9079,  3.7060,  1.1200], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1922, 0.0043, 0.0841, 0.2706, 0.2805, 0.2460], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0143, 0.0035, 0.0030, 0.0525, 0.0383, 0.0998], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([4879.1843], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [6, 2, 3, 5, 5, 3]
# 1400 th loss0 : 578.4704, test rmse : 147.1356, test mnll: : 6.8194
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 6.8198, 19.0918, 13.7851,  2.2816,  2.7756,  0.9033], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.2714, 0.0040, 0.0852, 0.2443, 0.3043, 0.2330], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0372, 0.0035, 0.0064, 0.0938, 0.0848, 0.1006], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7488.5627], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [7, 2, 4, 4, 4, 3]
# 1600 th loss0 : 573.5855, test rmse : 152.3352, test mnll: : 6.9188
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 5.1661, 31.9850, 14.1532,  1.6159,  1.8508,  0.6244], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.3331, 0.0036, 0.0873, 0.2379, 0.3076, 0.2326], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0830, 0.0034, 0.0168, 0.1006, 0.0998, 0.1012], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7507.5390], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [6, 3, 7, 3, 3, 2]
# 1800 th loss0 : 549.4390, test rmse : 164.7410, test mnll: : 8.8792
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([  2.9698, 112.4512,  14.8370,   1.0731,   1.0319,   0.4355],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3305, 0.0035, 0.0823, 0.2348, 0.3068, 0.2324], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1028, 0.0026, 0.0430, 0.1016, 0.0996, 0.1000], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([3375.0464], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 3, 10, 3, 3, 2]
# 2000 th loss0 : 496.5531, test rmse : 91.6010, test mnll: : 8.3037
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0969e+00, 3.6743e+02, 4.6825e+01, 6.1274e-01, 4.9069e-01, 2.4737e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3250, 0.0037, 0.0835, 0.2405, 0.2958, 0.2362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1034, 0.0012, 0.0424, 0.0964, 0.1015, 0.0987], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([909.4156], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 3, 13, 2, 2, 2]
# 2200 th loss0 : 471.6031, test rmse : 75.5522, test mnll: : 8.0238
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.3852e-01, 7.9330e+02, 1.3852e+02, 5.2462e-01, 3.1214e-01, 1.9709e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3321, 0.0034, 0.0717, 0.2525, 0.3136, 0.2363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1046, 0.0008, 0.0387, 0.0937, 0.0967, 0.0991], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([636.0112], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 14, 2, 2, 2]
# 2400 th loss0 : 474.5990, test rmse : 69.3559, test mnll: : 7.1143
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.9781e-01, 1.5504e+03, 3.2764e+02, 4.1215e-01, 2.1499e-01, 1.5416e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3344, 0.0031, 0.0767, 0.2403, 0.2991, 0.2212], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0986, 0.0007, 0.0316, 0.0950, 0.1044, 0.1035], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([486.8543], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 14, 2, 2, 2]
# 2600 th loss0 : 450.9149, test rmse : 68.6091, test mnll: : 7.2444
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.0489e-01, 2.9547e+03, 5.4996e+02, 3.9739e-01, 1.5200e-01, 1.6403e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3359, 0.0028, 0.0812, 0.2345, 0.3058, 0.2284], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1016, 0.0005, 0.0201, 0.0987, 0.0975, 0.1010], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([399.3826], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 14, 2, 2, 2]
# 2800 th loss0 : 444.7891, test rmse : 59.0391, test mnll: : 6.3422
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1872e-01, 5.3354e+03, 5.8984e+02, 4.6577e-01, 1.1000e-01, 1.6534e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3370, 0.0027, 0.0818, 0.2378, 0.3055, 0.2294], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0989, 0.0005, 0.0121, 0.0978, 0.1018, 0.1022], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([356.2158], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 3, 13, 2, 2, 2]
# 3000 th loss0 : 440.4219, test rmse : 59.8147, test mnll: : 6.2115
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.4493e-02, 8.6228e+03, 5.4661e+02, 4.5225e-01, 8.2157e-02, 1.8384e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3343, 0.0025, 0.0836, 0.2315, 0.3096, 0.2401], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1002, 0.0005, 0.0070, 0.1023, 0.0971, 0.0970], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([346.9190], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 4, 12, 2, 2, 2]
# 3200 th loss0 : 441.0970, test rmse : 50.6953, test mnll: : 5.5966
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.5152e-02, 1.2432e+04, 5.7394e+02, 4.9397e-01, 7.0494e-02, 1.7630e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3368, 0.0024, 0.0825, 0.2192, 0.3042, 0.2462], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0983, 0.0005, 0.0042, 0.1013, 0.1003, 0.0967], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([335.9989], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 5, 11, 2, 2, 2]
# 3400 th loss0 : 439.3303, test rmse : 43.3874, test mnll: : 5.5659
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.3573e-02, 1.4371e+04, 6.8072e+02, 5.6846e-01, 5.9224e-02, 1.7220e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3268, 0.0023, 0.0829, 0.2188, 0.3012, 0.2389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1019, 0.0006, 0.0028, 0.1014, 0.1012, 0.0964], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([331.0685], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 6, 10, 2, 2, 2]
# 3600 th loss0 : 439.5854, test rmse : 43.0721, test mnll: : 5.7137
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.1561e-02, 1.5752e+04, 7.8424e+02, 5.5559e-01, 5.8273e-02, 1.7045e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3327, 0.0022, 0.0831, 0.2316, 0.3047, 0.2486], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1006, 0.0006, 0.0023, 0.0972, 0.0991, 0.0945], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([327.5103], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 3800 th loss0 : 438.5174, test rmse : 40.4913, test mnll: : 5.5019
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.1668e-02, 1.6948e+04, 8.5252e+02, 6.8352e-01, 4.6405e-02, 1.8271e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3351, 0.0022, 0.0825, 0.2265, 0.2976, 0.2421], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1010, 0.0006, 0.0023, 0.0983, 0.1045, 0.0955], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([330.5629], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 4000 th loss0 : 438.7576, test rmse : 44.0095, test mnll: : 5.4287
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.4260e-02, 1.6589e+04, 8.4183e+02, 6.5686e-01, 4.1934e-02, 1.9725e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3341, 0.0021, 0.0831, 0.2477, 0.3040, 0.2265], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1017, 0.0006, 0.0023, 0.0952, 0.1017, 0.0999], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([331.4710], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 0 init loss: 24564.6874
# 0 model chosen
# 2 init loss: 24070.9711
# 2 model chosen
# 4 init loss: 17359.0134
# 4 model chosen
# ####################################################################################################
# equal_reg
# 0 th loss0 : 13453.7983, test rmse : 125.5796, test mnll: : 463.1227
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0151, 1.0130, 1.0149, 1.0141, 1.0150, 1.0151], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0114, 0.2384, 0.0822, 0.4507, 0.1628, 0.3334], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0053, 0.0122, 0.0069, 0.0277, 0.0101, 0.0050], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([13.1827], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 200 th loss0 : 4905.5270, test rmse : 171.5651, test mnll: : 248.7101
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2009, 2.0391, 2.1765, 1.7162, 2.1508, 2.1406], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0071, 0.2427, 0.0840, 0.4291, 0.1686, 0.3325], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0059, 0.0093, 0.0044, 0.0300, 0.0073, 0.0035], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([50.7819], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 400 th loss0 : 2142.3878, test rmse : 150.4065, test mnll: : 76.3437
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.8426, 3.2277, 3.6960, 1.8674, 3.6141, 3.5204], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0057, 0.2482, 0.0842, 0.4224, 0.1688, 0.3305], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0047, 0.0082, 0.0033, 0.0314, 0.0058, 0.0027], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([139.9202], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 600 th loss0 : 1128.2936, test rmse : 146.0685, test mnll: : 30.5888
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.0514, 4.1198, 5.6598, 1.4398, 5.2900, 4.9552], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0049, 0.2499, 0.0835, 0.4103, 0.1681, 0.3305], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0038, 0.0080, 0.0027, 0.0368, 0.0048, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([375.6469], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 800 th loss0 : 782.6809, test rmse : 140.8411, test mnll: : 14.0853
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.7545, 4.1704, 7.8884, 1.0414, 6.8039, 5.4820], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0045, 0.2442, 0.0842, 0.3897, 0.1680, 0.3317], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0032, 0.0121, 0.0025, 0.0546, 0.0049, 0.0056], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([991.4655], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1000 th loss0 : 645.2386, test rmse : 146.3055, test mnll: : 9.0674
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([11.5488,  3.5296,  9.9057,  0.7945,  7.4687,  4.4873], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0043, 0.2236, 0.0844, 0.3720, 0.1713, 0.3287], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0029, 0.0275, 0.0025, 0.0897, 0.0067, 0.0154], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([2493.6278], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1200 th loss0 : 599.6402, test rmse : 147.2108, test mnll: : 7.2644
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([14.2794,  2.9267, 11.3579,  0.6264,  7.1499,  3.4178], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0041, 0.1890, 0.0853, 0.3663, 0.1886, 0.3227], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.0654, 0.0034, 0.1033, 0.0144, 0.0412], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([5216.3669], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1400 th loss0 : 589.2838, test rmse : 153.3406, test mnll: : 6.9130
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([17.9354,  2.7136, 12.2569,  0.4746,  6.2116,  2.5115], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0039, 0.1501, 0.0871, 0.3690, 0.2474, 0.3192], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0029, 0.1013, 0.0069, 0.0999, 0.0364, 0.0878], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7713.7146], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1600 th loss0 : 585.1422, test rmse : 156.7669, test mnll: : 7.0176
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([30.2096,  3.1544, 12.2059,  0.3149,  4.7253,  1.6719], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.1279, 0.1016, 0.3689, 0.3025, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.0981, 0.0178, 0.1000, 0.0815, 0.1002], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7456.4929], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1800 th loss0 : 556.2552, test rmse : 122.7612, test mnll: : 7.3621
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([107.9620,   3.9544,   9.5107,   0.1601,   2.7164,   0.8535],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.1182, 0.1514, 0.3692, 0.2981, 0.3199], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0020, 0.0966, 0.0459, 0.0998, 0.1025, 0.0992], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([3006.7610], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2000 th loss0 : 507.9182, test rmse : 83.9846, test mnll: : 7.6639
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.4905e+02, 8.6737e+00, 8.4090e+00, 5.6765e-02, 1.1183e+00, 3.2357e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.0939, 0.1936, 0.3698, 0.2892, 0.3175], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0009, 0.1155, 0.0566, 0.1001, 0.1032, 0.1038], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([986.1920], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2200 th loss0 : 492.3653, test rmse : 77.6073, test mnll: : 7.3369
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.4217e+02, 1.4059e+01, 7.1326e+00, 2.7379e-02, 7.3187e-01, 1.8081e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0034, 0.0885, 0.1783, 0.3687, 0.3060, 0.3198], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.1119, 0.0672, 0.1002, 0.1014, 0.0975], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([899.0730], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2400 th loss0 : 489.0602, test rmse : 73.0008, test mnll: : 7.1950
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.4574e+03, 2.1335e+01, 8.4255e+00, 1.4137e-02, 4.5030e-01, 1.0685e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0033, 0.0860, 0.1780, 0.3686, 0.3040, 0.3230], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0995, 0.0702, 0.0999, 0.1012, 0.1002], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([868.1146], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2600 th loss0 : 487.0780, test rmse : 75.2755, test mnll: : 7.1397
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.7418e+03, 3.3606e+01, 1.0134e+01, 7.7163e-03, 2.6617e-01, 6.7080e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.0889, 0.1743, 0.3689, 0.3041, 0.3191], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0893, 0.0758, 0.1000, 0.1005, 0.1000], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([829.7356], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2800 th loss0 : 483.4147, test rmse : 72.8861, test mnll: : 6.7677
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.8550e+03, 4.4436e+01, 1.1985e+01, 4.2781e-03, 1.6391e-01, 3.9333e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.0880, 0.1755, 0.3690, 0.3031, 0.3186], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0883, 0.0787, 0.1000, 0.1004, 0.0990], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([854.0436], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3000 th loss0 : 476.5460, test rmse : 77.0919, test mnll: : 6.6039
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.0119e+03, 5.5338e+01, 1.3208e+01, 2.2981e-03, 9.7116e-02, 2.3082e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.0953, 0.1813, 0.3688, 0.3015, 0.3194], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0936, 0.0770, 0.1000, 0.1007, 0.1001], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([836.9984], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3200 th loss0 : 485.9553, test rmse : 73.1157, test mnll: : 6.7418
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0867e+04, 6.3037e+01, 1.3452e+01, 1.2362e-03, 5.8665e-02, 1.4706e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0971, 0.1885, 0.3691, 0.3047, 0.3195], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0983, 0.0751, 0.1000, 0.0992, 0.1003], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([816.2713], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3400 th loss0 : 487.2704, test rmse : 70.1859, test mnll: : 6.6901
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2320e+04, 7.1198e+01, 1.4214e+01, 6.6149e-04, 4.1440e-02, 8.4974e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0953, 0.2113, 0.3691, 0.3047, 0.3185], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0947, 0.0670, 0.1001, 0.0998, 0.1000], device='cuda:0',
# ...
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1745e-01, 8.8478e+03, 5.3669e+02, 9.5545e-01, 6.8837e-02, 5.2631e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3339, 0.0026, 0.0841, 0.2110, 0.3138, 0.2234], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0994, 0.0005, 0.0067, 0.1013, 0.0975, 0.0996], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([342.4694], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 4, 12, 2, 2, 2]
# 3200 th loss0 : 437.8262, test rmse : 46.3523, test mnll: : 5.9194
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.6715e-02, 1.2520e+04, 5.7357e+02, 1.0756e+00, 6.1593e-02, 5.7106e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3263, 0.0024, 0.0822, 0.2089, 0.3011, 0.2171], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1025, 0.0005, 0.0039, 0.1027, 0.1027, 0.1015], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([333.8424], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 5, 10, 2, 2, 2]
# 3400 th loss0 : 442.2304, test rmse : 48.0262, test mnll: : 5.8946
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.2171e-02, 1.5003e+04, 6.9983e+02, 1.3060e+00, 4.9104e-02, 5.8097e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3341, 0.0024, 0.0834, 0.1967, 0.3074, 0.2179], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0972, 0.0006, 0.0028, 0.1082, 0.1002, 0.1018], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([327.1767], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 6, 9, 2, 2, 2]
# 3600 th loss0 : 438.7268, test rmse : 43.8469, test mnll: : 5.6144
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.7843e-02, 1.5987e+04, 8.3252e+02, 1.5486e+00, 4.7019e-02, 6.5090e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3394, 0.0022, 0.0827, 0.2157, 0.3073, 0.2299], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0985, 0.0006, 0.0023, 0.0965, 0.0989, 0.0986], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([330.4911], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 6, 9, 2, 2, 2]
# 3800 th loss0 : 438.7622, test rmse : 44.3062, test mnll: : 5.4509
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.8070e-02, 1.6450e+04, 8.6812e+02, 1.5661e+00, 4.0621e-02, 7.6182e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3366, 0.0021, 0.0818, 0.2122, 0.3071, 0.2134], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0999, 0.0006, 0.0023, 0.1027, 0.1001, 0.1043], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([330.4217], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 6, 9, 2, 2, 2]
# 4000 th loss0 : 440.3165, test rmse : 45.9571, test mnll: : 5.7217
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.1885e-02, 1.7190e+04, 8.7440e+02, 1.7175e+00, 3.1920e-02, 8.5602e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3292, 0.0022, 0.0841, 0.2099, 0.3071, 0.2223], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.1008, 0.0006, 0.0023, 0.1041, 0.0999, 0.1037], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([338.3300], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 7, 9, 2, 2, 2]
# 0 init loss: 25971.0032
# 0 model chosen
# 1 init loss: 18899.7405
# 1 model chosen
# 4 init loss: 13386.7156
# 4 model chosen
# ####################################################################################################
# equal_reg
# 0 th loss0 : 13749.2291, test rmse : 137.1326, test mnll: : 556.2945
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0151, 1.0147, 1.0146, 1.0146, 1.0145, 1.0151], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0114, 0.2400, 0.0821, 0.4539, 0.1603, 0.3275], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0053, 0.0123, 0.0068, 0.0272, 0.0101, 0.0049], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([13.1850], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 200 th loss0 : 4175.0102, test rmse : 161.9026, test mnll: : 213.6363
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.1843, 2.0151, 2.1937, 1.5876, 2.1339, 2.1273], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0070, 0.2469, 0.0842, 0.4717, 0.1636, 0.3292], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0059, 0.0096, 0.0043, 0.0294, 0.0071, 0.0032], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([53.2411], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 400 th loss0 : 2196.5643, test rmse : 136.1550, test mnll: : 60.8331
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.7727, 3.0626, 3.6929, 1.3953, 3.5181, 3.4688], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0056, 0.2489, 0.0837, 0.4749, 0.1687, 0.3322], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0047, 0.0084, 0.0032, 0.0317, 0.0056, 0.0026], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([146.0628], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 600 th loss0 : 1134.6170, test rmse : 157.1880, test mnll: : 34.4069
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9512, 3.8516, 5.6425, 1.0288, 5.0929, 4.8746], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0049, 0.2486, 0.0833, 0.4481, 0.1687, 0.3312], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.0087, 0.0026, 0.0368, 0.0048, 0.0029], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([381.6162], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 800 th loss0 : 780.8780, test rmse : 131.6427, test mnll: : 12.7100
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.6138, 3.8930, 7.8588, 0.7704, 6.4804, 5.3841], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0044, 0.2431, 0.0844, 0.4100, 0.1688, 0.3327], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0031, 0.0125, 0.0023, 0.0542, 0.0049, 0.0057], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1012.5168], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1000 th loss0 : 643.4855, test rmse : 145.2732, test mnll: : 8.9497
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([11.3478,  3.2891,  9.8312,  0.6031,  7.0694,  4.4510], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0042, 0.2225, 0.0843, 0.3774, 0.1714, 0.3293], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.0275, 0.0024, 0.0890, 0.0067, 0.0156], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([2536.1939], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1200 th loss0 : 598.3401, test rmse : 149.1394, test mnll: : 7.2970
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([13.9792,  2.7350, 11.2527,  0.4801,  6.7649,  3.3880], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0040, 0.1878, 0.0851, 0.3690, 0.1906, 0.3228], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.0655, 0.0034, 0.1000, 0.0140, 0.0416], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([5289.1850], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1400 th loss0 : 588.8846, test rmse : 146.2924, test mnll: : 6.7745
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([17.5988,  2.6506, 12.1150,  0.3670,  5.8924,  2.4866], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0039, 0.1514, 0.0880, 0.3690, 0.2533, 0.3190], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.0951, 0.0072, 0.0999, 0.0353, 0.0884], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7736.5972], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1600 th loss0 : 584.1003, test rmse : 142.0808, test mnll: : 6.7266
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([30.1040,  2.9752, 11.9495,  0.2458,  4.5182,  1.6107], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0036, 0.1250, 0.1027, 0.3689, 0.3043, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.1002, 0.0188, 0.1000, 0.0796, 0.0998], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([7446.9977], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 1800 th loss0 : 556.6574, test rmse : 143.2066, test mnll: : 8.0742
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([107.0334,   4.1686,   9.0730,   0.1259,   2.5947,   0.8149],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0037, 0.1143, 0.1557, 0.3690, 0.3035, 0.3191], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0022, 0.0997, 0.0460, 0.1000, 0.1005, 0.0999], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([3204.1302], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2000 th loss0 : 507.5113, test rmse : 77.2184, test mnll: : 7.1753
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.5003e+02, 6.5153e+00, 7.9381e+00, 4.4709e-02, 1.0711e+00, 3.1465e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0038, 0.1083, 0.1807, 0.3692, 0.3046, 0.3249], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0011, 0.0969, 0.0589, 0.1004, 0.0969, 0.0995], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([1007.5689], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2200 th loss0 : 496.8768, test rmse : 80.1597, test mnll: : 7.4891
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.4681e+02, 1.1386e+01, 1.0688e+01, 2.1690e-02, 7.0138e-01, 1.5860e-01],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0035, 0.1048, 0.1709, 0.3685, 0.3151, 0.3174], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0008, 0.0926, 0.0658, 0.0999, 0.0982, 0.1017], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([883.9286], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2400 th loss0 : 492.5009, test rmse : 75.1376, test mnll: : 7.1470
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.4569e+03, 1.7239e+01, 1.2566e+01, 1.1284e-02, 4.8371e-01, 9.7582e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0031, 0.1073, 0.1777, 0.3689, 0.3012, 0.3212], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0934, 0.0676, 0.0999, 0.1027, 0.0978], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([880.1692], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2600 th loss0 : 488.3941, test rmse : 74.0679, test mnll: : 7.0296
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.7351e+03, 2.6010e+01, 1.4604e+01, 6.0284e-03, 3.0733e-01, 5.9282e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0030, 0.1058, 0.1737, 0.3692, 0.3049, 0.3203], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.1082, 0.0691, 0.1000, 0.0982, 0.1002], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([856.6724], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 2800 th loss0 : 478.3623, test rmse : 72.1562, test mnll: : 6.7417
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.9059e+03, 3.6054e+01, 1.7903e+01, 3.2277e-03, 1.8063e-01, 3.2950e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0028, 0.1096, 0.1939, 0.3688, 0.3025, 0.3176], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.1062, 0.0643, 0.1000, 0.1003, 0.1002], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([795.4528], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3000 th loss0 : 483.9504, test rmse : 72.6858, test mnll: : 6.6384
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.9749e+03, 5.0379e+01, 1.5182e+01, 1.7727e-03, 1.1371e-01, 1.9347e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0027, 0.1051, 0.2099, 0.3690, 0.3073, 0.3192], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.0921, 0.0637, 0.0999, 0.0987, 0.1007], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([826.3812], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3200 th loss0 : 474.3909, test rmse : 70.5889, test mnll: : 6.8591
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.0922e+04, 5.6486e+01, 1.2434e+01, 9.6793e-04, 6.5121e-02, 1.1316e-02],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0902, 0.2212, 0.3689, 0.3031, 0.3197], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0006, 0.1014, 0.0632, 0.0999, 0.0985, 0.1004], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([825.6928], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3400 th loss0 : 484.0728, test rmse : 72.0452, test mnll: : 6.5891
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.1945e+04, 6.2101e+01, 8.6824e+00, 5.3329e-04, 3.9133e-02, 6.6332e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0862, 0.2277, 0.3689, 0.3027, 0.3190], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0999, 0.0617, 0.1000, 0.1002, 0.0999], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([823.3807], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3600 th loss0 : 486.5473, test rmse : 74.4982, test mnll: : 6.8554
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2253e+04, 6.9469e+01, 6.4902e+00, 2.8605e-04, 2.3394e-02, 3.7926e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0842, 0.2098, 0.3690, 0.3043, 0.3197], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.1025, 0.0723, 0.1000, 0.0996, 0.1005], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([826.6064], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 3800 th loss0 : 482.6352, test rmse : 73.4018, test mnll: : 6.6984
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2450e+04, 6.7309e+01, 6.0358e+00, 1.5800e-04, 1.5516e-02, 2.3351e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025, 0.0824, 0.1955, 0.3689, 0.3023, 0.3189], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0973, 0.0801, 0.1000, 0.1007, 0.1001], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([851.9102], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]
# 4000 th loss0 : 486.8281, test rmse : 70.9994, test mnll: : 6.8344
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2463e+04, 8.2153e+01, 6.6481e+00, 8.5442e-05, 1.0082e-02, 1.3904e-03],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0026, 0.0689, 0.2169, 0.3689, 0.3041, 0.3190], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([0.0007, 0.0934, 0.0741, 0.1000, 0.0999, 0.1002], device='cuda:0',
#        grad_fn=<SqueezeBackward0>) tensor([810.6770], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 4, 4, 4, 4, 4]

# %% [markdown]
# ### summary

# %%
wl_mean1,wl_std1 = np.asarray(rep_loss_history_list_w).mean(axis = 0).round(3), np.asarray(rep_loss_history_list_w).std(axis = 0).round(3)
el_mean1,el_std1 = np.asarray(rep_loss_history_list_e).mean(axis = 0).round(3), np.asarray(rep_loss_history_list_e).std(axis = 0).round(3)


wr_mean1,wr_std1 = np.asarray(rep_rmse_history_list_w).mean(axis = 0).round(3), np.asarray(rep_rmse_history_list_w).std(axis = 0).round(3)
er_mean1,er_std1 = np.asarray(rep_rmse_history_list_e).mean(axis = 0).round(3), np.asarray(rep_rmse_history_list_e).std(axis = 0).round(3)

# %%
np.arange(5,10)
# Out:
# array([5, 6, 7, 8, 9])

# %%
import seaborn as sns
sns.set()
sns.set_style('white')
#sns.set_style('whitegrid')
import matplotlib
plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.cal'] = 'stix:italic'
#plt.rc('font', weight='bold')

# current_palette = sns.color_palette(sns.hls_palette(8+1, l=.5, s=1.0))
# sns.palplot(current_palette)
# current_palette = np.asarray(current_palette)

# %%
figsiz = (7,5)
#figsiz = (5,3.5)

# %%
current_palette = sns.color_palette(sns.hls_palette(15+1, l=.5, s=1.0))
sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %%
figsiz = (7,5)
markersiz = 8
#figsiz = (5,3.5)

# %% [markdown]
# ### loss

# %%
save_figname = filename + '_loss'+ '_Q'+str(setting_dict['Num_Q']) + '_spt' + str(num_spt1) + '_esti'
save_figname
# Out:
# 'airline_loss_Q6_spt4_esti'

# %%
idx = observed_period*np.arange(len(wl_mean1))

plt.figure(figsize = figsiz)

idxh = 0
plt.plot(idx, wl_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'SVSS Ws M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  wl_mean1 - wl_std1,
                  wl_mean1 + wl_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])



idxh = 9
plt.plot(idx,el_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'SVSS' '       M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  el_mean1 - el_std1,
                  el_mean1 + el_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])



plt.xlabel('iteration',fontsize = 20)
plt.ylabel('loss',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)
plt.ticklabel_format(axis='x',style='sci',scilimits=(0,0))
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))


plt.ylim([.41*1e3,.66*1e3]) #airline





leg = plt.legend(loc='best', fontsize = 17.5)

for line in leg.get_lines():
    line.set_linewidth(3) 
plt.gca().yaxis.get_offset_text().set_size(17)
plt.gca().xaxis.get_offset_text().set_size(15)

plt.show()

# %% [markdown]
# ### rmse

# %%
idx = observed_period*np.arange(len(wl_mean1))
plt.figure(figsize = figsiz)

idxh = 0
plt.plot(idx,wr_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'weight M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  wr_mean1 - wr_std1,
                  wr_mean1 + wr_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])




idxh = 9
plt.plot(idx,er_mean1,color =  current_palette[idxh],marker = 'd',markersize = markersiz,label = 'equal M={0}x{1}'.format(setting_dict['Num_Q'],num_spt1))
plt.fill_between( idx,
                  er_mean1 - er_std1,
                  er_mean1 + er_std1,
                  alpha = 0.25, edgecolor = current_palette[idxh], facecolor =  current_palette[idxh])





plt.xlabel('iteration',fontsize = 20)
plt.ylabel('rmse',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=10)
plt.locator_params(axis='x', nbins=6)
plt.ticklabel_format(axis='x',style='sci',scilimits=(0,0))
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.gca().yaxis.get_offset_text().set_size(17)
plt.gca().xaxis.get_offset_text().set_size(17)




plt.show()

# %%
idx = 2

# %% [markdown]
# # weight sampling

# %%
ith_model = rep_model_history_list_w[idx]

# %%
with torch.no_grad():
    pred_train_mu, pred_train_var = ith_model._predict_exact(inputs_new=x_train)
    pred_test_mu, pred_test_var = ith_model._predict_exact(inputs_new=x_test)

# %%
figsiz = (7,5)

ith = 7
plt.figure(figsize = figsiz)


plt.plot(x_train.cpu().data.numpy().squeeze(),y_train.cpu().data.numpy().squeeze(),'r.',markersize = 8, label='train')
plt.plot(x_test.cpu().data.numpy().squeeze(),y_test.cpu().data.numpy().squeeze(),'b.',markersize = 8, label='test')

plt.plot(x_train.cpu().data.numpy().squeeze(),pred_train_mu.cpu().data.numpy().squeeze(),'k',linewidth = 2, label='pred mu')

plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() + 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() - 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith], label='pred std')

plt.plot(x_test.cpu().data.numpy().squeeze(),pred_test_mu.cpu().data.numpy().squeeze() ,'k',linewidth = 2)
plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() + 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() - 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith])



plt.xlabel('x',fontsize = 20)
plt.ylabel('y',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)



leg = plt.legend(loc='best', fontsize = 15)
for line in leg.get_lines():
    line.set_linewidth(4) 
    line.set_markersize(4) 

plt.show()
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze() + 2*prede_test_var.sqrt().cpu().data.numpy().squeeze() ,'g')
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze(),'g')
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze() - 2*prede_test_var.sqrt().cpu().data.numpy().squeeze() ,'g')

# %% [markdown]
# # equal sampling

# %%
ith_model = rep_model_history_list_e[idx]

# %%
with torch.no_grad():
    pred_train_mu, pred_train_var = ith_model._predict_exact(inputs_new=x_train)
    pred_test_mu, pred_test_var = ith_model._predict_exact(inputs_new=x_test)

# %%
figsiz = (7,5)

ith = 7
plt.figure(figsize = figsiz)


plt.plot(x_train.cpu().data.numpy().squeeze(),y_train.cpu().data.numpy().squeeze(),'r.',markersize = 8, label='train')
plt.plot(x_test.cpu().data.numpy().squeeze(),y_test.cpu().data.numpy().squeeze(),'b.',markersize = 8, label='test')

plt.plot(x_train.cpu().data.numpy().squeeze(),pred_train_mu.cpu().data.numpy().squeeze(),'k',linewidth = 2, label='pred mu')

plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() + 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_train_mu.cpu().data.numpy().squeeze() - 2*pred_train_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith], label='pred std')

plt.plot(x_test.cpu().data.numpy().squeeze(),pred_test_mu.cpu().data.numpy().squeeze() ,'k',linewidth = 2)
plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() + 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  pred_test_mu.cpu().data.numpy().squeeze() - 2*pred_test_var.sqrt().cpu().data.numpy().squeeze(),
                  alpha = 0.25, edgecolor = current_palette[ith], facecolor =  current_palette[ith])



plt.xlabel('x',fontsize = 20)
plt.ylabel('y',fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)



leg = plt.legend(loc='best', fontsize = 15)
for line in leg.get_lines():
    line.set_linewidth(4) 
    line.set_markersize(4) 

plt.show()
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze() + 2*prede_test_var.sqrt().cpu().data.numpy().squeeze() ,'g')
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze(),'g')
# plt.plot(x_full.cpu().data.numpy().squeeze(),prede_test_mu.cpu().data.numpy().squeeze() - 2*prede_test_var.sqrt().cpu().data.numpy().squeeze() ,'g')
