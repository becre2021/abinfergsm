# %%
import pickle
import copy
import torch
import time
import numpy as np
np.set_printoptions(precision = 4)

import sys
sys.path.append('./../')

from datasets.dataset import _load_collection_real,_load_collection_syn
from models_utility.construct_models import _initialize_SMkernelhyp,_make_gpmodel
from models_utility.param_gp import Param



from kernels.RBF_kernel import RBF
from kernels.SM_kernel import SM
from scipy.linalg import norm as fnorm


from utility.eval_metric import _evaluate_metric
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()
sns.set_style('white')



plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
#plt.rc('font', weight='bold')

current_palette = sns.color_palette(sns.hls_palette(10+1, l=.4, s=1.0))
sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %%
random_seed = 1000
device = True

#filename = 'SM_Q2_exp1'
filename = 'SM_Q5_exp1_unequal_v3'
x_train, x_test, x_full, y_train, y_test,y_full,Dataset = _load_collection_syn(filename, cuda_option=device)
# Out:
# #loaded collection#
# /home/yohan/Myenv/Summit_Conference/ICML21_SMapproximation_Sumbit/test

# %%
setting_dict = {}
setting_dict['random_seed'] = random_seed
setting_dict['init_sample_num'] = 1000
setting_dict['input_dim'] = 1

setting_dict['Num_Q'] = 8
setting_dict['num_sample_pt'] = 3
setting_dict['num_batch'] = 1

setting_dict['lr_hyp'] = 0.001        

setting_dict['kl_option'] = True   
setting_dict['iter'] = 8000       
setting_dict['num_rep'] = 1
setting_dict['weight_rate'] = 0.05  
setting_dict['noise_err'] = 0.01*y_train.std()



setting_dict = _initialize_SMkernelhyp( x_train,y_train, setting_dict, random_seed)

# %%
#ith_model_name = 'equal_reg'
ith_model_name = 'weight_reg'

model = _make_gpmodel(model_name=ith_model_name, setting_dict=setting_dict, device=device)
model._set_data(x_train,y_train)

# %%
optimizable_param =  [*model.parameters(),model.likelihood.variance]
optimizable_param
# Out:
# [sf2 : tensor([0.], device='cuda:0'), weight : tensor([[0.2185],
#          [0.2413],
#          [0.0763],
#          [0.0180],
#          [0.0723],
#          [0.2364],
#          [0.0129],
#          [0.0302]], device='cuda:0'), std : tensor([[-3.8327],
#          [-3.0964],
#          [-3.5288],
#          [-3.4848],
#          [-6.9078],
#          [-6.9078],
#          [-3.4727],
#          [-2.5224]], device='cuda:0'), mu : tensor([[2.3787],
#          [1.8541],
#          [2.5964],
#          [1.8337],
#          [2.3888],
#          [2.3842],
#          [1.8077],
#          [2.5971]], device='cuda:0'), std_prior : tensor([[-3.3928],
#          [-5.2960],
#          [-3.2436],
#          [-2.6050],
#          [-2.6933],
#          [-6.6243],
#          [-2.8873],
#          [-3.2605]], device='cuda:0'), mu_prior : tensor([[-0.9668],
#          [-2.2254],
#          [-0.7595],
#          [-0.9781],
#          [-3.3675],
#          [-1.6025],
#          [-0.8985],
#          [-1.8781]], device='cuda:0'), noise_variance : tensor([-3.3278], device='cuda:0')]

# %%
optimizer = torch.optim.Adam(optimizable_param ,
                               lr=setting_dict['lr_hyp'],
                               betas=(0.9, 0.99),
                               eps=1e-08,
                               weight_decay=0.0)

# %%
observe_period = 100

# %%
for i in range(setting_dict['iter'] + 1):


    ith_tic = time.time()    
    optimizer.zero_grad()    
    ith_loss = model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])    
    
    ith_loss.backward()
    optimizer.step()

    
    
    with torch.no_grad():
        pred_train_mu, pred_train_var = model._predict(inputs_new=x_train)
        pred_test_mu, pred_test_var = model._predict(inputs_new=x_test)


    # out1 : root mean square (rmse)
    # out2 : mean negative log likelihood (mnll)
    #ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)
    ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)




    if i % observe_period == 0 :
        print('%d th loss0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,ith_loss.cpu().data.numpy(),ith_rmse,ith_mnll))
        try:
            print('self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance')            
            print(model.weight.exp().squeeze(),model.mu.exp().squeeze(),model.std.exp().squeeze(),model.likelihood.variance.transform()**2)

            print('\n')
            print('self.num_samplept_list_at')
            print(model.num_samplept_list_at)
        except:
            pass
        
        print('')
# Out:
# 0 th loss0 : 33498737.1987, test rmse : 3.0327, test mnll: : 1425.4262
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.2455, 1.2741, 1.0804, 1.0192, 1.0761, 1.2680, 1.0140, 1.0317],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7799,  6.3922, 13.4285,  6.2636, 10.8891, 10.8392,  6.1023, 13.4380],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0216, 0.0452, 0.0293, 0.0306, 0.0010, 0.0010, 0.0310, 0.0802],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0013], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 100 th loss0 : 27907044.6707, test rmse : 8.0420, test mnll: : 13082.8931
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3154, 1.3349, 1.1483, 1.0597, 1.1315, 1.2892, 1.0327, 1.0966],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7886,  6.4012, 13.5194,  6.3033, 10.8764,  9.8839,  6.1159, 13.3602],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0210, 0.0451, 0.0298, 0.0307, 0.0011, 0.0010, 0.0303, 0.0781],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0016], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 200 th loss0 : 23307559.0044, test rmse : 5.3051, test mnll: : 1839.6158
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.3857, 1.3840, 1.2088, 1.0914, 1.1784, 1.2892, 1.0538, 1.1392],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8020,  6.4185, 13.4800,  6.2697, 10.8408,  9.0256,  6.1974, 13.4307],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0208, 0.0440, 0.0305, 0.0306, 0.0011, 0.0010, 0.0305, 0.0776],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0018], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 300 th loss0 : 19614677.2981, test rmse : 9.5382, test mnll: : 4017.8423
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.4122, 1.4309, 1.2644, 1.1297, 1.2162, 1.2889, 1.1004, 1.1751],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7892,  6.3871, 13.4538,  6.2808, 10.8544,  8.2722,  6.1857, 13.4331],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0204, 0.0434, 0.0303, 0.0307, 0.0011, 0.0010, 0.0314, 0.0773],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0021], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 400 th loss0 : 16619148.0664, test rmse : 5.2711, test mnll: : 794.7755
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.4525, 1.4770, 1.3095, 1.1634, 1.2717, 1.2887, 1.1083, 1.1992],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7976,  6.4154, 13.4577,  6.3084, 10.8510,  7.5974,  6.1566, 13.5081],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0201, 0.0429, 0.0304, 0.0305, 0.0012, 0.0010, 0.0315, 0.0754],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0025], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 500 th loss0 : 14226999.5197, test rmse : 5.9566, test mnll: : 2809.6003
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5042, 1.5107, 1.3611, 1.1923, 1.3260, 1.2912, 1.1222, 1.2417],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7991,  6.4057, 13.5374,  6.3053, 10.8580,  6.9851,  6.1352, 13.3845],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0200, 0.0427, 0.0308, 0.0305, 0.0012, 0.0010, 0.0314, 0.0741],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0028], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 600 th loss0 : 12013534.5006, test rmse : 11.8720, test mnll: : 2726.1931
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.5413, 1.5500, 1.4327, 1.2176, 1.3842, 1.3593, 1.1389, 1.2919],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7892,  6.3581, 13.4833,  6.3224, 10.8661,  6.4157,  6.1490, 13.4383],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0198, 0.0428, 0.0305, 0.0305, 0.0013, 0.0011, 0.0313, 0.0717],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0032], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 700 th loss0 : 10283522.7053, test rmse : 38.8846, test mnll: : 44801.0460
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6093, 1.6246, 1.4824, 1.2690, 1.4506, 1.4381, 1.1596, 1.3373],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7917,  6.2868, 13.4999,  6.4196, 10.8555,  5.9163,  6.1581, 13.3959],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0197, 0.0430, 0.0309, 0.0307, 0.0013, 0.0011, 0.0313, 0.0703],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0038], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 800 th loss0 : 8943627.5248, test rmse : 5.1247, test mnll: : 1437.9320
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6690, 1.6873, 1.5295, 1.3158, 1.5072, 1.4423, 1.2111, 1.3761],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7889,  6.2615, 13.4644,  6.3909, 10.8516,  5.4482,  6.1254, 13.4214],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0196, 0.0426, 0.0306, 0.0300, 0.0014, 0.0011, 0.0315, 0.0690],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0044], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 900 th loss0 : 7559270.3786, test rmse : 7.9267, test mnll: : 2009.1579
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.7456, 1.7678, 1.5758, 1.3504, 1.5864, 1.4424, 1.2530, 1.4232],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7821,  6.2539, 13.4219,  6.3877, 10.8731,  5.0160,  6.1294, 13.4963],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0193, 0.0425, 0.0310, 0.0296, 0.0015, 0.0011, 0.0314, 0.0687],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0050], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1000 th loss0 : 6558467.1824, test rmse : 11.4665, test mnll: : 5618.0876
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8081, 1.8372, 1.6178, 1.3888, 1.6606, 1.4416, 1.3058, 1.4683],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7882,  6.2642, 13.4506,  6.3940, 10.8595,  4.6178,  6.1023, 13.5837],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0191, 0.0425, 0.0307, 0.0294, 0.0015, 0.0011, 0.0314, 0.0677],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0058], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1100 th loss0 : 5633650.1769, test rmse : 12.6684, test mnll: : 1606.4384
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8553, 1.9279, 1.6508, 1.4146, 1.7414, 1.4402, 1.3504, 1.5394],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7938,  6.2699, 13.4062,  6.3680, 10.8657,  4.2510,  6.1463, 13.5069],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0188, 0.0424, 0.0308, 0.0290, 0.0016, 0.0011, 0.0310, 0.0681],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0066], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1200 th loss0 : 4910454.3464, test rmse : 9.7338, test mnll: : 3324.9198
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.9518, 2.0295, 1.6876, 1.4543, 1.8079, 1.4377, 1.4160, 1.5834],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7785,  6.2012, 13.4139,  6.3952, 10.8564,  3.9135,  6.1620, 13.4863],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0189, 0.0423, 0.0305, 0.0283, 0.0017, 0.0011, 0.0306, 0.0677],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0077], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
# 1300 th loss0 : 4272437.8182, test rmse : 6.4035, test mnll: : 1089.5957
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.0402, 2.1416, 1.7293, 1.4889, 1.8765, 1.4337, 1.4935, 1.6541],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7865,  6.2197, 13.4270,  6.3895, 10.8543,  3.6028,  6.1671, 13.4729],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0190, 0.0424, 0.0306, 0.0280, 0.0017, 0.0011, 0.0307, 0.0675],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0089], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1400 th loss0 : 3707744.0559, test rmse : 21.2632, test mnll: : 8419.6760
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.1184, 2.2326, 1.8031, 1.5293, 1.9509, 1.4257, 1.5553, 1.7425],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7889,  6.2211, 13.4302,  6.3899, 10.8580,  3.3169,  6.1232, 13.5079],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0190, 0.0423, 0.0305, 0.0277, 0.0018, 0.0011, 0.0308, 0.0670],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0104], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1500 th loss0 : 3256478.8510, test rmse : 8.3515, test mnll: : 1561.2650
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.1950, 2.3572, 1.8876, 1.5747, 2.0632, 1.4152, 1.6308, 1.8395],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8591,  6.2219, 13.4385,  6.3900, 10.7783,  3.0538,  6.1314, 13.4528],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0189, 0.0422, 0.0306, 0.0274, 0.0019, 0.0011, 0.0313, 0.0665],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0123], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1600 th loss0 : 2882433.3721, test rmse : 31.6387, test mnll: : 4681.6035
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2481, 2.4948, 1.9851, 1.6176, 2.1372, 1.3925, 1.7023, 1.9308],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8590,  6.2205, 13.4971,  6.3705, 10.7813,  2.8117,  6.1254, 13.3820],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0189, 0.0423, 0.0306, 0.0266, 0.0020, 0.0011, 0.0311, 0.0651],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0144], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1700 th loss0 : 2519141.5736, test rmse : 7.5083, test mnll: : 984.5739
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.3074, 2.5913, 2.0651, 1.6822, 2.2280, 1.3570, 1.8076, 2.0097],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8460,  6.0037, 13.4334,  6.3843, 10.7772,  2.5889,  6.2917, 13.4375],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0188, 0.0420, 0.0306, 0.0259, 0.0021, 0.0011, 0.0314, 0.0631],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0170], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1800 th loss0 : 2188006.0664, test rmse : 7.2058, test mnll: : 612.1172
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.3605, 2.5997, 2.1491, 1.7556, 2.3444, 1.3001, 1.8866, 2.1123],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8232,  5.6968, 13.4879,  6.4167, 10.7704,  2.3839,  6.3105, 13.4183],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0187, 0.0420, 0.0310, 0.0258, 0.0022, 0.0011, 0.0312, 0.0608],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0199], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 1900 th loss0 : 1881122.1542, test rmse : 9.6391, test mnll: : 1199.4035
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.4719, 2.5999, 2.2306, 1.8243, 2.4465, 1.2229, 1.9572, 2.2067],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8411,  5.3164, 13.5790,  6.4011, 10.7723,  2.1952,  6.3157, 13.3907],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0185, 0.0420, 0.0314, 0.0255, 0.0023, 0.0011, 0.0310, 0.0597],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0239], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2000 th loss0 : 1607261.9921, test rmse : 9.5077, test mnll: : 519.6573
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.5717, 2.5974, 2.2751, 1.9050, 2.5352, 1.1312, 2.0315, 2.2747],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8510,  4.9267, 13.4760,  6.4068, 10.7778,  2.0216,  6.3124, 13.4405],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0185, 0.0420, 0.0317, 0.0252, 0.0024, 0.0010, 0.0305, 0.0592],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0272], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2100 th loss0 : 1371130.4189, test rmse : 7.6280, test mnll: : 496.0443
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.6694, 2.5925, 2.3448, 1.9714, 2.6445, 1.0329, 2.1123, 2.3376],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8541,  4.5488, 13.4528,  6.4241, 10.7727,  1.8619,  6.3048, 13.4384],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0184, 0.0419, 0.0324, 0.0252, 0.0025, 0.0010, 0.0303, 0.0593],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0309], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2200 th loss0 : 1183313.4663, test rmse : 6.6183, test mnll: : 257.9172
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.7757, 2.5842, 2.4156, 2.0361, 2.7777, 0.9419, 2.1847, 2.4025],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8467,  4.1925, 13.4706,  6.3771, 10.7855,  1.7149,  6.3480, 13.4284],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0185, 0.0419, 0.0330, 0.0248, 0.0026, 0.0009, 0.0300, 0.0594],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0357], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2300 th loss0 : 1015647.9004, test rmse : 6.3250, test mnll: : 220.2472
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.8951, 2.5711, 2.5133, 2.0982, 2.9179, 0.8584, 2.2886, 2.4628],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8515,  3.8613, 13.4557,  6.3115, 10.7763,  1.5796,  6.4158, 13.3962],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0184, 0.0418, 0.0329, 0.0247, 0.0027, 0.0009, 0.0297, 0.0588],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0418], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2400 th loss0 : 876372.6190, test rmse : 6.6983, test mnll: : 261.5501
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.0327, 2.5483, 2.5843, 2.1683, 3.0485, 0.7804, 2.4224, 2.5570],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8466,  3.5550, 13.4028,  6.3273, 10.7836,  1.4552,  6.3876, 13.5002],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0186, 0.0416, 0.0325, 0.0245, 0.0028, 0.0008, 0.0294, 0.0583],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0484], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2500 th loss0 : 762139.1557, test rmse : 3.7299, test mnll: : 65.8354
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.1885, 2.5113, 2.6742, 2.2406, 3.1826, 0.7089, 2.5138, 2.6740],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8537,  3.2725, 13.4039,  6.3176, 10.7688,  1.3407,  6.4054, 13.4922],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0184, 0.0413, 0.0326, 0.0245, 0.0029, 0.0008, 0.0291, 0.0579],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0564], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
# 2600 th loss0 : 663781.7957, test rmse : 6.3090, test mnll: : 222.8387
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.3323, 2.4509, 2.7271, 2.3064, 3.3256, 0.6440, 2.5595, 2.8159],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8392,  3.0124, 13.3945,  6.3164, 10.7738,  1.2353,  6.4114, 13.5540],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0185, 0.0408, 0.0324, 0.0244, 0.0031, 0.0007, 0.0289, 0.0572],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0656], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2700 th loss0 : 599396.4301, test rmse : 6.3774, test mnll: : 157.8076
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.4854, 2.3617, 2.7923, 2.4088, 3.4768, 0.5863, 2.6511, 2.9573],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8383,  2.7730, 13.3981,  6.2975, 10.7605,  1.1384,  6.4117, 13.4367],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0187, 0.0400, 0.0323, 0.0243, 0.0032, 0.0007, 0.0284, 0.0564],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0768], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2800 th loss0 : 513725.8480, test rmse : 8.1656, test mnll: : 205.9173
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.6332, 2.2363, 2.8917, 2.4966, 3.6287, 0.5326, 2.7363, 3.0657],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8643,  2.5526, 13.4759,  6.3117, 10.7810,  1.0492,  6.4134, 13.3772],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0188, 0.0389, 0.0324, 0.0241, 0.0033, 0.0007, 0.0281, 0.0570],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0890], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 2900 th loss0 : 456039.0077, test rmse : 4.9413, test mnll: : 63.2141
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.7942, 2.0791, 2.9638, 2.6188, 3.7980, 0.4855, 2.8355, 3.1722],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8545,  2.3498, 13.4770,  6.2831, 10.7856,  0.9672,  6.3993, 13.3959],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0189, 0.0373, 0.0327, 0.0240, 0.0035, 0.0007, 0.0277, 0.0566],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.1040], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 4, 3, 3, 2, 2, 3, 4]
#
# 3000 th loss0 : 407377.8367, test rmse : 5.0055, test mnll: : 62.5717
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.9637, 1.9257, 3.0647, 2.6855, 3.9204, 0.4402, 2.9372, 3.2547],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8454,  2.1631, 13.4670,  6.2979, 10.7787,  0.8917,  6.4185, 13.3746],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0190, 0.0354, 0.0328, 0.0238, 0.0036, 0.0007, 0.0275, 0.0565],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.1177], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 3, 3, 2, 2, 3, 4]
#
# 3100 th loss0 : 368445.9413, test rmse : 7.5142, test mnll: : 114.1071
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.1565, 1.7666, 3.1855, 2.8095, 4.0942, 0.4000, 3.0632, 3.3725],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8288,  1.9914, 13.4278,  6.3011, 10.7744,  0.8223,  6.4109, 13.3473],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0189, 0.0331, 0.0323, 0.0239, 0.0037, 0.0007, 0.0274, 0.0565],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.1383], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 3, 3, 3, 2, 2, 3, 5]
#
# 3200 th loss0 : 335586.8103, test rmse : 7.5840, test mnll: : 106.7392
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.3611, 1.6095, 3.3543, 2.9518, 4.2706, 0.3633, 3.2105, 3.5492],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8529,  1.8333, 13.4058,  6.3007, 10.7733,  0.7585,  6.4137, 13.3932],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0190, 0.0307, 0.0322, 0.0237, 0.0039, 0.0007, 0.0274, 0.0570],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.1626], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 3, 3, 3, 2, 2, 3, 5]
#
# 3300 th loss0 : 308479.1365, test rmse : 5.1009, test mnll: : 45.4691
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.5636, 1.4628, 3.4225, 3.0374, 4.4606, 0.3292, 3.3502, 3.8136],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8451,  1.6879, 13.2579,  6.2997, 10.7662,  0.6998,  6.4128, 13.4353],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0192, 0.0284, 0.0322, 0.0235, 0.0040, 0.0007, 0.0273, 0.0565],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.1890], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 3, 3, 3, 2, 2, 3, 5]
#
# 3400 th loss0 : 282926.8383, test rmse : 3.6310, test mnll: : 22.7633
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.7337, 1.3467, 3.4167, 3.1734, 4.5711, 0.2992, 3.4954, 4.0639],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8290,  1.5540, 12.9868,  6.2994, 10.7599,  0.6458,  6.3987, 13.4078],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0193, 0.0262, 0.0322, 0.0233, 0.0041, 0.0008, 0.0266, 0.0552],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.2184], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 3500 th loss0 : 261442.3635, test rmse : 6.1282, test mnll: : 49.7318
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.9807, 1.2337, 3.3879, 3.3274, 4.6816, 0.2722, 3.6380, 4.2908],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8350,  1.4309, 12.4481,  6.3239, 10.7607,  0.5962,  6.3969, 13.4372],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0198, 0.0242, 0.0322, 0.0232, 0.0042, 0.0008, 0.0257, 0.0546],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.2545], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 3600 th loss0 : 239696.3319, test rmse : 3.9713, test mnll: : 22.4604
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.2403, 1.1231, 3.3383, 3.4259, 4.8256, 0.2471, 3.7846, 4.5096],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8412,  1.3175, 11.7735,  6.2988, 10.7505,  0.5506,  6.3774, 13.4285],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0203, 0.0223, 0.0321, 0.0231, 0.0043, 0.0008, 0.0252, 0.0537],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.2904], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 3700 th loss0 : 220444.6724, test rmse : 4.7086, test mnll: : 25.6824
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.5087, 1.0185, 3.2612, 3.5466, 4.9933, 0.2237, 3.9682, 4.7603],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.8344,  1.2132, 11.0062,  6.3024, 10.7431,  0.5088,  6.4172, 13.4471],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0211, 0.0205, 0.0321, 0.0227, 0.0044, 0.0009, 0.0249, 0.0522],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3365], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 3800 th loss0 : 206951.0728, test rmse : 7.3160, test mnll: : 41.0466
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.7044, 0.9243, 3.5384, 3.6985, 5.0473, 0.2034, 4.1016, 4.9664],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7374,  1.1173, 10.8599,  6.3069, 10.5624,  0.4703,  6.3898, 13.4253],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0216, 0.0189, 0.0320, 0.0226, 0.0045, 0.0009, 0.0248, 0.0513],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.3790], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
# 3900 th loss0 : 198322.5668, test rmse : 8.3089, test mnll: : 51.8125
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9432, 0.8377, 3.7690, 3.8383, 5.0222, 0.1842, 4.2709, 5.2161],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.7352,  1.0290, 10.8384,  6.2859, 10.3677,  0.4350,  6.4004, 13.3952],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0224, 0.0174, 0.0302, 0.0222, 0.0045, 0.0009, 0.0244, 0.0493],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.4462], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4000 th loss0 : 189849.7594, test rmse : 7.2773, test mnll: : 43.8142
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.1800, 0.7581, 3.9812, 3.9885, 4.9776, 0.1671, 4.4892, 5.4684],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.5820,  0.9477, 10.8228,  6.3055, 10.0934,  0.4027,  6.4042, 13.4237],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0226, 0.0160, 0.0294, 0.0220, 0.0045, 0.0010, 0.0241, 0.0484],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.5298], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4100 th loss0 : 181542.4960, test rmse : 4.0815, test mnll: : 11.1578
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.2229, 0.6860, 4.2787, 4.1512, 4.9015, 0.1517, 4.6497, 5.7451],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([10.2269,  0.8729, 10.8425,  6.2848,  9.6965,  0.3731,  6.3831, 13.4108],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0227, 0.0147, 0.0287, 0.0217, 0.0045, 0.0010, 0.0237, 0.0475],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.6492], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4200 th loss0 : 172009.1767, test rmse : 3.1945, test mnll: : 6.6357
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.1879, 0.6213, 4.4854, 4.3845, 4.7736, 0.1375, 4.8096, 6.0162],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 9.7079,  0.8041, 10.8287,  6.3066,  9.1836,  0.3460,  6.3892, 13.3828],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0227, 0.0135, 0.0281, 0.0215, 0.0044, 0.0011, 0.0231, 0.0472],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.7507], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4300 th loss0 : 162745.4815, test rmse : 6.8524, test mnll: : 20.8745
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.1197, 0.5626, 4.7184, 4.5828, 4.5816, 0.1247, 5.0231, 6.3549],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 9.1023,  0.7408, 10.8261,  6.2830,  8.5951,  0.3213,  6.3849, 13.4154],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0226, 0.0124, 0.0275, 0.0212, 0.0044, 0.0011, 0.0227, 0.0470],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.8617], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4400 th loss0 : 154262.0997, test rmse : 6.8410, test mnll: : 19.8540
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.9960, 0.5109, 4.9708, 4.7805, 4.3136, 0.1130, 5.2400, 6.7227],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 8.4586,  0.6826, 10.8229,  6.2946,  7.9789,  0.2988,  6.3827, 13.3852],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0226, 0.0114, 0.0271, 0.0211, 0.0043, 0.0012, 0.0226, 0.0465],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.9593], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4500 th loss0 : 148524.0615, test rmse : 5.1685, test mnll: : 11.3886
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.8099, 0.4630, 5.2607, 5.0185, 3.9989, 0.1024, 5.5054, 7.0790],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 7.8221,  0.6290, 10.8234,  6.2766,  7.3735,  0.2785,  6.3630, 13.3910],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0225, 0.0105, 0.0266, 0.0211, 0.0043, 0.0012, 0.0222, 0.0467],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([1.0931], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4600 th loss0 : 138340.7720, test rmse : 7.6329, test mnll: : 18.8516
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.5437, 0.4198, 5.5268, 5.2934, 3.6730, 0.0928, 5.7654, 7.4683],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 7.2157,  0.5797, 10.8214,  6.3023,  6.7948,  0.2603,  6.3950, 13.3736],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0223, 0.0097, 0.0261, 0.0212, 0.0042, 0.0012, 0.0219, 0.0475],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([1.2063], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4700 th loss0 : 133261.2865, test rmse : 7.2394, test mnll: : 15.9099
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.2698, 0.3812, 5.8129, 5.5717, 3.7964, 0.0841, 5.9724, 7.8897],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.6425,  0.5343, 10.8370,  6.2682,  6.3772,  0.2442,  6.3498, 13.3746],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0223, 0.0089, 0.0257, 0.0215, 0.0045, 0.0012, 0.0217, 0.0483],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([1.3149], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4800 th loss0 : 130069.1383, test rmse : 5.6195, test mnll: : 8.8742
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.6958, 0.3463, 6.1730, 5.6193, 4.0730, 0.0762, 6.0884, 8.3682],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3595,  0.4926, 10.8340,  6.0661,  6.2592,  0.2302,  6.1579, 13.3702],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0226, 0.0082, 0.0255, 0.0218, 0.0048, 0.0013, 0.0218, 0.0489],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([1.4058], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 4900 th loss0 : 125527.0765, test rmse : 7.7766, test mnll: : 15.0419
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.1194, 0.3144, 6.4788, 5.5884, 4.2255, 0.0690, 6.1660, 8.5414],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3621,  0.4542, 10.7968,  5.8493,  6.2613,  0.2187,  6.0561, 12.7922],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0238, 0.0075, 0.0252, 0.0221, 0.0050, 0.0013, 0.0222, 0.0492],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([1.6844], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 5000 th loss0 : 115104.7762, test rmse : 4.0072, test mnll: : 4.9140
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.5233, 0.2856, 6.7923, 5.3500, 4.4285, 0.0625, 6.1110, 8.3863],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3699,  0.4189, 10.8112,  5.4851,  6.2631,  0.2098,  5.8204, 11.8209],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0246, 0.0070, 0.0249, 0.0218, 0.0052, 0.0013, 0.0223, 0.0491],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([2.0214], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 5100 th loss0 : 106021.6454, test rmse : 3.3980, test mnll: : 3.1591
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.9000, 0.2598, 7.1603, 5.0192, 4.6872, 0.0566, 5.8971, 8.2879],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3703,  0.3865, 10.8337,  5.0903,  6.2691,  0.2042,  5.4121, 10.8653],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0258, 0.0064, 0.0248, 0.0215, 0.0056, 0.0013, 0.0222, 0.0492],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([2.3314], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
# 5200 th loss0 : 101038.1952, test rmse : 4.5054, test mnll: : 4.9351
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.3339, 0.2365, 7.4973, 4.6251, 4.9054, 0.0513, 5.5888, 8.4578],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3620,  0.3566, 10.8169,  4.7030,  6.2577,  0.2019,  5.0074, 10.1029],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0263, 0.0060, 0.0247, 0.0209, 0.0058, 0.0013, 0.0220, 0.0498],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([2.5930], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 3, 3, 2, 2, 3, 5]
#
# 5300 th loss0 : 93482.6991, test rmse : 4.4132, test mnll: : 4.3393
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.8009, 0.2150, 7.9543, 4.2267, 5.1589, 0.0465, 5.2049, 8.0794],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3529,  0.3292, 10.8190,  4.3365,  6.2657,  0.2014,  4.6201,  9.3084],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0263, 0.0056, 0.0247, 0.0201, 0.0061, 0.0013, 0.0216, 0.0496],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([2.9055], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 4, 3, 2, 2, 3, 5]
#
# 5400 th loss0 : 88526.4126, test rmse : 5.0611, test mnll: : 5.1617
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.1471, 0.1958, 8.5349, 3.8432, 5.4808, 0.0421, 4.7758, 7.5792],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3628,  0.3040, 10.8013,  3.9963,  6.2574,  0.2014,  4.2584,  8.5710],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0260, 0.0052, 0.0253, 0.0190, 0.0065, 0.0013, 0.0211, 0.0492],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.0808], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 4, 3, 2, 2, 3, 5]
#
# 5500 th loss0 : 84212.7917, test rmse : 3.5917, test mnll: : 3.3819
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([8.5714, 0.1784, 9.0978, 3.4896, 5.6978, 0.0382, 4.3550, 6.9857],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3637,  0.2808, 10.8173,  3.6814,  6.2709,  0.2014,  3.9233,  7.8901],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0261, 0.0049, 0.0256, 0.0178, 0.0067, 0.0013, 0.0203, 0.0484],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2330], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 4, 3, 2, 2, 3, 5]
#
# 5600 th loss0 : 79326.3847, test rmse : 4.0182, test mnll: : 3.7709
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([9.1141, 0.1617, 9.6712, 3.2064, 5.9703, 0.0346, 3.9548, 6.3888],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3469,  0.2595, 10.8194,  3.3912,  6.2565,  0.2014,  3.6140,  7.2619],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0266, 0.0046, 0.0262, 0.0173, 0.0071, 0.0013, 0.0193, 0.0473],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2435], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 3, 4, 2, 2, 2, 3, 4]
#
# 5700 th loss0 : 75810.3664, test rmse : 5.2233, test mnll: : 5.3503
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.8332,  0.1473, 10.2515,  2.9253,  6.1002,  0.0313,  3.5855,  5.8942],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.3446,  0.2400, 10.8259,  3.1239,  6.0910,  0.2014,  3.3289,  6.6825],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0283, 0.0044, 0.0266, 0.0168, 0.0073, 0.0013, 0.0180, 0.0464],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3014], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 2, 4, 2, 2, 2, 3, 4]
#
# 5800 th loss0 : 71947.8615, test rmse : 5.2255, test mnll: : 5.2764
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([10.3084,  0.1344, 10.9797,  2.6603,  5.9291,  0.0285,  3.2879,  6.2729],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 6.0684,  0.2220, 10.8179,  2.8776,  5.6269,  0.2015,  3.0667,  6.3543],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0297, 0.0044, 0.0266, 0.0163, 0.0073, 0.0013, 0.0174, 0.0462],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2957], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 3, 4, 2, 2, 2, 2, 4]
#
# 5900 th loss0 : 69041.6013, test rmse : 6.1572, test mnll: : 6.5127
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([10.2194,  0.1222, 11.7342,  2.4103,  5.6306,  0.0266,  3.0025,  6.7140],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 5.5986,  0.2055, 10.8125,  2.6509,  5.1692,  0.2015,  2.8252,  6.3522],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0297, 0.0043, 0.0273, 0.0155, 0.0073, 0.0013, 0.0169, 0.0461],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.5321], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 3, 4, 2, 2, 2, 2, 4]
#
# 6000 th loss0 : 65820.0676, test rmse : 4.7091, test mnll: : 4.2683
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.9605,  0.1111, 12.5209,  2.1836,  5.2483,  0.0251,  2.7322,  6.9905],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 5.1526,  0.1907, 10.8035,  2.4426,  4.7533,  0.2013,  2.6030,  6.3186],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0295, 0.0041, 0.0280, 0.0148, 0.0072, 0.0013, 0.0163, 0.0456],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.6845], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 2, 5, 2, 2, 2, 2, 4]
#
# 6100 th loss0 : 63913.1694, test rmse : 3.7653, test mnll: : 3.2932
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.5546,  0.1009, 13.2714,  1.9767,  4.8246,  0.0224,  2.4758,  7.3596],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 4.7434,  0.1772, 10.8245,  2.2507,  4.3724,  0.2013,  2.3987,  6.3501],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0291, 0.0043, 0.0290, 0.0138, 0.0070, 0.0013, 0.0154, 0.0462],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.7550], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [5, 2, 5, 2, 2, 2, 2, 4]
#
# 6200 th loss0 : 61711.0207, test rmse : 5.8974, test mnll: : 5.8637
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 9.0287,  0.0913, 14.1358,  1.7920,  4.4084,  0.0200,  2.2478,  7.7964],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 4.3676,  0.1647, 10.7999,  2.0745,  4.0232,  0.2014,  2.2103,  6.3491],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0286, 0.0044, 0.0301, 0.0129, 0.0069, 0.0013, 0.0146, 0.0465],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.6664], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 5, 2, 2, 2, 2, 5]
#
# 6300 th loss0 : 60183.3724, test rmse : 7.4625, test mnll: : 8.5028
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 8.3948,  0.0824, 15.0512,  1.6256,  4.0050,  0.0180,  2.0404,  8.3413],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 4.0219,  0.1533, 10.8258,  1.9124,  3.7025,  0.2014,  2.0372,  6.3253],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0278, 0.0044, 0.0315, 0.0121, 0.0066, 0.0013, 0.0139, 0.0467],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4271], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 5, 2, 2, 2, 2, 5]
#
# 6400 th loss0 : 58961.0252, test rmse : 5.8752, test mnll: : 5.9254
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([ 7.7100,  0.0745, 15.9892,  1.4755,  3.6374,  0.0162,  1.8480,  8.8977],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 3.7039,  0.1431, 10.7878,  1.7631,  3.4072,  0.2014,  1.8780,  6.3496],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0267, 0.0044, 0.0324, 0.0114, 0.0063, 0.0013, 0.0130, 0.0470],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4981], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [4, 2, 5, 2, 2, 2, 2, 5]
# 6500 th loss0 : 57582.6226, test rmse : 6.6752, test mnll: : 6.4409
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([7.0618e+00, 6.7543e-02, 1.7053e+01, 1.3396e+00, 3.2944e+00, 1.4655e-02,
#         1.6713e+00, 9.4902e+00], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 3.4113,  0.1340, 10.8021,  1.6254,  3.1357,  0.2014,  1.7319,  6.3323],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0256, 0.0044, 0.0330, 0.0109, 0.0060, 0.0013, 0.0120, 0.0469],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4577], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 6600 th loss0 : 56677.3077, test rmse : 5.7873, test mnll: : 5.8876
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([6.4456e+00, 6.1089e-02, 1.8089e+01, 1.2140e+00, 2.9869e+00, 1.3272e-02,
#         1.5137e+00, 1.0193e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 3.1421,  0.1261, 10.8051,  1.4991,  2.8859,  0.2014,  1.5973,  6.3471],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0243, 0.0043, 0.0345, 0.0103, 0.0056, 0.0013, 0.0112, 0.0472],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3766], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 6700 th loss0 : 56197.0260, test rmse : 2.6678, test mnll: : 2.5193
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.8534e+00, 5.5363e-02, 1.9303e+01, 1.0996e+00, 2.7071e+00, 1.2026e-02,
#         1.3725e+00, 1.0816e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 2.8944,  0.1194, 10.8175,  1.3839,  2.6560,  0.2014,  1.4727,  6.3531],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0226, 0.0043, 0.0360, 0.0097, 0.0053, 0.0013, 0.0104, 0.0477],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4777], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 6800 th loss0 : 55245.0482, test rmse : 4.9027, test mnll: : 4.5142
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([5.3187e+00, 5.0119e-02, 2.0587e+01, 9.9955e-01, 2.4614e+00, 1.0902e-02,
#         1.2459e+00, 1.1491e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 2.6665,  0.1141, 10.8035,  1.2797,  2.4443,  0.2014,  1.3575,  6.3561],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0209, 0.0043, 0.0365, 0.0094, 0.0051, 0.0013, 0.0099, 0.0481],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4486], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 6900 th loss0 : 54751.5515, test rmse : 4.7744, test mnll: : 4.4416
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.8288e+00, 4.5473e-02, 2.1823e+01, 9.0581e-01, 2.2327e+00, 9.8843e-03,
#         1.1329e+00, 1.2088e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 2.4567,  0.1104, 10.8134,  1.1895,  2.2497,  0.2014,  1.2490,  6.3241],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0192, 0.0044, 0.0373, 0.0090, 0.0049, 0.0013, 0.0096, 0.0488],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3520], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 7000 th loss0 : 54065.5508, test rmse : 3.6933, test mnll: : 3.2045
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([4.3800e+00, 4.1275e-02, 2.3309e+01, 8.2947e-01, 2.0233e+00, 8.9614e-03,
#         1.0357e+00, 1.2791e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 2.2637,  0.1086, 10.7896,  1.1331,  2.0706,  0.2014,  1.1407,  6.3456],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0176, 0.0045, 0.0384, 0.0093, 0.0047, 0.0013, 0.0099, 0.0485],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4425], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [3, 2, 6, 2, 2, 2, 2, 5]
#
# 7100 th loss0 : 54221.4083, test rmse : 5.8049, test mnll: : 5.1566
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.9875e+00, 3.7434e-02, 2.4606e+01, 7.6625e-01, 1.8374e+00, 8.1293e-03,
#         9.5513e-01, 1.3651e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 2.0862,  0.1081, 10.7953,  1.0564,  1.9058,  0.2014,  1.0584,  6.3349],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0163, 0.0045, 0.0395, 0.0091, 0.0045, 0.0013, 0.0097, 0.0484],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3766], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7200 th loss0 : 53374.1811, test rmse : 5.2671, test mnll: : 5.2878
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.6588e+00, 3.3932e-02, 2.5910e+01, 7.0581e-01, 1.6690e+00, 7.3712e-03,
#         8.7177e-01, 1.4434e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.9229,  0.1080, 10.7918,  0.9884,  1.7539,  0.2014,  0.9860,  6.3406],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0157, 0.0046, 0.0406, 0.0091, 0.0044, 0.0013, 0.0094, 0.0487],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2577], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7300 th loss0 : 53419.5301, test rmse : 4.1810, test mnll: : 3.7930
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.3343e+00, 3.0755e-02, 2.7420e+01, 6.4356e-01, 1.5121e+00, 6.6836e-03,
#         7.9427e-01, 1.5310e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.7727,  0.1080, 10.7963,  0.9256,  1.6143,  0.2014,  0.9226,  6.3573],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0150, 0.0046, 0.0419, 0.0090, 0.0043, 0.0013, 0.0091, 0.0484],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2148], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7400 th loss0 : 52940.7790, test rmse : 7.0920, test mnll: : 7.5098
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([3.0243e+00, 2.7855e-02, 2.8974e+01, 5.8434e-01, 1.3710e+00, 6.0640e-03,
#         7.2298e-01, 1.6170e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.6344,  0.1080, 10.7927,  0.8647,  1.4857,  0.2014,  0.8670,  6.3395],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0142, 0.0046, 0.0429, 0.0087, 0.0042, 0.0013, 0.0090, 0.0484],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.2717], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7500 th loss0 : 52908.2883, test rmse : 6.9372, test mnll: : 7.5565
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.7437e+00, 2.5252e-02, 3.0563e+01, 5.3044e-01, 1.2460e+00, 5.5057e-03,
#         6.5717e-01, 1.7265e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.5073,  0.1080, 10.8078,  0.8148,  1.3676,  0.2014,  0.8139,  6.3498],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0132, 0.0047, 0.0440, 0.0086, 0.0041, 0.0013, 0.0089, 0.0489],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3508], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7600 th loss0 : 52637.2097, test rmse : 8.2048, test mnll: : 7.8935
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.4863e+00, 2.2893e-02, 3.2400e+01, 4.8236e-01, 1.1322e+00, 5.0003e-03,
#         5.9707e-01, 1.8230e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.3904,  0.1080, 10.7848,  0.7673,  1.2591,  0.2014,  0.7661,  6.3592],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0124, 0.0047, 0.0453, 0.0085, 0.0041, 0.0013, 0.0087, 0.0481],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3018], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7700 th loss0 : 52482.2180, test rmse : 4.2969, test mnll: : 3.9330
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.2520e+00, 2.0759e-02, 3.4083e+01, 4.3825e-01, 1.0261e+00, 4.5407e-03,
#         5.4326e-01, 1.9345e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.2828,  0.1080, 10.7984,  0.7260,  1.1591,  0.2014,  0.7219,  6.3441],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0115, 0.0047, 0.0465, 0.0084, 0.0041, 0.0013, 0.0087, 0.0476],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3890], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
# 7800 th loss0 : 52638.1534, test rmse : 3.8401, test mnll: : 3.4244
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([2.0415e+00, 1.8829e-02, 3.5941e+01, 3.9830e-01, 9.3211e-01, 4.1250e-03,
#         4.9423e-01, 2.0461e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.1840,  0.1081, 10.7889,  0.6856,  1.0669,  0.2014,  0.6856,  6.3296],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0107, 0.0048, 0.0480, 0.0084, 0.0041, 0.0013, 0.0087, 0.0473],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4068], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 7900 th loss0 : 52497.8812, test rmse : 4.9709, test mnll: : 4.6696
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.8511e+00, 1.7063e-02, 3.7887e+01, 3.6240e-01, 8.4643e-01, 3.7481e-03,
#         4.4856e-01, 2.1787e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.0932,  0.1080, 10.8165,  0.6526,  0.9820,  0.2014,  0.6508,  6.3554],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0100, 0.0048, 0.0494, 0.0085, 0.0042, 0.0013, 0.0088, 0.0478],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.3177], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]
#
# 8000 th loss0 : 52084.7411, test rmse : 8.5499, test mnll: : 8.4447
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# tensor([1.6802e+00, 1.5467e-02, 4.0079e+01, 3.2898e-01, 7.6795e-01, 3.4044e-03,
#         4.0615e-01, 2.2918e+01], device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([ 1.0097,  0.1080, 10.7893,  0.6219,  0.9039,  0.2014,  0.6211,  6.3179],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([0.0093, 0.0048, 0.0502, 0.0086, 0.0043, 0.0013, 0.0087, 0.0477],
#        device='cuda:0', grad_fn=<SqueezeBackward0>) tensor([3.4066], device='cuda:0', grad_fn=<PowBackward0>)
#
#
# self.num_samplept_list_at
# [2, 2, 7, 2, 2, 2, 2, 5]

# %% [markdown]
# # approximate prediction for train set

# %%
with torch.no_grad():
    pred_train_mu, pred_train_var = model._predict( inputs_new=x_train)
    #pred_train_mu, pred_train_var = model._predict_exact(inputs_new = x_train, diag=True)
    


plt.figure(figsize=(20,3))
if x_train.shape[1] == 1:
    plt.plot(x_train.cpu().data.numpy(),pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(x_train.cpu().data.numpy(),y_train.cpu().data.numpy(),'r.')
    plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:
    plt.plot(pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(y_train.cpu().data.numpy(),'r.')
    

_evaluate_metric(pred_train_mu, pred_train_var, y_train)
# Out:
# (array(1.5726), array(1.8967))

# %% [markdown]
# # exact prediction for train set

# %%
with torch.no_grad():
    #pred_train_mu, pred_train_var = model._predict( inputs_new=x_train)
    pred_train_mu, pred_train_var = model._predict_exact(inputs_new = x_train, diag=True)

plt.figure(figsize=(20,3))
if x_train.shape[1] == 1:
    plt.plot(x_train.cpu().data.numpy(),pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(x_train.cpu().data.numpy(),y_train.cpu().data.numpy(),'r.')
    plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:
    plt.plot(pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(y_train.cpu().data.numpy(),'r.')
    

_evaluate_metric(pred_train_mu, pred_train_var, y_train)
# Out:
# (array(1.458), array(1.8489))

# %% [markdown]
# # approximate prediction for test set

# %%
with torch.no_grad():
    pred_test_mu, pred_test_var = model._predict(inputs_new = x_test, diag=True)    
    #pred_test_mu, pred_test_var = model._predict_exact(inputs_new = x_test, diag=True)

plt.figure(figsize=(20,3))
if x_test.shape[1] == 1:
    plt.plot(x_test.cpu().data.numpy(),y_test.cpu().data.numpy(),'r.')
    plt.plot(x_test.cpu().data.numpy(),pred_test_mu.cpu().data.numpy(),'b.')
    plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:   
    plt.plot(pred_test_mu.cpu().data.numpy(),'b.')

_evaluate_metric(pred_test_mu, pred_test_var, y_test)
# Out:
# (array(4.5258), array(3.9535))

# %% [markdown]
# # exact predictin for test set

# %%
with torch.no_grad():
    #pred_test_mu, pred_test_var = model._predict(inputs_new = x_test, diag=True)    
    pred_test_mu, pred_test_var = model._predict_exact(inputs_new = x_test, diag=True)

plt.figure(figsize=(20,3))
if x_test.shape[1] == 1:
    plt.plot(x_test.cpu().data.numpy(),y_test.cpu().data.numpy(),'r.')
    plt.plot(x_test.cpu().data.numpy(),pred_test_mu.cpu().data.numpy(),'b.')
    plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:   
    plt.plot(pred_test_mu.cpu().data.numpy(),'b.')

_evaluate_metric(pred_test_mu, pred_test_var, y_test)
# Out:
# (array(3.7574), array(2.5886))
