# %%
import pickle
import copy
import torch
import time
import numpy as np
np.set_printoptions(precision = 4)

import sys
sys.path.append('./../')

from datasets.dataset import _load_collection_real,_load_collection_syn
from models_utility.construct_models import _initialize_SMkernelhyp,_make_gpmodel
from models_utility.param_gp import Param



from kernels.RBF_kernel import RBF
from kernels.SM_kernel import SM
from scipy.linalg import norm as fnorm


from utility.eval_metric import _evaluate_metric
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()
sns.set_style('white')



plt.rcParams["axes.grid"] = True
plt.rc('font', family='serif')
#plt.rc('font', weight='bold')

current_palette = sns.color_palette(sns.hls_palette(10+1, l=.4, s=1.0))
sns.palplot(current_palette)
current_palette = np.asarray(current_palette)

# %%
random_seed = 1000
device = True

#SM_Q2_exp1.mat 40.9 kB9일 전

#filename = 'SM_Q2_exp1'
filename = 'SM_Q5_exp1_unequal_v3'
x_train, x_test, x_full, y_train, y_test,y_full,Dataset = _load_collection_syn(filename, cuda_option=device)
# Out:
# #loaded collection#
# /home/yohan/Myenv/Summit_Conference/ICML21_SMapproximation_Sumbit/test

# %%
setting_dict = {}
setting_dict['random_seed'] = random_seed
setting_dict['init_sample_num'] = 500

#setting_dict['input_dim'] = x_train.shape[1]
setting_dict['input_dim'] = 1

setting_dict['Num_Q'] = 5
setting_dict['num_sample_pt'] = 3
setting_dict['num_batch'] = 1


setting_dict['lr_hyp'] = 0.005    

setting_dict['kl_option'] = True  
setting_dict['num_batch'] = 1
setting_dict['tau0'] = 1000
setting_dict['iter'] = 4000        
setting_dict['num_rep'] = 1
setting_dict['weight_rate'] = 1e-3 
setting_dict['optimizer'] = 'Adam'   
setting_dict['noise_err'] = 0.01*y_train.std()


setting_dict = _initialize_SMkernelhyp( x_train,y_train, setting_dict, random_seed)

# %%
ith_model_name = 'gpsm'
model = _make_gpmodel(model_name=ith_model_name, setting_dict=setting_dict, device=device)
model._set_data(x_train,y_train)

# %%
optimizable_param =  [*model.parameters(),model.likelihood.variance]
optimizable_param
# Out:
# [weight : tensor([[0.4297],
#          [0.1975],
#          [0.1026],
#          [0.0895],
#          [0.0423]], device='cuda:0'), std : tensor([[-3.3086],
#          [-3.5864],
#          [-3.0208],
#          [-2.1755],
#          [-6.9078]], device='cuda:0'), mu : tensor([[2.3831],
#          [1.8535],
#          [2.5961],
#          [1.8461],
#          [2.3749]], device='cuda:0'), noise_variance : tensor([-1.7184], device='cuda:0')]

# %%
optimizer = torch.optim.Adam(optimizable_param ,
                               lr=setting_dict['lr_hyp'],
                               betas=(0.9, 0.99),
                               eps=1e-08,
                               weight_decay=0.0)

# %%
for i in range(setting_dict['iter'] + 1):


    ith_tic = time.time()    
    optimizer.zero_grad()    
    
    
    

    ith_loss = model.compute_loss(batch_x=x_train, batch_y=y_train, kl_option=setting_dict['kl_option'])
    ith_loss.backward()
    optimizer.step()
    
    
    with torch.no_grad():
        pred_train_mu, pred_train_var = model._predict(inputs_new=x_train)
        pred_test_mu, pred_test_var = model._predict(inputs_new=x_test)


    # out1 : root mean square (rmse)
    # out2 : mean negative log likelihood (mnll)
    #ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)
    ith_rmse,ith_mnll = _evaluate_metric(pred_test_mu, pred_test_var, y_test)




    if i % 50 == 0 :
        print('%d th loss0 : %.4f, test rmse : %.4f, test mnll: : %.4f' % (i,ith_loss.cpu().data.numpy(),ith_rmse,ith_mnll))
        try:
            print('self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance')            
            print(model.weight.exp().squeeze(),model.mu.exp().squeeze(),model.std.exp().squeeze(),model.likelihood.variance.transform()**2)

            print('\n')
            print('self.num_samplept_list_at')
            print(model.num_samplept_list_at)
        except:
            pass
        
#                 print('self.weight.exp(),self.mu.exp(),self.std.exp()')            
#                 print(ith_model.kernel.weight.exp().squeeze(),ith_model.kernel.mu.exp().squeeze(),ith_model.kernel.std.exp().squeeze())

        print('')
# Out:
# 0 th loss0 : -1080.3697, test rmse : 1.6894, test mnll: : 1.8785
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 50 th loss0 : -1763.2942, test rmse : 1.5009, test mnll: : 1.6739
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 100 th loss0 : -2242.7886, test rmse : 1.4847, test mnll: : 1.6380
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 150 th loss0 : -2711.9619, test rmse : 1.4779, test mnll: : 1.5500
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 200 th loss0 : -3169.7826, test rmse : 1.4406, test mnll: : 1.5212
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 250 th loss0 : -3611.1294, test rmse : 1.4118, test mnll: : 1.4007
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 300 th loss0 : -4028.2027, test rmse : 1.3569, test mnll: : 1.2169
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 350 th loss0 : -4409.5108, test rmse : 1.3153, test mnll: : 1.0708
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 400 th loss0 : -4736.7507, test rmse : 1.2497, test mnll: : 0.9404
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 450 th loss0 : -4990.5068, test rmse : 1.2029, test mnll: : 0.8354
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 500 th loss0 : -5152.6674, test rmse : 1.2146, test mnll: : 0.7689
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 550 th loss0 : -5227.6692, test rmse : 1.2274, test mnll: : 0.7391
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 600 th loss0 : -5247.2506, test rmse : 1.2768, test mnll: : 0.7341
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 650 th loss0 : -5249.6343, test rmse : 1.2786, test mnll: : 0.7324
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 700 th loss0 : -5249.1693, test rmse : 1.1983, test mnll: : 0.6943
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 750 th loss0 : -5249.7028, test rmse : 1.2252, test mnll: : 0.7135
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 800 th loss0 : -5249.8989, test rmse : 1.2163, test mnll: : 0.7060
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 850 th loss0 : -5249.4094, test rmse : 1.1945, test mnll: : 0.7006
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 900 th loss0 : -5249.7288, test rmse : 1.2939, test mnll: : 0.7326
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 950 th loss0 : -5249.8818, test rmse : 1.2261, test mnll: : 0.7050
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1000 th loss0 : -5248.8960, test rmse : 1.2733, test mnll: : 0.7240
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1050 th loss0 : -5249.7643, test rmse : 1.2620, test mnll: : 0.7208
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1100 th loss0 : -5249.6598, test rmse : 1.3298, test mnll: : 0.7434
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1150 th loss0 : -5249.6966, test rmse : 1.2288, test mnll: : 0.7092
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1200 th loss0 : -5249.8452, test rmse : 1.2251, test mnll: : 0.7074
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1250 th loss0 : -5247.9743, test rmse : 1.3139, test mnll: : 0.7511
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1300 th loss0 : -5248.3268, test rmse : 1.3008, test mnll: : 0.7385
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1350 th loss0 : -5248.4619, test rmse : 1.1538, test mnll: : 0.6898
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1400 th loss0 : -5248.6023, test rmse : 1.2771, test mnll: : 0.7273
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1450 th loss0 : -5248.7699, test rmse : 1.2368, test mnll: : 0.7117
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1500 th loss0 : -5248.6619, test rmse : 1.2211, test mnll: : 0.7128
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1550 th loss0 : -5241.3608, test rmse : 1.2423, test mnll: : 0.7132
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1600 th loss0 : -5242.5113, test rmse : 1.2208, test mnll: : 0.7010
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1650 th loss0 : -5246.4224, test rmse : 1.2498, test mnll: : 0.7130
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1700 th loss0 : -5248.7122, test rmse : 1.2212, test mnll: : 0.7013
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 1750 th loss0 : -5249.3175, test rmse : 1.2391, test mnll: : 0.7144
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 3950 th loss0 : -5251.0964, test rmse : 1.2020, test mnll: : 0.7044
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 4000 th loss0 : -5251.0476, test rmse : 1.2201, test mnll: : 0.7131
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
#
# 4050 th loss0 : -5251.0098, test rmse : 1.2759, test mnll: : 0.7314
# self.weight.exp(),self.mu.exp(),self.std.exp(),likelihood variance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e73dfc47de00> in <module>()
#      15     with torch.no_grad():
#      16         pred_train_mu, pred_train_var = model._predict(inputs_new=x_train)
# ---> 17         pred_test_mu, pred_test_var = model._predict(inputs_new=x_test)
#      18
#      19
#
# /home/yohan/Myenv/Summit_Conference/ICML21_SMapproximation_Sumbit/models/gp.py in _predict(self, inputs_new, diag)
#      89         k_xs = self._compute_Kxs(self.x,inputs_new)
#      90
# ---> 91         L = cholesky(k_xx)
#      92         A = triangular_solve(k_xs,L,upper=False)[0]   #A = trtrs(L, k_xs)
#      93         V = triangular_solve(self.y,L,upper=False)[0]
#
# /home/yohan/Myenv/Summit_Conference/ICML21_SMapproximation_Sumbit/models_utility/function_gp.py in cholesky(A, flag)
#     151     """
#     152     # return _Cholesky(flag=flag)(A)
# --> 153     return _Cholesky(flag=flag).apply(A)
#     154
#     155
#
# /home/yohan/Myenv/Summit_Conference/ICML21_SMapproximation_Sumbit/models_utility/function_gp.py in forward(self, A)
#     112             try:
#     113                 # L = torch.potrf(A, upper=False)
# --> 114                 L = torch.cholesky(A, upper=False)
#     115                 success = True
#     116
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    pred_train_mu, pred_train_var = model._predict( inputs_new=x_train)    


plt.figure(figsize=(20,3))
if x_train.shape[1] == 1:
    plt.plot(x_train.cpu().data.numpy(),pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(x_train.cpu().data.numpy(),y_train.cpu().data.numpy(),'r.')
    plt.fill_between( x_train.cpu().data.numpy().squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      pred_train_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:
    plt.plot(pred_train_mu.cpu().data.numpy(),'b.')
    plt.plot(y_train.cpu().data.numpy(),'r.')
#     plt.fill_between( x_train.cpu().data.numpy().squeeze(),
#                       pred_train_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
#                       pred_train_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_train_var.cpu().data.numpy()).squeeze(),
#                       alpha = 0.5, edgecolor = 'b', facecolor = 'b')        

_evaluate_metric(pred_train_mu, pred_train_var, y_train)
# Out:
# (array(0.0135), array(-2.8872))

# %%
with torch.no_grad():
    pred_test_mu, pred_test_var = model._predict( inputs_new=x_test)

plt.figure(figsize=(20,3))
if x_test.shape[1] == 1:
    plt.plot(x_test.cpu().data.numpy(),y_test.cpu().data.numpy(),'r.')
    plt.plot(x_test.cpu().data.numpy(),pred_test_mu.cpu().data.numpy(),'b.')
    plt.fill_between( x_test.cpu().data.numpy().squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() - np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      pred_test_mu.cpu().data.numpy().squeeze() + np.sqrt(pred_test_var.cpu().data.numpy()).squeeze(),
                      alpha = 0.5, edgecolor = 'b', facecolor = 'b')
else:   
    plt.plot(pred_test_mu.cpu().data.numpy(),'b.')
    #plt.plot(y_test.cpu().data.numpy(),'r.')
#plt.ylim([-50,50])
_evaluate_metric(pred_test_mu, pred_test_var, y_test)
# Out:
# (array(1.1829), array(0.7032))
